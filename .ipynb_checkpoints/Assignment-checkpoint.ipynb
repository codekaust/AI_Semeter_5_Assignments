# %% [markdown]
# # PREPROCESSING

# %%
# import ElementTree to parse XML test corpus
import xml.etree.ElementTree as ET

# %%
# get all files in the Train-corpus folder
import glob
path = '/home/bhavye/CSN-371-AI/Assignment-files/Train-corups/*.xml'
files = glob.glob(path)

# %%
# open a file to write the cleaned data
writer = open("train_data.txt", "w+")

# iterate over all files
for file in files:
    
    # parse each XML file
    tree = ET.parse(file)
    root = tree.getroot()   
    
    # get w elements in the file
    for word in root.iter('w'):      
        writer.write("%s_%s\n" % (word.text.strip(), word.attrib['pos'].strip()))
        
writer.close()

# %% [markdown]
# # WORD+TAG FREQUENCY COUNT

# %%
freq = {}

reader = open("train_data.txt", "r")
for line in reader:
    freq[line.strip()] = freq.get(line.strip(), 0) + 1

reader.close()

# %%
freq
# Out:
# {'FACTSHEET_SUBST': 4,
#  'WHAT_PRON': 22,
#  'IS_VERB': 35,
#  'AIDS_SUBST': 176,
#  'Acquired_VERB': 1,
#  'Immune_ADJ': 1,
#  'Deficiency_SUBST': 3,
#  'Syndrome_SUBST': 4,
#  'is_VERB': 10777,
#  'a_ART': 19068,
#  'condition_SUBST': 49,
#  'caused_VERB': 76,
#  'by_PREP': 3827,
#  'virus_SUBST': 28,
#  'called_VERB': 245,
#  'HIV_SUBST': 78,
#  'Human_ADJ': 18,
#  'Immuno_SUBST': 2,
#  'Virus_SUBST': 2,
#  'This_ADJ': 1175,
#  'affects_VERB': 18,
#  'the_ART': 46249,
#  'body_SUBST': 283,
#  "'s_UNC": 3665,
#  'defence_SUBST': 22,
#  'system_SUBST': 370,
#  'so_ADV': 1538,
#  'that_CONJ': 5832,
#  'it_PRON': 7085,
#  'can_VERB': 2719,
#  'not_ADV': 4226,
#  'fight_VERB': 38,
#  'infection_SUBST': 52,
#  'How_ADV': 306,
#  'transmitted_VERB': 7,
#  'through_PREP': 607,
#  'unprotected_ADJ': 4,
#  'sexual_ADJ': 68,
#  'intercourse_SUBST': 26,
#  'with_PREP': 5918,
#  'an_ART': 2974,
#  'infected_ADJ': 16,
#  'partner_SUBST': 60,
#  'blood_SUBST': 94,
#  'or_CONJ': 4030,
#  'products_SUBST': 40,
#  'from_PREP': 3561,
#  'mother_SUBST': 150,
#  'to_PREP': 23319,
#  'her_PRON': 2605,
#  'baby_SUBST': 100,
#  'It_PRON': 2123,
#  'giving_VERB': 93,
#  'blood/mosquito_SUBST': 1,
#  'bites/toilet_UNC': 1,
#  'seats/kissing/from_UNC': 1,
#  'normal_ADJ': 124,
#  'day-to-day_ADJ': 8,
#  'contact_SUBST': 70,
#  'does_VERB': 575,
#  'affect_VERB': 40,
#  'you_PRON': 6133,
#  'The_ART': 5050,
#  'medical_ADJ': 54,
#  'aspects_SUBST': 79,
#  'be_VERB': 6167,
#  'cancer_SUBST': 28,
#  'pneumonia_SUBST': 12,
#  'sudden_ADJ': 43,
#  'blindness_SUBST': 5,
#  'dementia_SUBST': 4,
#  'dramatic_ADJ': 44,
#  'weight_SUBST': 115,
#  'loss_SUBST': 70,
#  'any_ADJ': 1056,
#  'combination_SUBST': 51,
#  'of_PREP': 25860,
#  'these_ADJ': 817,
#  'Often_ADV': 23,
#  'people_SUBST': 1015,
#  'are_VERB': 4697,
#  'rejected_VERB': 15,
#  'family_SUBST': 339,
#  'and_CONJ': 22704,
#  'friends_SUBST': 177,
#  'leaving_VERB': 90,
#  'them_PRON': 1584,
#  'face_VERB': 76,
#  'this_ADJ': 3224,
#  'chronic_ADJ': 14,
#  'alone_ADV': 79,
#  'Did_VERB': 89,
#  'know_VERB': 862,
#  'there_PRON': 1499,
#  'no_ART': 1261,
#  'vaccine_SUBST': 7,
#  'cure_VERB': 3,
#  'currently_ADV': 36,
#  'available_ADJ': 290,
#  '10_ADJ': 77,
#  'million_ADJ': 60,
#  'worldwide_ADV': 13,
#  'infected_VERB': 51,
#  'for_PREP': 6785,
#  'between_PREP': 721,
#  '10–15_UNC': 5,
#  'years_SUBST': 677,
#  'without_PREP': 463,
#  'realising_VERB': 8,
#  '7_ADJ': 54,
#  'out_ADV': 1887,
#  'heterosexual_ADJ': 2,
#  'women_SUBST': 251,
#  'twice_ADV': 42,
#  'as_CONJ': 3302,
#  'at_PREP': 4222,
#  'risk_SUBST': 98,
#  'men_SUBST': 299,
#  'In_PREP': 1315,
#  'UK_SUBST': 158,
#  '16,000_ADJ': 1,
#  'reported_ADJ': 4,
#  'infections_SUBST': 18,
#  'probable_ADJ': 5,
#  '40–60,000_UNC': 1,
#  'actually_ADV': 154,
#  'nearly_ADV': 87,
#  '5,000_ADJ': 3,
#  'cases_SUBST': 133,
#  'which_PRON': 3420,
#  '3,000_ADJ': 5,
#  'have_VERB': 4154,
#  'already_ADV': 273,
#  'died_VERB': 85,
#  '1_ADJ': 189,
#  'in_PREP': 14009,
#  '500_ADJ': 15,
#  'Londoners_SUBST': 1,
#  'believed_VERB': 45,
#  'Future_SUBST': 3,
#  'World_SUBST': 138,
#  'Health_SUBST': 89,
#  'Organisation_SUBST': 10,
#  'projects_SUBST': 30,
#  '40_ADJ': 30,
#  'year_SUBST': 478,
#  '2000_ADJ': 12,
#  'We_PRON': 647,
#  'just_ADV': 929,
#  'beginning_SUBST': 85,
#  'worldwide_ADJ': 6,
#  'epidemic_SUBST': 4,
#  'situation_SUBST': 148,
#  'still_ADV': 576,
#  'very_ADV': 955,
#  'unstable_ADJ': 5,
#  'major_ADJ': 136,
#  'impact_SUBST': 58,
#  'yet_ADV': 233,
#  'come_VERB': 526,
#  'Professor_SUBST': 30,
#  'Jonathan_SUBST': 30,
#  'Mann_SUBST': 4,
#  'former_ADJ': 90,
#  'director_SUBST': 82,
#  'WHO_SUBST': 9,
#  'Global_ADJ': 3,
#  'Programme_SUBST': 7,
#  'ACET_SUBST': 205,
#  'International_ADJ': 66,
#  'Adviser_SUBST': 7,
#  'Useful_ADJ': 6,
#  'Contacts_SUBST': 3,
#  'Practical_ADJ': 8,
#  'home_SUBST': 290,
#  'care_SUBST': 206,
#  'schools_SUBST': 216,
#  'education_SUBST': 112,
#  'training_SUBST': 339,
#  '081_ADJ': 17,
#  '840_ADJ': 12,
#  '7879_ADJ': 12,
#  'Mildmay_SUBST': 1,
#  'Hospital_SUBST': 17,
#  'Hackney_SUBST': 2,
#  'Road_SUBST': 57,
#  'London_SUBST': 379,
#  'E2_UNC': 2,
#  '7NA_UNC': 1,
#  'Hospice_SUBST': 3,
#  '071_ADJ': 8,
#  '739_ADJ': 1,
#  '2331_ADJ': 1,
#  'Catholic_ADJ': 36,
#  'Link_SUBST': 4,
#  'Spiritual_ADJ': 1,
#  'practical_ADJ': 134,
#  'financial_ADJ': 52,
#  'support_SUBST': 150,
#  'P_SUBST': 7,
#  'O_SUBST': 14,
#  'Box_SUBST': 42,
#  '646_ADJ': 1,
#  'E9_UNC': 1,
#  '6QP_UNC': 1,
#  'National_ADJ': 109,
#  'Helpline_SUBST': 5,
#  'Counselling_SUBST': 3,
#  'confidential_ADJ': 8,
#  'advice_SUBST': 159,
#  '0800_ADJ': 10,
#  '567_ADJ': 2,
#  '123_ADJ': 4,
#  'Bureau_SUBST': 18,
#  'Hygiene_SUBST': 1,
#  'Tropical_ADJ': 2,
#  'Medicine_SUBST': 4,
#  'Overseas_ADJ': 2,
#  'development_SUBST': 150,
#  '636_ADJ': 1,
#  '8638_ADJ': 1,
#  'Haemophilia_SUBST': 1,
#  'Society_SUBST': 51,
#  'Serving_VERB': 3,
#  'interests_SUBST': 51,
#  'Haemophiliacs_SUBST': 1,
#  '928_ADJ': 2,
#  '2020_ADJ': 1,
#  'SCODA_SUBST': 2,
#  'drugs_SUBST': 56,
#  '430_ADJ': 3,
#  '2341_ADJ': 1,
#  'Immunity_SUBST': 1,
#  'legal_ADJ': 38,
#  'issues_SUBST': 50,
#  '968_ADJ': 1,
#  '8909_ADJ': 1,
#  'PUT_VERB': 1,
#  'THE_ART': 219,
#  'FUN_ADJ': 2,
#  'BACK_SUBST': 2,
#  'IN_PREP': 44,
#  'FUNDRAISING_SUBST': 1,
#  'Raising_VERB': 2,
#  'money_SUBST': 234,
#  'your_PRON': 2218,
#  'favourite_ADJ': 41,
#  'charity_SUBST': 38,
#  'fun_ADJ': 19,
#  'You_PRON': 1039,
#  'do_VERB': 2050,
#  'on_PREP': 5038,
#  'own_ADJ': 678,
#  'get_VERB': 761,
#  'together_ADV': 299,
#  'There_PRON': 737,
#  'limit_SUBST': 28,
#  'number_SUBST': 297,
#  'ways_SUBST': 122,
#  'raise_VERB': 52,
#  'Whether_CONJ': 32,
#  'final_ADJ': 126,
#  'total_SUBST': 17,
#  '£5_UNC': 8,
#  '£5,000_UNC': 3,
#  'all_ADJ': 2113,
#  'much_ADV': 350,
#  'needed_VERB': 140,
#  'Below_ADV': 6,
#  'I_PRON': 8385,
#  "'ve_VERB": 459,
#  'listed_VERB': 44,
#  'some_ADJ': 1351,
#  'ideas_SUBST': 92,
#  'many_ADJ': 693,
#  'carried_VERB': 81,
#  'None_PRON': 17,
#  'new_ADJ': 702,
#  'they_PRON': 2697,
#  'straightforward_ADJ': 16,
#  'CAR_SUBST': 2,
#  'BOOT_SUBST': 1,
#  'SALE_SUBST': 4,
#  'Why_ADV': 189,
#  'clear_ADJ': 204,
#  'did_VERB': 912,
#  'was_VERB': 6284,
#  'absolutely_ADV': 54,
#  'amazed_ADJ': 7,
#  'how_ADV': 822,
#  'much_ADJ': 457,
#  'stuff_SUBST': 42,
#  'sold_VERB': 43,
#  'kind_SUBST': 247,
#  'things_SUBST': 400,
#  'bought_VERB': 70,
#  'well_ADV': 816,
#  '2_ADJ': 157,
#  'JUMBLE_VERB': 1,
#  'A_ART': 1055,
#  'bit_SUBST': 171,
#  'like_PREP': 1039,
#  'car_SUBST': 135,
#  'boot_SUBST': 5,
#  'sale_SUBST': 27,
#  'but_CONJ': 2700,
#  'clothes_SUBST': 91,
#  'happens_VERB': 89,
#  'indoors_ADV': 16,
#  'need_VERB': 465,
#  'involve_VERB': 22,
#  'collecting_VERB': 8,
#  'jumble_SUBST': 5,
#  'Do_VERB': 291,
#  "n't_ADV": 2105,
#  'plan_VERB': 24,
#  'selling_VERB': 22,
#  'too_ADV': 823,
#  'more_ADV': 1246,
#  'than_CONJ': 1214,
#  '10p_SUBST': 3,
#  'item_SUBST': 17,
#  '3_ADJ': 143,
#  'SPONSORED_ADJ': 5,
#  'RUN_SUBST': 1,
#  'For_PREP': 420,
#  'keen_ADJ': 36,
#  'runner_SUBST': 8,
#  'why_ADV': 316,
#  'next_ADJ': 324,
#  'full_ADJ': 320,
#  'half_ADJ': 125,
#  'marathon_SUBST': 3,
#  'sponsored_VERB': 25,
#  '4_ADJ': 103,
#  'HAVE_VERB': 7,
#  'DISCO_SUBST': 2,
#  'At_PREP': 325,
#  'local_ADJ': 383,
#  'club_SUBST': 20,
#  'church_SUBST': 248,
#  'put_VERB': 408,
#  'evening_SUBST': 130,
#  'young_ADJ': 357,
#  "'s_VERB": 1698,
#  'hard_ADJ': 160,
#  'work_SUBST': 929,
#  'rewarding_ADJ': 8,
#  '5_ADJ': 91,
#  'PARACHUTE_SUBST': 1,
#  'JUMP_SUBST': 1,
#  'Not_ADV': 260,
#  'faint-hearted_ADJ': 1,
#  'But_CONJ': 1120,
#  'pluck_VERB': 1,
#  'up_ADV': 1832,
#  'courage_SUBST': 12,
#  'what_PRON': 1637,
#  'always_ADV': 582,
#  'wanted_VERB': 217,
#  'good_ADJ': 709,
#  'cause_SUBST': 76,
#  '6_ADJ': 54,
#  'SLIM_ADJ': 1,
#  'HOLD_VERB': 1,
#  'COFFEE_SUBST': 2,
#  'MORNING_SUBST': 2,
#  'BAKE_VERB': 1,
#  'CAKES_SUBST': 1,
#  'sell_VERB': 31,
#  'work_VERB': 298,
#  'colleagues_SUBST': 46,
#  '8_ADJ': 42,
#  'KIDDIES_SUBST': 1,
#  "'_UNC": 431,
#  'SWIM_SUBST': 1,
#  '9_ADJ': 22,
#  'Organise_VERB': 1,
#  'WALK_SUBST': 1,
#  'OR_CONJ': 14,
#  'RAMBLE_SUBST': 1,
#  'youth_SUBST': 29,
#  'MARATHON_SUBST': 1,
#  'FOOTBALL_SUBST': 2,
#  '5-A-SIDE_SUBST': 1,
#  'If_CONJ': 899,
#  'help_VERB': 292,
#  'further_ADV': 97,
#  'please_ADV': 49,
#  'hesitate_VERB': 9,
#  'contact_VERB': 63,
#  'me_PRON': 1494,
#  'Peter_SUBST': 92,
#  'Fabian_SUBST': 3,
#  'Director_SUBST': 50,
#  'Fundraising_SUBST': 1,
#  'BECOMING_VERB': 1,
#  'AN_ART': 8,
#  'HOME_SUBST': 9,
#  'CARE_SUBST': 14,
#  'VOLUNTEER_SUBST': 1,
#  'About_PREP': 19,
#  'Home_SUBST': 61,
#  'Care_SUBST': 47,
#  'Many_ADJ': 123,
#  'spend_VERB': 51,
#  'long_ADJ': 316,
#  'periods_SUBST': 70,
#  'time_SUBST': 1414,
#  'hospital_SUBST': 73,
#  'unless_CONJ': 99,
#  'someone_PRON': 250,
#  'who_PRON': 1772,
#  'look_VERB': 346,
#  'after_PREP': 605,
#  'volunteers_SUBST': 40,
#  'as_PREP': 1759,
#  'part_SUBST': 464,
#  'team_SUBST': 91,
#  'provide_VERB': 166,
#  'help_SUBST': 197,
#  'different_ADJ': 415,
#  'ensure_VERB': 72,
#  'unnecessarily_ADV': 7,
#  'What_PRON': 631,
#  'Transport_SUBST': 7,
#  'clients_SUBST': 27,
#  'Housework_SUBST': 3,
#  'Shopping_VERB': 2,
#  'including_PREP': 134,
#  'collection_SUBST': 42,
#  'prescriptions_SUBST': 5,
#  'Daysitting_VERB': 1,
#  'nightsitting_VERB': 2,
#  'give_VERB': 425,
#  'simple_ADJ': 160,
#  'answer_SUBST': 60,
#  'as_ADV': 482,
#  'little_ADJ': 457,
#  'feel_VERB': 305,
#  'able_ADJ': 352,
#  'our_PRON': 712,
#  'existing_ADJ': 67,
#  'families_SUBST': 52,
#  'jobs_SUBST': 18,
#  'often_ADV': 468,
#  'busy_ADJ': 43,
#  'make_VERB': 849,
#  'firm_ADJ': 32,
#  'commitment_SUBST': 38,
#  'obviously_ADV': 51,
#  'we_PRON': 1620,
#  'like_VERB': 304,
#  'us_PRON': 581,
#  'idea_SUBST': 239,
#  'availability_SUBST': 11,
#  'respond_VERB': 45,
#  'effectively_ADV': 39,
#  'needs_SUBST': 79,
#  'Yes_INTERJ': 143,
#  'expected_VERB': 78,
#  'nurse_SUBST': 30,
#  'will_VERB': 2500,
#  'asked_VERB': 328,
#  'complete_VERB': 29,
#  'application_SUBST': 45,
#  'form_SUBST': 260,
#  'subsequently_ADV': 26,
#  'attend_VERB': 34,
#  'course_SUBST': 429,
#  'one_ADJ': 1479,
#  'week_SUBST': 162,
#  'six_ADJ': 119,
#  'weeks_SUBST': 100,
#  'subjects_SUBST': 59,
#  'covered_VERB': 58,
#  'include_VERB': 128,
#  'Death_SUBST': 25,
#  'Dying_VERB': 1,
#  'Grief_SUBST': 1,
#  'Loss_SUBST': 3,
#  'Sex_SUBST': 15,
#  'Sexuality_SUBST': 2,
#  'Medical_ADJ': 11,
#  'Aspects_SUBST': 4,
#  'HIV/AIDS_UNC': 20,
#  'Race_SUBST': 1,
#  'Racism_SUBST': 1,
#  'Issues_SUBST': 4,
#  'if_CONJ': 1857,
#  'find_VERB': 471,
#  'certain_ADJ': 231,
#  'situations_SUBST': 35,
#  'difficult_ADJ': 225,
#  'Your_PRON': 136,
#  'leader_SUBST': 19,
#  'also_ADV': 1042,
#  'keep_VERB': 281,
#  'leaders_SUBST': 25,
#  'informed_VERB': 39,
#  'involvement_SUBST': 25,
#  'adequately_ADV': 14,
#  'supported_VERB': 41,
#  'After_CONJ': 40,
#  'every_ART': 361,
#  'client_SUBST': 14,
#  'visit_VERB': 50,
#  'call_VERB': 89,
#  'office_SUBST': 125,
#  'report_VERB': 20,
#  'visit_SUBST': 45,
#  'went_VERB': 457,
#  'hold_VERB': 125,
#  'regular_ADJ': 83,
#  'meetings_SUBST': 31,
#  'discuss_VERB': 50,
#  'concern_SUBST': 64,
#  'encourage_VERB': 51,
#  'another_ADJ': 507,
#  'Volunteers_SUBST': 10,
#  'visiting_VERB': 10,
#  'immediate_ADJ': 45,
#  'access_SUBST': 62,
#  'professional_ADJ': 92,
#  'nursing_ADJ': 8,
#  '24_ADJ': 17,
#  'hour_SUBST': 76,
#  'call_SUBST': 41,
#  'facility_SUBST': 17,
#  'would_VERB': 1743,
#  'volunteer_VERB': 6,
#  'now_ADV': 987,
#  'Telephone_VERB': 7,
#  'write_VERB': 156,
#  'Christine_SUBST': 3,
#  'Catlin_SUBST': 3,
#  'Janet_SUBST': 9,
#  'Sutton_SUBST': 8,
#  'ask_VERB': 174,
#  '1323_ADJ': 6,
#  'W5_UNC': 7,
#  '5TF_UNC': 6,
#  'Tel_SUBST': 49,
#  'Newsletter_SUBST': 1,
#  'EDUCATION_SUBST': 12,
#  'AND_CONJ': 84,
#  'TRAINING_SUBST': 17,
#  'Issue_SUBST': 1,
#  'No._SUBST': 31,
#  'Cliff_SUBST': 10,
#  'New_ADJ': 60,
#  'Patron_SUBST': 2,
#  'CLIFF_SUBST': 1,
#  'RICHARD_SUBST': 1,
#  'Head_SUBST': 35,
#  'Salvation_SUBST': 11,
#  'Army_SUBST': 17,
#  'General_SUBST': 10,
#  'Eva_SUBST': 3,
#  'Burrows_SUBST': 2,
#  'first_ADJ': 953,
#  'patrons_SUBST': 2,
#  'Ealing_SUBST': 19,
#  'offices_SUBST': 34,
#  'BBC_SUBST': 62,
#  'newsroom_SUBST': 1,
#  'South_SUBST': 95,
#  'East_SUBST': 57,
#  'television_SUBST': 157,
#  'cameras_SUBST': 4,
#  'attendance_SUBST': 7,
#  'cut_VERB': 120,
#  'cake_SUBST': 34,
#  'celebrate_VERB': 14,
#  'third_ADJ': 101,
#  'birthday_SUBST': 28,
#  'during_PREP': 326,
#  'June_SUBST': 65,
#  'After_PREP': 136,
#  'short_ADJ': 179,
#  'interview_SUBST': 40,
#  'meet_VERB': 134,
#  'Tony_SUBST': 34,
#  'Chapman_SUBST': 2,
#  'his_PRON': 3740,
#  'Community_SUBST': 31,
#  'Nurse_SUBST': 5,
#  'Sue_SUBST': 13,
#  'Lore_SUBST': 4,
#  'trip_SUBST': 18,
#  'class_SUBST': 102,
#  'Abbeylands_SUBST': 1,
#  'School_SUBST': 35,
#  'Addlestone_SUBST': 1,
#  'Surrey_SUBST': 17,
#  'completed_VERB': 43,
#  'said_VERB': 1972,
#  'am_VERB': 326,
#  'pleased_ADJ': 35,
#  'support_VERB': 75,
#  'world_SUBST': 628,
#  'doing_VERB': 230,
#  'community_SUBST': 194,
#  'ill_ADJ': 55,
#  'schoolchildren_SUBST': 3,
#  'prevent_VERB': 127,
#  'spread_SUBST': 17,
#  'terrible_ADJ': 22,
#  'disease_SUBST': 38,
#  'becoming_VERB': 60,
#  'urgent_ADJ': 18,
#  'believe_VERB': 175,
#  'especially_ADV': 178,
#  'important_ADJ': 395,
#  'represents_VERB': 30,
#  'Church_SUBST': 82,
#  'working_VERB': 170,
#  'front_ADJ': 141,
#  'line_SUBST': 159,
#  'real_ADJ': 269,
#  'So_ADV': 361,
#  'Christians_SUBST': 4,
#  'criticised_VERB': 9,
#  'getting_VERB': 174,
#  'involved_VERB': 42,
#  'Dr_SUBST': 66,
#  'Patrick_SUBST': 75,
#  'Dixon_SUBST': 9,
#  'Glasgow_SUBST': 29,
#  'opened_VERB': 89,
#  'its_PRON': 1296,
#  'service_SUBST': 176,
#  'late_ADJ': 201,
#  'receiving_VERB': 24,
#  'confirmation_SUBST': 7,
#  'grant_SUBST': 59,
#  'Greater_SUBST': 5,
#  'Board_SUBST': 16,
#  'fund_VERB': 6,
#  'Ruchill_SUBST': 1,
#  'Social_ADJ': 78,
#  'Resource_SUBST': 3,
#  'Unit_SUBST': 20,
#  'were_VERB': 1899,
#  'particularly_ADV': 202,
#  'helpful_ADJ': 34,
#  'identifying_VERB': 12,
#  'need_SUBST': 146,
#  'Coordinator_SUBST': 1,
#  'Margaret_SUBST': 9,
#  'Gillies_SUBST': 9,
#  'has_VERB': 2250,
#  '20_ADJ': 61,
#  'variety_SUBST': 96,
#  'churches_SUBST': 53,
#  'providing_VERB': 42,
#  'referred_VERB': 34,
#  'Strathclyde_SUBST': 3,
#  'Regional_ADJ': 12,
#  'Council_SUBST': 73,
#  'may_VERB': 1271,
#  'further_ADJ': 163,
#  'funding_SUBST': 15,
#  'consideration_SUBST': 16,
#  'being_VERB': 716,
#  'given_VERB': 239,
#  'possible_ADJ': 374,
#  'employment_SUBST': 17,
#  'part-time_ADJ': 14,
#  'says_VERB': 200,
#  'discovering_VERB': 10,
#  'extent_SUBST': 41,
#  'offers_VERB': 47,
#  'other_ADJ': 1007,
#  'agencies_SUBST': 29,
#  'Scottish_ADJ': 30,
#  'Monitor_SUBST': 1,
#  'Body_SUBST': 6,
#  'Positive_ADJ': 2,
#  'contacts_SUBST': 11,
#  'counselling_SUBST': 20,
#  'services_SUBST': 134,
#  'Chris_SUBST': 19,
#  'Southwick_SUBST': 2,
#  'Scotland_SUBST': 53,
#  'With_PREP': 152,
#  'opening_SUBST': 38,
#  'volunteer_SUBST': 10,
#  '95%_UNC': 1,
#  'those_ADJ': 673,
#  'Most_ADJ': 109,
#  'Churches_SUBST': 8,
#  'Unprepared_ADJ': 1,
#  'Aids_SUBST': 5,
#  'completely_ADV': 86,
#  'unprepared_ADJ': 3,
#  'shock_SUBST': 22,
#  'finding_VERB': 61,
#  'established_ADJ': 13,
#  'member_SUBST': 72,
#  'congregation_SUBST': 13,
#  'dying_VERB': 23,
#  'even_ADV': 833,
#  'though_CONJ': 437,
#  'increasingly_ADV': 39,
#  'common_ADJ': 154,
#  'recently_ADV': 105,
#  'told_VERB': 261,
#  'Symposium_SUBST': 2,
#  'Teenage_ADJ': 2,
#  'Swanwick_SUBST': 1,
#  'conference_SUBST': 48,
#  'attended_VERB': 31,
#  '300_ADJ': 13,
#  'school_SUBST': 302,
#  'workers_SUBST': 34,
#  'across_PREP': 186,
#  'illness_SUBST': 28,
#  'been_VERB': 1905,
#  'added_VERB': 77,
#  'that_ADJ': 2136,
#  'Three-quarters_ADJ': 1,
#  'problem_SUBST': 306,
#  'rest_SUBST': 154,
#  'cities_SUBST': 33,
#  'areas_SUBST': 157,
#  'involved_ADJ': 53,
#  'supporting_ADJ': 13,
#  'Christian_ADJ': 50,
#  'seeking_VERB': 42,
#  'considered_VERB': 91,
#  'communicate_VERB': 10,
#  'today_ADV': 133,
#  'benefit_SUBST': 83,
#  'their_PRON': 2079,
#  'safety_SUBST': 62,
#  'emotional_ADJ': 24,
#  'health_SUBST': 147,
#  'responding_VERB': 13,
#  'Those_ADJ': 48,
#  'helping_VERB': 37,
#  'home_ADV': 143,
#  'care_VERB': 46,
#  'one_PRON': 856,
#  'four_ADJ': 172,
#  '4,000_ADJ': 6,
#  'pupils_SUBST': 25,
#  'month_SUBST': 110,
#  'subject_SUBST': 166,
#  'Both_ADJ': 40,
#  'programmes_SUBST': 43,
#  'largest_ADJ': 28,
#  'country_SUBST': 238,
#  'offering_VERB': 32,
#  'speakers_SUBST': 10,
#  'inform_VERB': 18,
#  'motivate_VERB': 2,
#  'train_SUBST': 42,
#  'wanting_VERB': 28,
#  'speaker_SUBST': 5,
#  'should_VERB': 1043,
#  'West_SUBST': 85,
#  'Third_ADJ': 20,
#  'Annual_ADJ': 8,
#  'Report_SUBST': 7,
#  'Published_VERB': 6,
#  'annual_ADJ': 44,
#  'report_SUBST': 74,
#  '1990/91_ADJ': 4,
#  'subtitled_VERB': 2,
#  'Bringing_VERB': 2,
#  'Home_ADV': 6,
#  'published_VERB': 96,
#  '21_ADJ': 34,
#  'Official_ADJ': 10,
#  'figures_SUBST': 48,
#  'suggest_VERB': 69,
#  'provided_VERB': 84,
#  'last_ADJ': 426,
#  '24,000_ADJ': 3,
#  'seen_VERB': 320,
#  'educators_SUBST': 6,
#  'Bulletin_SUBST': 2,
#  'shortly_ADV': 21,
#  'opening_VERB': 26,
#  'east_SUBST': 29,
#  'end_SUBST': 348,
#  'serve_VERB': 55,
#  'North_SUBST': 73,
#  'Nurse_VERB': 1,
#  'Kay_SUBST': 5,
#  'Hopps_SUBST': 2,
#  'responsibility_SUBST': 48,
#  'running_SUBST': 15,
#  'numbers_SUBST': 87,
#  'children_SUBST': 300,
#  'doubled_VERB': 10,
#  'based_VERB': 100,
#  'Portsmouth_SUBST': 10,
#  'move_VERB': 153,
#  'into_PREP': 1513,
#  'accommodation_SUBST': 19,
#  'July_SUBST': 47,
#  'Purchased_VERB': 1,
#  'Hampshire_SUBST': 11,
#  'Area_SUBST': 5,
#  'Authority_SUBST': 22,
#  'building_SUBST': 111,
#  'two_ADJ': 907,
#  'charities_SUBST': 7,
#  'caring_VERB': 12,
#  'growing_ADJ': 66,
#  'Coast_SUBST': 6,
#  'Brighton_SUBST': 21,
#  '24-page_ADJ': 1,
#  'colour_SUBST': 172,
#  'booklet_SUBST': 19,
#  'Choice_SUBST': 4,
#  'members_SUBST': 148,
#  'public_SUBST': 70,
#  'price_SUBST': 52,
#  '50p_SUBST': 4,
#  'each_ADJ': 493,
#  'Last_ADJ': 35,
#  'saw_VERB': 214,
#  '24,500_ADJ': 1,
#  'face_SUBST': 323,
#  'presentations_SUBST': 9,
#  'Conference_SUBST': 27,
#  'May_SUBST': 77,
#  'YMCA_SUBST': 2,
#  'both_ADV': 339,
#  'staff_SUBST': 113,
#  'Northern_SUBST': 44,
#  'Ireland_SUBST': 233,
#  'Romania_SUBST': 15,
#  'Uganda_SUBST': 16,
#  'organiser_SUBST': 4,
#  'Johnson_SUBST': 13,
#  'day_SUBST': 528,
#  'provided_CONJ': 24,
#  'reaffirmation_SUBST': 1,
#  'vision_SUBST': 61,
#  'marvellous_ADJ': 26,
#  'sense_SUBST': 285,
#  'unity_SUBST': 22,
#  'national_ADJ': 135,
#  'international_ADJ': 56,
#  'network_SUBST': 20,
#  'had_VERB': 3072,
#  'gathered_VERB': 25,
#  'place_SUBST': 484,
#  'made_VERB': 785,
#  'realise_VERB': 50,
#  'grown_VERB': 43,
#  'Three_ADJ': 38,
#  'visitors_SUBST': 28,
#  'Frankfurt_SUBST': 2,
#  'Germany_SUBST': 30,
#  'visited_VERB': 28,
#  'before_PREP': 304,
#  'returning_VERB': 21,
#  'begin_VERB': 80,
#  'similar_ADJ': 130,
#  'Help_SUBST': 9,
#  'CAH_SUBST': 2,
#  'Interest_SUBST': 4,
#  'expressed_VERB': 45,
#  'organisational_ADJ': 2,
#  'nursing_SUBST': 7,
#  'equipment_SUBST': 69,
#  'loans_SUBST': 10,
#  'programme_SUBST': 78,
#  'Like_PREP': 76,
#  'patients_SUBST': 45,
#  'Letters_SUBST': 12,
#  'Editor_SUBST': 7,
#  'welcome_ADJ': 21,
#  'Any_ADJ': 64,
#  'contributions_SUBST': 17,
#  'edited_VERB': 13,
#  'Please_ADV': 34,
#  'EDITOR_SUBST': 2,
#  'NEWSLETTER_SUBST': 1,
#  'P.O._SUBST': 5,
#  'BOX_SUBST': 3,
#  'LONDON_SUBST': 7,
#  'Be_VERB': 44,
#  'ACET-Link_SUBST': 2,
#  'Dear_ADJ': 28,
#  'Friend_SUBST': 5,
#  'As_PREP': 83,
#  'increases_VERB': 16,
#  'Over_PREP': 46,
#  'three_ADJ': 410,
#  'love_SUBST': 211,
#  'hurt_ADJ': 13,
#  'lonely_ADJ': 25,
#  'measured_VERB': 10,
#  'purely_ADV': 24,
#  'terms_SUBST': 186,
#  'continuing_ADJ': 34,
#  'contribution_SUBST': 24,
#  'vital_ADJ': 73,
#  'ongoing_ADJ': 4,
#  'recognition_SUBST': 41,
#  'importance_SUBST': 80,
#  'train_VERB': 44,
#  'more_ADJ': 659,
#  'want_VERB': 456,
#  'develop_VERB': 75,
#  'links_SUBST': 17,
#  'individual_ADJ': 102,
#  'To_PREP': 295,
#  'recruit_VERB': 4,
#  'willing_ADJ': 30,
#  'ACET-link_SUBST': 4,
#  'An_ART': 173,
#  'person_SUBST': 285,
#  'possibly_ADV': 46,
#  'about_PREP': 1616,
#  'consider_VERB': 79,
#  'fundraising_SUBST': 2,
#  'circulate_VERB': 2,
#  'newsletters_SUBST': 2,
#  'play_VERB': 107,
#  'role_SUBST': 124,
#  'growing_VERB': 57,
#  'rapidly_ADV': 29,
#  'Catlin/Peter_SUBST': 1,
#  'Glover_SUBST': 4,
#  'PO_SUBST': 13,
#  'Tear_SUBST': 4,
#  'Fund_SUBST': 36,
#  'Support_VERB': 3,
#  'Ugandan_ADJ': 6,
#  'Work_SUBST': 15,
#  'Anthony_SUBST': 14,
#  'Kasozi_SUBST': 3,
#  'uganda_SUBST': 1,
#  'received_VERB': 80,
#  'enabled_VERB': 12,
#  'him_PRON': 1214,
#  'General_ADJ': 27,
#  'Manager_SUBST': 25,
#  'Maurice_SUBST': 6,
#  'Adams_SUBST': 10,
#  'identify_VERB': 22,
#  'church-based_ADJ': 6,
#  'coming_ADJ': 5,
#  'These_ADJ': 222,
#  'pedal_VERB': 1,
#  'cycles_SUBST': 4,
#  'clinic_SUBST': 32,
#  'allowing_VERB': 39,
#  'nurses_SUBST': 20,
#  'outlying_ADJ': 4,
#  'villages_SUBST': 11,
#  'kits_SUBST': 7,
#  'homes_SUBST': 25,
#  'initiatives_SUBST': 3,
#  'Returning_VERB': 4,
#  'where_ADV': 411,
#  'he_PRON': 4246,
#  'met_VERB': 98,
#  'beautiful_ADJ': 85,
#  'devastated_VERB': 3,
#  'stopped_VERB': 90,
#  'population_SUBST': 55,
#  'general_ADJ': 155,
#  'educated_VERB': 11,
#  'thanks_SUBST': 26,
#  'Government_SUBST': 60,
#  'done_VERB': 320,
#  'raising_VERB': 24,
#  'awareness_SUBST': 51,
#  'here_ADV': 543,
#  'convince_VERB': 13,
#  'must_VERB': 769,
#  'change_VERB': 97,
#  'behaviour_SUBST': 109,
#  'because_CONJ': 712,
#  'own_VERB': 12,
#  'themselves_PRON': 216,
#  'way_SUBST': 878,
#  'great_ADJ': 356,
#  'deal_SUBST': 77,
#  'takes_VERB': 140,
#  'patron_SUBST': 8,
#  'Living_VERB': 4,
#  'John_SUBST': 192,
#  'Creedy_SUBST': 2,
#  'perfectly_ADV': 45,
#  'well_ADJ': 32,
#  'times_SUBST': 199,
#  'debility_SUBST': 5,
#  'makes_VERB': 178,
#  'hard_ADV': 84,
#  'basic_ADJ': 117,
#  'early_ADJ': 246,
#  ...}

# %% [markdown]
# # WORD AND TAG DISTRIBUTION IN THE CORPUS

# %%
word_f = {}
tag_f = {}

reader = open("train_data.txt", "r")

for line in reader:
    components = line.split("_")     # split the word_tag by '_'
    word_f[components[0]] = word_f.get(components[0], 0) + 1     # update word frequency
    tag_f[components[1].strip()] = tag_f.get(components[1].strip(), 0) + 1       # update tag frequency
    
reader.close()

# %%
# get the 10 most used words
sorted_word = sorted(word_f.items(), key = lambda x : x[1])
sorted_word.reverse()
sorted_word[:10]
# Out:
# [('the', 46249),
#  ('of', 25860),
#  ('to', 23320),
#  ('and', 22704),
#  ('a', 19111),
#  ('in', 14513),
#  ('is', 10777),
#  ('I', 8428),
#  ('that', 7996),
#  ('it', 7087)]

# %%
# get the 10 most used tags
sorted_tags = sorted(tag_f.items(), key = lambda x : x[1])
sorted_tags.reverse()
sorted_tags[:10]
# Out:
# [('SUBST', 211526),
#  ('VERB', 159864),
#  ('PREP', 110905),
#  ('ADJ', 98153),
#  ('ART', 76658),
#  ('PRON', 75307),
#  ('ADV', 59998),
#  ('CONJ', 51824),
#  ('UNC', 6664),
#  ('INTERJ', 1249)]

# %% [markdown]
# # COMPUTE PROBABILITIES

# %%
import numpy as np
