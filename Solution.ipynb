# %% [markdown]
# # PREPROCESSING

# %%
# import ElementTree to parse XML test corpus
import xml.etree.ElementTree as ET

# %%
# get all files in the Train-corpus folder
import glob
path = '/home/kaustubh/Dropbox/Sem5/AI/Assignments/Train-corups/*.xml'
files = glob.glob(path)

# %%
# open a file to write the cleaned data
writer = open("train_data.txt", "w+")

# iterate over all files
for file in files:
    
    # parse each XML file
    tree = ET.parse(file)
    root = tree.getroot()   
    
    # get w elements in the file
    for word in root.iter('w'):      
        writer.write("%s_%s\n" % (word.text.strip(), word.attrib['pos'].strip()))
        
writer.close()

# %% [markdown]
# # WORD+TAG FREQUENCY COUNT

# %%
freq = {}

reader = open("train_data.txt", "r")
for line in reader:
    freq[line.strip()] = freq.get(line.strip(), 0) + 1

reader.close()

# %%
freq
# Out:
# {'USING_VERB': 3,
#  'THE_ART': 219,
#  'RULES_SUBST': 1,
#  'TO_PREP': 49,
#  'HELP_VERB': 5,
#  'YOU_PRON': 26,
#  'WIN_VERB': 9,
#  'It_PRON': 2123,
#  'is_VERB': 10777,
#  'surprising_ADJ': 33,
#  'how_ADV': 822,
#  'many_ADJ': 693,
#  'people_SUBST': 1015,
#  'take_VERB': 583,
#  'part_SUBST': 464,
#  'in_PREP': 14009,
#  'competition_SUBST': 161,
#  'without_PREP': 463,
#  'knowing_VERB': 67,
#  'the_ART': 46249,
#  'rules_SUBST': 63,
#  'even_ADV': 833,
#  'at_PREP': 4222,
#  'élite_UNC': 24,
#  'level_SUBST': 156,
#  'This_ADJ': 1175,
#  'chapter_SUBST': 49,
#  'will_VERB': 2500,
#  'examine_VERB': 14,
#  'of_PREP': 25860,
#  'from_PREP': 3561,
#  'competitors_SUBST': 27,
#  "'_UNC": 431,
#  'point_SUBST': 345,
#  'view_SUBST': 206,
#  'rather_ADV': 390,
#  'than_CONJ': 1214,
#  'referees_SUBST': 11,
#  'show_VERB': 136,
#  'a_ART': 19068,
#  'knowledge_SUBST': 174,
#  'can_VERB': 2719,
#  'be_VERB': 6167,
#  'used_VERB': 432,
#  'to_PREP': 23319,
#  'help_VERB': 292,
#  'your_PRON': 2218,
#  'tournament_SUBST': 41,
#  'training_SUBST': 339,
#  'by_PREP': 3827,
#  'outlining_VERB': 5,
#  'following_ADJ': 101,
#  'kind_SUBST': 247,
#  'fitness_SUBST': 29,
#  'requirements_SUBST': 35,
#  'you_PRON': 6133,
#  'need_VERB': 465,
#  'most_ADV': 519,
#  'often_ADV': 468,
#  'scored_VERB': 15,
#  'techniques_SUBST': 73,
#  'explaining_VERB': 31,
#  'why_ADV': 316,
#  'they_PRON': 2697,
#  'failed_VERB': 54,
#  'score_VERB': 26,
#  'when_CONJ': 1239,
#  'felt_VERB': 245,
#  'should_VERB': 1043,
#  'have_VERB': 4154,
#  'injuries_SUBST': 21,
#  'are_VERB': 4697,
#  'dealt_VERB': 18,
#  'with_PREP': 5918,
#  'ensure_VERB': 72,
#  'that_CONJ': 5832,
#  'any_ADJ': 1056,
#  'complaint_SUBST': 9,
#  'make_VERB': 849,
#  'correctly_ADV': 39,
#  'The_ART': 5050,
#  'area_SUBST': 220,
#  'In_PREP': 1315,
#  'principle_SUBST': 55,
#  'this_ADJ': 3224,
#  '8m_SUBST': 5,
#  'x_PREP': 10,
#  '9.5yd_SUBST': 3,
#  'but_CONJ': 2700,
#  'practice_SUBST': 174,
#  'it_PRON': 7085,
#  'may_VERB': 1271,
#  'shrink_VERB': 2,
#  'only_ADV': 1101,
#  '7m_SUBST': 2,
#  '8.3yd_SUBST': 2,
#  'order_SUBST': 238,
#  'fit_VERB': 64,
#  'enough_ADJ': 86,
#  'areas_SUBST': 157,
#  'available_ADJ': 290,
#  'space_SUBST': 117,
#  'Many_ADJ': 123,
#  'organisers_SUBST': 10,
#  'miscalculate_VERB': 1,
#  'entry_SUBST': 45,
#  'levels_SUBST': 49,
#  'result_SUBST': 121,
#  'adjacent_ADJ': 18,
#  'crowded_VERB': 5,
#  'together_ADV': 299,
#  'and_CONJ': 22704,
#  'safety_SUBST': 62,
#  'imperilled_VERB': 1,
#  'Often_ADV': 23,
#  'run-off_SUBST': 1,
#  'zone_SUBST': 5,
#  'missing_VERB': 25,
#  'one_ADJ': 1479,
#  'metre_SUBST': 2,
#  'band_SUBST': 29,
#  'marked_VERB': 23,
#  'inside_PREP': 64,
#  'outer_ADJ': 12,
#  'perimeter_SUBST': 2,
#  'sometimes_ADV': 173,
#  'highlighted_VERB': 8,
#  'using_VERB': 211,
#  'different_ADJ': 415,
#  'coloured_ADJ': 24,
#  'mats_SUBST': 6,
#  'its_PRON': 1296,
#  'purpose_SUBST': 45,
#  'alert_VERB': 9,
#  'approach_VERB': 19,
#  'mat_SUBST': 15,
#  'boundary_SUBST': 26,
#  'Since_CONJ': 47,
#  'pick_VERB': 56,
#  'up_ADV': 1832,
#  'penalties_SUBST': 13,
#  'for_PREP': 6785,
#  'stepping_VERB': 18,
#  'out_ADV': 1887,
#  'inadvertently_ADV': 6,
#  'makes_VERB': 178,
#  'sense_SUBST': 285,
#  'get_VERB': 761,
#  'used_ADJ': 40,
#  'sparring_VERB': 2,
#  'competition-sized_ADJ': 1,
#  'square_SUBST': 20,
#  'very_ADV': 955,
#  'important_ADJ': 395,
#  'because_CONJ': 712,
#  'tactically-minded_ADJ': 1,
#  'competitor_SUBST': 19,
#  'crowd_VERB': 2,
#  'an_ART': 2974,
#  'inexperienced_ADJ': 31,
#  'opponent_SUBST': 295,
#  'picking_VERB': 17,
#  'points_SUBST': 67,
#  'exchanging_VERB': 3,
#  'technique_SUBST': 116,
#  'You_PRON': 1039,
#  'must_VERB': 769,
#  'always_ADV': 582,
#  'able_ADJ': 352,
#  'locate_VERB': 11,
#  'position_SUBST': 245,
#  'within_PREP': 254,
#  '8-metre_SUBST': 1,
#  'Normal_ADJ': 2,
#  'free-sparring_ADJ': 1,
#  'hall_SUBST': 38,
#  'limited_VERB': 29,
#  'number_SUBST': 297,
#  'there_ADV': 504,
#  'so_CONJ': 245,
#  'bad_ADJ': 136,
#  'habits_SUBST': 12,
#  'through_PREP': 607,
#  'uneconomically_ADV': 1,
#  'Therefore_ADV': 28,
#  'do_VERB': 2050,
#  'all_ADV': 225,
#  'final_ADJ': 126,
#  '8_ADJ': 42,
#  'm_SUBST': 8,
#  'x_SUBST': 29,
#  '9.5_ADJ': 3,
#  'yd_SUBST': 8,
#  'exactly_ADV': 88,
#  'where_CONJ': 359,
#  'Safety_SUBST': 15,
#  'Virtually_ADV': 1,
#  'all_ADJ': 2113,
#  'now_ADV': 987,
#  'takes_VERB': 140,
#  'place_SUBST': 484,
#  'on_PREP': 5038,
#  'since_CONJ': 162,
#  'hard_ADJ': 160,
#  'floors_SUBST': 7,
#  'known_VERB': 213,
#  'present_VERB': 39,
#  'hazard_SUBST': 14,
#  'falling_ADJ': 1,
#  'However_ADV': 281,
#  'themselves_PRON': 216,
#  'pose_VERB': 8,
#  'hazards_SUBST': 15,
#  'as_ADV': 482,
#  'well_ADJ': 32,
#  'if_CONJ': 1857,
#  'aware_ADJ': 133,
#  'these_ADJ': 817,
#  'Firstly_ADV': 10,
#  'modules_SUBST': 4,
#  'come_VERB': 526,
#  'apart_ADV': 87,
#  'referee_SUBST': 41,
#  'fails_VERB': 18,
#  'notice_VERB': 38,
#  'injured_VERB': 4,
#  'his_PRON': 3740,
#  'foot_SUBST': 185,
#  'slips_VERB': 5,
#  'into_PREP': 1513,
#  'gap_SUBST': 18,
#  'Broken_ADJ': 1,
#  'ankles_SUBST': 10,
#  'not_ADV': 4226,
#  'uncommon_ADJ': 10,
#  'karate_SUBST': 24,
#  'Secondly_ADV': 17,
#  'some_ADJ': 1351,
#  'sticky_ADJ': 18,
#  'preventing_VERB': 16,
#  'feet_SUBST': 186,
#  'sliding_VERB': 10,
#  'easily_ADV': 133,
#  'over_PREP': 511,
#  'them_PRON': 1584,
#  'throw_VERB': 40,
#  'roundhouse_SUBST': 42,
#  'kick_SUBST': 119,
#  'supporting_ADJ': 13,
#  'prevented_VERB': 23,
#  'swivelling_VERB': 1,
#  'Finally_ADV': 41,
#  'spongy_ADJ': 1,
#  'requiring_VERB': 11,
#  'lift_VERB': 42,
#  'well_ADV': 816,
#  'clear_ADJ': 204,
#  'before_PREP': 304,
#  'Obviously_ADV': 21,
#  'know_VERB': 862,
#  'advance_SUBST': 31,
#  'which_PRON': 3420,
#  'type_SUBST': 141,
#  'particular_ADJ': 236,
#  'just_ADV': 929,
#  'feel_SUBST': 15,
#  'then_ADV': 1236,
#  'try_VERB': 261,
#  'use_VERB': 296,
#  'free_ADJ': 213,
#  'time_SUBST': 1414,
#  'actual_ADJ': 50,
#  'little_ADJ': 457,
#  'beforehand_ADV': 12,
#  'Some_ADJ': 256,
#  'competitions_SUBST': 21,
#  'provide_VERB': 166,
#  'warm-up_SUBST': 4,
#  'matted_VERB': 1,
#  'same_ADJ': 500,
#  'material_SUBST': 115,
#  'as_CONJ': 3302,
#  'Check_VERB': 19,
#  'Get_VERB': 28,
#  'those_ADJ': 673,
#  'who_PRON': 1772,
#  'sit_VERB': 67,
#  'down_ADV': 798,
#  'so_ADV': 1538,
#  'emergency_SUBST': 29,
#  'services_SUBST': 134,
#  'across_PREP': 186,
#  'move_VERB': 153,
#  'quickly_ADV': 152,
#  'event_SUBST': 116,
#  'accident_SUBST': 52,
#  'such_ADJ': 948,
#  'as_PREP': 1759,
#  'pillars_SUBST': 4,
#  'radiators_SUBST': 7,
#  'chairs_SUBST': 26,
#  'or_CONJ': 4030,
#  'bags_SUBST': 18,
#  'near_PREP': 89,
#  'anything_PRON': 252,
#  'fact_SUBST': 290,
#  'that_ADJ': 2136,
#  'might_VERB': 501,
#  'cause_VERB': 71,
#  'injury_SUBST': 66,
#  'ploughed_VERB': 1,
#  'speed_SUBST': 172,
#  'Clothing_SUBST': 1,
#  'Ensure_VERB': 10,
#  'turned_VERB': 260,
#  'clean_ADJ': 48,
#  'white_ADJ': 195,
#  'karategi_SUBST': 3,
#  'open_ADJ': 140,
#  'tears_SUBST': 38,
#  'rips_SUBST': 2,
#  'Coloured_ADJ': 1,
#  'gis_SUBST': 1,
#  'black_ADJ': 168,
#  'edging_SUBST': 10,
#  'stripes_SUBST': 6,
#  'normally_ADV': 67,
#  'permitted_VERB': 14,
#  'sleeves_SUBST': 7,
#  'least_ADV': 337,
#  'mid-way_ADV': 7,
#  'forearm_SUBST': 15,
#  'folded_VERB': 12,
#  'lead_VERB': 60,
#  'Similarly_ADV': 19,
#  'trousers_SUBST': 27,
#  'shins_SUBST': 3,
#  'fraying_ADJ': 1,
#  'edges_SUBST': 26,
#  'whip_VERB': 2,
#  "'s_UNC": 3665,
#  'eyes_SUBST': 320,
#  'intend_VERB': 9,
#  'wear_VERB': 49,
#  'badge_SUBST': 7,
#  'being_VERB': 716,
#  'strictly_ADV': 9,
#  'interpreted_VERB': 22,
#  'single_ADJ': 116,
#  'national_ADJ': 135,
#  'association_SUBST': 43,
#  'identifying_ADJ': 1,
#  'red_SUBST': 31,
#  'belt_SUBST': 12,
#  'either_ADV': 180,
#  'normal_ADJ': 124,
#  'grade_SUBST': 6,
#  'addition_SUBST': 78,
#  'Japanese_ADJ': 17,
#  'word_SUBST': 181,
#  'aka_SUBST': 2,
#  'shiro_VERB': 1,
#  'Remember_VERB': 53,
#  'bearing_VERB': 11,
#  'mind_SUBST': 353,
#  'like_PREP': 1039,
#  'has_VERB': 2250,
#  'three_ADJ': 410,
#  'letters_SUBST': 78,
#  'while_CONJ': 360,
#  'shiro_ADJ': 1,
#  'five_ADJ': 148,
#  'colour_SUBST': 172,
#  'assigned_VERB': 7,
#  'arises_VERB': 15,
#  'draw_SUBST': 13,
#  'change_VERB': 97,
#  'round_SUBST': 22,
#  "n't_ADV": 2105,
#  'go_VERB': 646,
#  'went_VERB': 457,
#  'previously_ADV': 38,
#  'Make_VERB': 49,
#  'rule_SUBST': 40,
#  'check_VERB': 84,
#  'scorekeeper_SUBST': 2,
#  'going_VERB': 534,
#  'on_ADV': 814,
#  'times_SUBST': 199,
#  'wrong_ADJ': 164,
#  'name_SUBST': 209,
#  'gone_VERB': 176,
#  'forwards_ADV': 134,
#  'next_ADJ': 324,
#  'confused_VERB': 3,
#  'was_VERB': 6284,
#  'red_ADJ': 129,
#  'Take_VERB': 52,
#  'off_ADV': 490,
#  'after_CONJ': 120,
#  'leave_VERB': 158,
#  'wo_VERB': 95,
#  'stewards_SUBST': 2,
#  'chasing_VERB': 7,
#  'after_PREP': 605,
#  'Protective_ADJ': 2,
#  'equipment_SUBST': 69,
#  'fist_SUBST': 38,
#  'protectors_SUBST': 6,
#  'approved_ADJ': 8,
#  'These_ADJ': 222,
#  'centimetre_SUBST': 1,
#  'padding_SUBST': 2,
#  'thumb_SUBST': 14,
#  'fold_VERB': 7,
#  'in_ADV': 499,
#  'safely_ADV': 31,
#  'Always_ADV': 57,
#  'train_VERB': 44,
#  'mitts_SUBST': 3,
#  'additional_ADJ': 48,
#  'range_SUBST': 167,
#  'allow_VERB': 95,
#  'experience_VERB': 41,
#  'what_PRON': 1637,
#  'acceptable_ADJ': 27,
#  'impact_SUBST': 58,
#  'feels_VERB': 42,
#  'Never_ADV': 42,
#  'heavily_ADV': 42,
#  'padded_ADJ': 8,
#  'rely_VERB': 17,
#  'upon_PREP': 154,
#  'extra_ADJ': 103,
#  'cushioning_SUBST': 3,
#  'effect_SUBST': 170,
#  'version_SUBST': 67,
#  'shin/instep_SUBST': 3,
#  'early_ADV': 68,
#  'whether_CONJ': 221,
#  'allowed_VERB': 101,
#  'information_SUBST': 297,
#  'contained_VERB': 41,
#  'details_SUBST': 94,
#  'accompany_VERB': 12,
#  'application_SUBST': 45,
#  'form_SUBST': 260,
#  'If_CONJ': 899,
#  'missing_ADJ': 8,
#  'when_ADV': 315,
#  'contact_VERB': 63,
#  'organiser_SUBST': 4,
#  'find_VERB': 471,
#  'Then_ADV': 228,
#  'tailor_VERB': 1,
#  'accordingly_ADV': 11,
#  'Shin/instep_SUBST': 1,
#  'close_VERB': 33,
#  'velcro_SUBST': 1,
#  'more_ADV': 1246,
#  'tube_SUBST': 26,
#  'variety_SUBST': 96,
#  'greater_ADJ': 92,
#  'leeway_SUBST': 4,
#  'soon_ADV': 218,
#  'difference_SUBST': 101,
#  'sudden_ADJ': 43,
#  'switch_SUBST': 6,
#  'between_PREP': 721,
#  'two_ADJ': 907,
#  'Although_CONJ': 82,
#  'groin_SUBST': 12,
#  'guards_SUBST': 8,
#  'mandatory_ADJ': 4,
#  'male_ADJ': 31,
#  'no_ART': 1261,
#  'way_SUBST': 878,
#  'checking_VERB': 26,
#  'worn_VERB': 23,
#  'receive_VERB': 82,
#  'discovered_VERB': 55,
#  'wearing_VERB': 39,
#  'guard_SUBST': 59,
#  'automatically_ADV': 25,
#  'disqualified_VERB': 7,
#  'regardless_ADV': 25,
#  'whose_PRON': 212,
#  'fault_SUBST': 38,
#  'low_ADJ': 169,
#  'Do_VERB': 291,
#  'plastic_SUBST': 52,
#  'cups_SUBST': 16,
#  'slip_VERB': 13,
#  'inside_ADV': 56,
#  'jock_VERB': 1,
#  'straps_SUBST': 4,
#  'Not_ADV': 260,
#  'shatter_VERB': 2,
#  'been_VERB': 1905,
#  'nip_VERB': 3,
#  'parts_SUBST': 105,
#  'straying_VERB': 2,
#  'outside_ADV': 59,
#  'incoming_ADJ': 15,
#  'struck_VERB': 29,
#  'home_ADV': 143,
#  'Buy_VERB': 5,
#  'boxing-type_ADJ': 1,
#  'instead_ADV': 90,
#  'Female_ADJ': 3,
#  'contestants_SUBST': 15,
#  'advised_VERB': 17,
#  'sanitary_ADJ': 1,
#  'towel_SUBST': 11,
#  'protect_VERB': 45,
#  'perineum_SUBST': 1,
#  'I_PRON': 8385,
#  'never_ADV': 619,
#  'arise_VERB': 25,
#  'breasts_SUBST': 28,
#  'more_ADJ': 659,
#  'their_PRON': 2079,
#  'fair_ADJ': 68,
#  'share_SUBST': 12,
#  'impacts_SUBST': 6,
#  'both_ADV': 339,
#  'during_PREP': 326,
#  'close_ADJ': 122,
#  'frequently_ADV': 81,
#  'attacked_VERB': 16,
#  'scoring_VERB': 8,
#  'less_ADV': 249,
#  'protected_VERB': 23,
#  'follows_VERB': 48,
#  'chest_SUBST': 72,
#  'ought_VERB': 34,
#  'compulsory_ADJ': 6,
#  'female_ADJ': 30,
#  'shields_SUBST': 4,
#  'cover_VERB': 57,
#  'am_VERB': 326,
#  'happy_ADJ': 79,
#  'seen_VERB': 320,
#  'would_VERB': 1743,
#  'advise_VERB': 46,
#  'buy_VERB': 63,
#  'World_SUBST': 138,
#  'Taekwondo_SUBST': 1,
#  'Federation_SUBST': 32,
#  'WTF_SUBST': 1,
#  'jacket_SUBST': 31,
#  'sparring_SUBST': 2,
#  'much_ADV': 350,
#  'effective_ADJ': 125,
#  'muting_VERB': 1,
#  'breast_SUBST': 27,
#  'shield_SUBST': 2,
#  'though_CONJ': 437,
#  'proper_ADJ': 57,
#  'removes_VERB': 4,
#  'much_ADJ': 457,
#  'risk_SUBST': 98,
#  'pre-competition_ADJ': 1,
#  'firm_ADJ': 32,
#  'bra_SUBST': 5,
#  'means_SUBST': 109,
#  'protection_SUBST': 49,
#  'does_VERB': 575,
#  'hold_VERB': 125,
#  'ca_VERB': 183,
#  'freely_ADV': 17,
#  'under_PREP': 437,
#  'my_PRON': 1813,
#  'bras_SUBST': 1,
#  'capable_ADJ': 36,
#  'causing_VERB': 37,
#  'damage_SUBST': 68,
#  'trapping_VERB': 2,
#  'tissue_SUBST': 10,
#  'rib_SUBST': 3,
#  'cage_SUBST': 4,
#  'blow_SUBST': 14,
#  'Choose_VERB': 20,
#  'feel_VERB': 305,
#  'best_ADV': 77,
#  'suits_VERB': 9,
#  'become_VERB': 275,
#  'use_SUBST': 239,
#  'constrictions_SUBST': 1,
#  'causes_VERB': 35,
#  'also_ADV': 1042,
#  'plain_ADJ': 23,
#  'T-shirt_SUBST': 3,
#  'beneath_PREP': 36,
#  'jackets_SUBST': 1,
#  'Spectacles_SUBST': 1,
#  'see_VERB': 847,
#  'enough_ADV': 281,
#  'want_VERB': 456,
#  'compete_VERB': 24,
#  'anyway_ADV': 76,
#  'pair_SUBST': 46,
#  'soft_ADJ': 64,
#  'contact_SUBST': 70,
#  'lenses_SUBST': 4,
#  'manage_VERB': 53,
#  'glasses_SUBST': 39,
#  'Contact_VERB': 9,
#  'lost_ADJ': 26,
#  'bear_VERB': 45,
#  'before_CONJ': 254,
#  'spend_VERB': 51,
#  'hefty_ADJ': 5,
#  'sum_SUBST': 26,
#  'about_PREP': 1616,
#  'landing_VERB': 29,
#  'controlled_ADJ': 10,
#  'shortsighted_ADJ': 1,
#  'danger_SUBST': 42,
#  'opponents_SUBST': 13,
#  'sweatband_SUBST': 1,
#  'jewellery_SUBST': 5,
#  'earrings_SUBST': 8,
#  'necklaces_SUBST': 1,
#  'bracelets_SUBST': 3,
#  'rings_SUBST': 8,
#  'Smooth_ADJ': 1,
#  'removed_VERB': 45,
#  'taped_VERB': 3,
#  'over_ADV': 475,
#  'remove_VERB': 33,
#  'otherwise_ADV': 66,
#  'dangerous_ADJ': 81,
#  'ring_SUBST': 30,
#  'opinion_SUBST': 49,
#  'disbarred_VERB': 3,
#  'Sikh_ADJ': 1,
#  'prior_ADJ': 28,
#  'Chief_ADJ': 12,
#  'Referee_SUBST': 3,
#  'modified_ADJ': 6,
#  'ritual_ADJ': 9,
#  'headgear_SUBST': 2,
#  'Long_ADJ': 7,
#  'hair_SUBST': 172,
#  'held_VERB': 223,
#  'back_ADV': 748,
#  'elastic_ADJ': 1,
#  'clasps_SUBST': 1,
#  'metal_SUBST': 24,
#  'grips_SUBST': 4,
#  'fingernails_SUBST': 4,
#  'toenails_SUBST': 3,
#  'cut_VERB': 120,
#  'short_ADV': 7,
#  'Organization_SUBST': 3,
#  'Sparring_VERB': 1,
#  'divided_VERB': 34,
#  'categories_SUBST': 26,
#  'Men_SUBST': 19,
#  'Senior_ADJ': 12,
#  '21_ADJ': 34,
#  'years_SUBST': 677,
#  'age_SUBST': 146,
#  'day_SUBST': 528,
#  'Women_SUBST': 35,
#  '18_ADJ': 29,
#  'junior_ADJ': 11,
#  'below_ADV': 73,
#  'Male_ADJ': 4,
#  'Cadets_SUBST': 1,
#  '16_ADJ': 36,
#  'Juniors_SUBST': 1,
#  'fight_VERB': 38,
#  'associations_SUBST': 13,
#  '12_ADJ': 55,
#  'year_SUBST': 478,
#  'olds_SUBST': 2,
#  'Coaches_SUBST': 2,
#  'generally_ADV': 79,
#  'asked_VERB': 328,
#  'give_VERB': 425,
#  'undertaking_SUBST': 5,
#  'entries_SUBST': 26,
#  'comply_VERB': 5,
#  'ceilings_SUBST': 4,
#  'subsequently_ADV': 26,
#  'challenged_VERB': 11,
#  'found_VERB': 401,
#  'wanting_ADJ': 4,
#  'entire_ADJ': 41,
#  'titles_SUBST': 23,
#  'won_VERB': 66,
#  'forfeited_VERB': 1,
#  'International_ADJ': 66,
#  'requires_VERB': 49,
#  'passport_SUBST': 7,
#  'date_SUBST': 64,
#  'birth_SUBST': 57,
#  'eliminates_VERB': 2,
#  'ineligible_ADJ': 1,
#  'grounds_SUBST': 44,
#  'shows_VERB': 75,
#  'citizen_SUBST': 9,
#  'country_SUBST': 238,
#  'he_PRON': 4246,
#  'represents_VERB': 30,
#  'karateka_SUBST': 8,
#  'travelled_VERB': 10,
#  'international_ADJ': 56,
#  'took_VERB': 303,
#  'passports_SUBST': 4,
#  'Team_SUBST': 11,
#  'events_SUBST': 132,
#  'There_PRON': 737,
#  'team_SUBST': 91,
#  'individual_ADJ': 102,
#  'teams_SUBST': 20,
#  'consist_VERB': 10,
#  'plus_PREP': 33,
#  'reserve_SUBST': 7,
#  'comprise_VERB': 4,
#  'reserves_SUBST': 2,
#  'sizes_SUBST': 18,
#  'varied_VERB': 15,
#  'made_VERB': 785,
#  'odd_ADJ': 29,
#  'Fighting_VERB': 2,
#  'Before_CONJ': 19,
#  'each_ADJ': 493,
#  'match_VERB': 12,
#  'representative_SUBST': 13,
#  'hand_SUBST': 374,
#  'list_SUBST': 86,
#  'specifying_VERB': 2,
#  'submitted_VERB': 22,
#  'earlier_ADJ': 52,
#  'rounds_SUBST': 10,
#  'deemed_VERB': 11,
#  'still_ADV': 576,
#  'apply_VERB': 74,
#  'something_PRON': 514,
#  'lightly_ADV': 19,
#  'field_VERB': 3,
#  'described_VERB': 123,
#  'new_ADJ': 702,
#  'notice_SUBST': 22,
#  'fighting_SUBST': 13,
#  'Reserves_SUBST': 1,
#  'substituted_VERB': 2,
#  'discretion_SUBST': 5,
#  'coach_SUBST': 48,
#  'Generally_ADV': 8,
#  'best_ADJ': 312,
#  'send_VERB': 73,
#  'strong_ADJ': 166,
#  'opener_SUBST': 2,
#  'someone_PRON': 250,
#  'relied_VERB': 8,
#  'victory_SUBST': 14,
#  'lifts_VERB': 4,
#  'morale_SUBST': 6,
#  'encourages_VERB': 13,
#  'line_SUBST': 159,
#  'member_SUBST': 72,
#  'suspect_VERB': 25,
#  'put_VERB': 408,
#  'third_ADJ': 101,
#  'With_PREP': 152,
#  'wins_VERB': 13,
#  'already_ADV': 273,
#  'gained_VERB': 21,
#  'performers_SUBST': 11,
#  'middle_ADJ': 33,
#  'ideally_ADV': 6,
#  'suited_VERB': 26,
#  'weakest_ADJ': 3,
#  'last_ADJ': 426,
#  'called_VERB': 245,
#  'save_VERB': 44,
#  'keep_VERB': 281,
#  'good_ADJ': 709,
#  'finisher_SUBST': 1,
#  'Such_ADJ': 71,
#  'lagging_SUBST': 1,
#  'Each_ADJ': 70,
#  'short-handed_ADJ': 1,
#  'chance_SUBST': 131,
#  'win_VERB': 63,
#  'match_SUBST': 34,
#  'therefore_ADV': 156,
#  'meaningful_ADJ': 11,
#  'A_ART': 1055,
#  'successful_ADJ': 67,
#  'fights_SUBST': 3,
#  'course_SUBST': 429,
#  'unusual_ADJ': 43,
#  'short-handed_ADV': 1,
#  'stages_SUBST': 28,
#  'tempted_VERB': 15,
#  'forfeit_VERB': 1,
#  'bouts_SUBST': 13,
#  'bout_SUBST': 40,
#  'deciding_ADJ': 4,
#  'first_ADJ': 953,
#  'three/two_ADJ': 1,
#  'victories_SUBST': 3,
#  'opposing_ADJ': 10,
#  'winning_VERB': 28,
#  'attempt_SUBST': 68,
#  'withdraw_VERB': 15,
#  'remaining_ADJ': 30,
#  'team-member(s)_SUBST': 1,
#  'rewarded_VERB': 4,
#  'disqualification_SUBST': 5,
#  'sportsmanship_SUBST': 1,
#  'Sometimes_ADV': 59,
#  'delayed_VERB': 11,
#  'things_SUBST': 400,
#  'happen_VERB': 81,
#  'fast_ADV': 30,
#  'Should_VERB': 21,
#  'occur_VERB': 68,
#  'relaxing_VERB': 9,
#  'itself_PRON': 277,
#  'earshot_SUBST': 1,
#  'vital_ADJ': 73,
#  'nominates_VERB': 2,
#  'observer_SUBST': 17,
#  'monitor_VERB': 7,
#  'happening_VERB': 57,
#  'arena_SUBST': 10,
#  'Otherwise_ADV': 20,
#  'public_ADJ': 169,
#  'announcements_SUBST': 4,
#  'Any_ADJ': 64,
#  'withdraws_VERB': 2,
#  'short_ADJ': 179,
#  'whole_SUBST': 86,
#  'cancelled_VERB': 5,
#  'arrives_VERB': 10,
#  'venue_SUBST': 7,
#  'sufficient_ADJ': 47,
#  'register_VERB': 13,
#  'weigh-in_SUBST': 1,
#  'face_VERB': 76,
#  'unexpected_ADJ': 22,
#  'travel_SUBST': 19,
#  'delays_SUBST': 3,
#  'arrive_VERB': 38,
#  'progressed_VERB': 6,
#  'beyond_PREP': 98,
#  'Important_ADJ': 3,
#  'preparation_SUBST': 33,
#  'adequate_ADJ': 35,
#  'rest_SUBST': 154,
#  'night_SUBST': 258,
#  'before_ADV': 126,
#  'duty_SUBST': 46,
#  'arriving_VERB': 17,
#  'hold_SUBST': 22,
#  'current_ADJ': 74,
#  'sheet_SUBST': 33,
#  'identify_VERB': 22,
#  'competing_ADJ': 4,
#  'confirm_VERB': 14,
#  'timetable_SUBST': 3,
#  'Weight_SUBST': 4,
#  'Individual_ADJ': 3,
#  'fought_VERB': 22,
#  'weight_SUBST': 115,
#  '60_ADJ': 37,
#  'kilos_SUBST': 10,
#  '65_ADJ': 11,
#  '70_ADJ': 21,
#  '53_ADJ': 1,
#  '75_ADJ': 11,
#  '80_ADJ': 14,
#  '+_UNC': 8,
#  '+60_ADJ': 1,
#  'Open_ADJ': 24,
#  'Min._SUBST': 1,
#  '43_ADJ': 5,
#  'individuals_SUBST': 47,
#  'closely_ADV': 28,
#  'matched_VERB': 11,
#  'kilo_SUBST': 4,
#  'male_SUBST': 10,
#  '+90_ADJ': 1,
#  'category_SUBST': 27,
#  'outcome_SUBST': 17,
#  'pretty_ADJ': 22,
#  'My_PRON': 205,
#  'advice_SUBST': 159,
#  'lightweights_SUBST': 1,
#  'consider_VERB': 79,
#  'heavyweights_SUBST': 1,
#  'great_ADJ': 356,
#  'advantage_SUBST': 55,
#  'forget_VERB': 62,
#  'glass_SUBST': 370,
#  'water_SUBST': 204,
#  'tip_VERB': 5,
#  'At_PREP': 325,
#  'every_ART': 361,
#  'working_VERB': 170,
#  'hard_ADV': 84,
#  'sweat_VERB': 3,
#  'off_PREP': 164,
#  're-weigh_SUBST': 1,
#  'Usually_ADV': 29,
#  'lost_VERB': 125,
#  'totally_ADV': 46,
#  'fatigued_VERB': 1,
#  'An_ART': 173,
#  'diuretic_SUBST': 1,
#  'reduce_VERB': 69,
#  'constitutes_VERB': 16,
#  'drug-taking_SUBST': 5,
#  'lifetime_SUBST': 15,
#  'ban_SUBST': 11,
#  'few_ADJ': 435,
#  'grams_SUBST': 1,
#  'legitimately_ADV': 2,
#  'shed_VERB': 8,
#  'stripping_VERB': 4,
#  'undershorts_SUBST': 1,
#  'T_SUBST': 10,
#  'shirts_SUBST': 18,
#  'weighs_VERB': 3,
#  'accurate_ADJ': 37,
#  'scales_SUBST': 7,
#  'warns_VERB': 8,
#  'marginals_SUBST': 2,
#  'care_SUBST': 206,
#  'Normally_ADV': 7,
#  're-weigh_VERB': 1,
#  'another_ADJ': 507,
#  'set_SUBST': 88,
#  'believe_VERB': 175,
#  'reading_VERB': 67,
#  'heavy_ADJ': 101,
#  'Documentation_SUBST': 1,
#  'bring_VERB': 135,
#  'required_ADJ': 9,
#  'documentation_SUBST': 6,
#  'For_PREP': 420,
#  'example_SUBST': 302,
#  'British_ADJ': 267,
#  'require_VERB': 46,
#  'produce_VERB': 111,
#  'Martial_ADJ': 4,
#  'Arts_SUBST': 33,
#  'Commission_SUBST': 28,
#  'licence_SUBST': 12,
#  'faces_SUBST': 63,
#  'sidelined_VERB': 1,
#  'forgetting_VERB': 11,
#  'requirement_SUBST': 18,
#  'properly_ADV': 54,
#  'prepared_VERB': 46,
#  'unissued_ADJ': 1,
#  'licences_SUBST': 1,
#  'along_ADV': 119,
#  'forgotten_VERB': 40,
#  'theirs_PRON': 13,
#  'contest_SUBST': 9,
#  'Karate_SUBST': 3,
#  'two-minute_ADJ': 1,
#  'extended_VERB': 19,
#  'minutes_SUBST': 110,
#  'taken_VERB': 261,
#  'pauses_SUBST': 2,
#  'counted_VERB': 14,
#  'defines_VERB': 7,
#  'extent_SUBST': 41,
#  'stamina_SUBST': 9,
#  'programme_SUBST': 78,
#  'develop_VERB': 75,
#  'maintaining_VERB': 16,
#  'relentless_ADJ': 1,
#  'powerful_ADJ': 84,
#  'onslaught_SUBST': 4,
#  'whole_ADJ': 201,
#  'Aim_VERB': 5,
#  'margin_SUBST': 46,
#  'allowing_VERB': 39,
#  'further_ADJ': 163,
#  'death_SUBST': 196,
#  'extension_SUBST': 25,
#  'there_PRON': 1499,
#  'pause_SUBST': 20,
#  'minute_SUBST': 51,
#  'successive_ADJ': 12,
#  'Bout_SUBST': 1,
#  'bell_SUBST': 33,
#  'hear_VERB': 102,
#  '30_ADJ': 61,
#  'seconds_SUBST': 56,
#  'warning_SUBST': 26,
#  ...}

# %% [markdown]
# # WORD AND TAG DISTRIBUTION IN THE CORPUS

# %%
word_f = {}
tag_f = {}

reader = open("train_data.txt", "r")

for line in reader:
    components = line.split("_")     # split the word_tag by '_'
    word_f[components[0]] = word_f.get(components[0], 0) + 1     # update word frequency
    tag_f[components[1].strip()] = tag_f.get(components[1].strip(), 0) + 1       # update tag frequency
    
reader.close()

# %%
# get the 10 most used words
sorted_word = sorted(word_f.items(), key = lambda x : x[1])
sorted_word.reverse()
sorted_word[:10]
# Out:
# [('the', 46249),
#  ('of', 25860),
#  ('to', 23320),
#  ('and', 22704),
#  ('a', 19111),
#  ('in', 14513),
#  ('is', 10777),
#  ('I', 8428),
#  ('that', 7996),
#  ('it', 7087)]

# %%
# get the 10 most used tags
sorted_tags = sorted(tag_f.items(), key = lambda x : x[1])
sorted_tags.reverse()
sorted_tags[:10]
# Out:
# [('SUBST', 211526),
#  ('VERB', 159864),
#  ('PREP', 110905),
#  ('ADJ', 98153),
#  ('ART', 76658),
#  ('PRON', 75307),
#  ('ADV', 59998),
#  ('CONJ', 51824),
#  ('UNC', 6664),
#  ('INTERJ', 1249)]

# %% [markdown]
# # COMPUTE PROBABILITIES

# %%
probab_w_t = {}

for key in freq:
    components = key.split("_")
    probab_w_t[key] = freq.get(key)/word_f.get(components[0])
    
probab_w_t
# Out:
# {'USING_VERB': 1.0,
#  'THE_ART': 1.0,
#  'RULES_SUBST': 1.0,
#  'TO_PREP': 1.0,
#  'HELP_VERB': 0.29411764705882354,
#  'YOU_PRON': 1.0,
#  'WIN_VERB': 1.0,
#  'It_PRON': 0.9976503759398496,
#  'is_VERB': 1.0,
#  'surprising_ADJ': 1.0,
#  'how_ADV': 1.0,
#  'many_ADJ': 1.0,
#  'people_SUBST': 1.0,
#  'take_VERB': 0.9965811965811966,
#  'part_SUBST': 0.9957081545064378,
#  'in_PREP': 0.9652725142975264,
#  'competition_SUBST': 1.0,
#  'without_PREP': 0.9935622317596566,
#  'knowing_VERB': 0.9054054054054054,
#  'the_ART': 1.0,
#  'rules_SUBST': 0.984375,
#  'even_ADV': 0.995221027479092,
#  'at_PREP': 1.0,
#  'élite_UNC': 1.0,
#  'level_SUBST': 0.8524590163934426,
#  'This_ADJ': 0.9991496598639455,
#  'chapter_SUBST': 1.0,
#  'will_VERB': 0.9819324430479183,
#  'examine_VERB': 1.0,
#  'of_PREP': 1.0,
#  'from_PREP': 1.0,
#  'competitors_SUBST': 1.0,
#  "'_UNC": 1.0,
#  'point_SUBST': 0.905511811023622,
#  'view_SUBST': 0.9279279279279279,
#  'rather_ADV': 1.0,
#  'than_CONJ': 1.0,
#  'referees_SUBST': 1.0,
#  'show_VERB': 0.6445497630331753,
#  'a_ART': 0.9977499869185286,
#  'knowledge_SUBST': 1.0,
#  'can_VERB': 0.9956060051263274,
#  'be_VERB': 1.0,
#  'used_VERB': 0.9152542372881356,
#  'to_PREP': 0.9999571183533448,
#  'help_VERB': 0.5971370143149284,
#  'your_PRON': 1.0,
#  'tournament_SUBST': 1.0,
#  'training_SUBST': 0.9416666666666667,
#  'by_PREP': 0.9917076962943768,
#  'outlining_VERB': 1.0,
#  'following_ADJ': 0.6047904191616766,
#  'kind_SUBST': 0.9686274509803922,
#  'fitness_SUBST': 1.0,
#  'requirements_SUBST': 1.0,
#  'you_PRON': 1.0,
#  'need_VERB': 0.7610474631751227,
#  'most_ADV': 0.6423267326732673,
#  'often_ADV': 1.0,
#  'scored_VERB': 1.0,
#  'techniques_SUBST': 1.0,
#  'explaining_VERB': 1.0,
#  'why_ADV': 1.0,
#  'they_PRON': 1.0,
#  'failed_VERB': 0.9310344827586207,
#  'score_VERB': 0.41935483870967744,
#  'when_CONJ': 0.7972972972972973,
#  'felt_VERB': 0.9879032258064516,
#  'should_VERB': 1.0,
#  'have_VERB': 1.0,
#  'injuries_SUBST': 1.0,
#  'are_VERB': 1.0,
#  'dealt_VERB': 1.0,
#  'with_PREP': 1.0,
#  'ensure_VERB': 1.0,
#  'that_CONJ': 0.7293646823411706,
#  'any_ADJ': 0.9768732654949122,
#  'complaint_SUBST': 1.0,
#  'make_VERB': 0.9941451990632318,
#  'correctly_ADV': 1.0,
#  'The_ART': 1.0,
#  'area_SUBST': 1.0,
#  'In_PREP': 0.9984813971146546,
#  'principle_SUBST': 1.0,
#  'this_ADJ': 0.9978334880841845,
#  '8m_SUBST': 1.0,
#  'x_PREP': 0.23255813953488372,
#  '9.5yd_SUBST': 1.0,
#  'but_CONJ': 0.9861212563915267,
#  'practice_SUBST': 0.9942857142857143,
#  'it_PRON': 0.9997177931423734,
#  'may_VERB': 1.0,
#  'shrink_VERB': 1.0,
#  'only_ADV': 0.8772908366533865,
#  '7m_SUBST': 1.0,
#  '8.3yd_SUBST': 1.0,
#  'order_SUBST': 0.9596774193548387,
#  'fit_VERB': 0.6464646464646465,
#  'enough_ADJ': 0.23433242506811988,
#  'areas_SUBST': 1.0,
#  'available_ADJ': 1.0,
#  'space_SUBST': 0.9831932773109243,
#  'Many_ADJ': 1.0,
#  'organisers_SUBST': 1.0,
#  'miscalculate_VERB': 1.0,
#  'entry_SUBST': 1.0,
#  'levels_SUBST': 1.0,
#  'result_SUBST': 0.6994219653179191,
#  'adjacent_ADJ': 1.0,
#  'crowded_VERB': 0.3333333333333333,
#  'together_ADV': 1.0,
#  'and_CONJ': 1.0,
#  'safety_SUBST': 1.0,
#  'imperilled_VERB': 1.0,
#  'Often_ADV': 1.0,
#  'run-off_SUBST': 1.0,
#  'zone_SUBST': 1.0,
#  'missing_VERB': 0.7575757575757576,
#  'one_ADJ': 0.6334047109207709,
#  'metre_SUBST': 1.0,
#  'band_SUBST': 1.0,
#  'marked_VERB': 0.6571428571428571,
#  'inside_PREP': 0.4383561643835616,
#  'outer_ADJ': 1.0,
#  'perimeter_SUBST': 1.0,
#  'sometimes_ADV': 1.0,
#  'highlighted_VERB': 1.0,
#  'using_VERB': 1.0,
#  'different_ADJ': 1.0,
#  'coloured_ADJ': 0.8275862068965517,
#  'mats_SUBST': 1.0,
#  'its_PRON': 1.0,
#  'purpose_SUBST': 1.0,
#  'alert_VERB': 0.391304347826087,
#  'approach_VERB': 0.13970588235294118,
#  'mat_SUBST': 1.0,
#  'boundary_SUBST': 1.0,
#  'Since_CONJ': 0.6527777777777778,
#  'pick_VERB': 0.9491525423728814,
#  'up_ADV': 0.9693121693121693,
#  'penalties_SUBST': 1.0,
#  'for_PREP': 0.9710891655932447,
#  'stepping_VERB': 1.0,
#  'out_ADV': 0.9963041182682154,
#  'inadvertently_ADV': 1.0,
#  'makes_VERB': 0.9834254143646409,
#  'sense_SUBST': 0.976027397260274,
#  'get_VERB': 1.0,
#  'used_ADJ': 0.0847457627118644,
#  'sparring_VERB': 0.5,
#  'competition-sized_ADJ': 1.0,
#  'square_SUBST': 0.5263157894736842,
#  'very_ADV': 0.9253875968992248,
#  'important_ADJ': 1.0,
#  'because_CONJ': 1.0,
#  'tactically-minded_ADJ': 1.0,
#  'competitor_SUBST': 1.0,
#  'crowd_VERB': 0.024390243902439025,
#  'an_ART': 1.0,
#  'inexperienced_ADJ': 1.0,
#  'opponent_SUBST': 1.0,
#  'picking_VERB': 1.0,
#  'points_SUBST': 0.7204301075268817,
#  'exchanging_VERB': 1.0,
#  'technique_SUBST': 1.0,
#  'You_PRON': 1.0,
#  'must_VERB': 0.9974059662775616,
#  'always_ADV': 1.0,
#  'able_ADJ': 1.0,
#  'locate_VERB': 1.0,
#  'position_SUBST': 0.9839357429718876,
#  'within_PREP': 0.9202898550724637,
#  '8-metre_SUBST': 1.0,
#  'Normal_ADJ': 1.0,
#  'free-sparring_ADJ': 1.0,
#  'hall_SUBST': 1.0,
#  'limited_VERB': 0.4142857142857143,
#  'number_SUBST': 0.9966442953020134,
#  'there_ADV': 0.25162256615077383,
#  'so_CONJ': 0.13740886146943354,
#  'bad_ADJ': 0.9855072463768116,
#  'habits_SUBST': 1.0,
#  'through_PREP': 0.8708751793400287,
#  'uneconomically_ADV': 1.0,
#  'Therefore_ADV': 1.0,
#  'do_VERB': 0.9985387238188017,
#  'all_ADV': 0.0962360992301112,
#  'final_ADJ': 0.8129032258064516,
#  '8_ADJ': 1.0,
#  'm_SUBST': 1.0,
#  'x_SUBST': 0.6744186046511628,
#  '9.5_ADJ': 1.0,
#  'yd_SUBST': 0.7272727272727273,
#  'exactly_ADV': 1.0,
#  'where_CONJ': 0.4662337662337662,
#  'Safety_SUBST': 1.0,
#  'Virtually_ADV': 1.0,
#  'all_ADJ': 0.9037639007698888,
#  'now_ADV': 0.9989878542510121,
#  'takes_VERB': 0.9929078014184397,
#  'place_SUBST': 0.9434697855750487,
#  'on_PREP': 0.8609022556390977,
#  'since_CONJ': 0.5912408759124088,
#  'hard_ADJ': 0.6530612244897959,
#  'floors_SUBST': 1.0,
#  'known_VERB': 0.9424778761061947,
#  'present_VERB': 0.20526315789473684,
#  'hazard_SUBST': 1.0,
#  'falling_ADJ': 0.03125,
#  'However_ADV': 1.0,
#  'themselves_PRON': 1.0,
#  'pose_VERB': 0.5,
#  'hazards_SUBST': 1.0,
#  'as_ADV': 0.08695652173913043,
#  'well_ADJ': 0.03773584905660377,
#  'if_CONJ': 1.0,
#  'aware_ADJ': 1.0,
#  'these_ADJ': 1.0,
#  'Firstly_ADV': 1.0,
#  'modules_SUBST': 1.0,
#  'come_VERB': 1.0,
#  'apart_ADV': 1.0,
#  'referee_SUBST': 1.0,
#  'fails_VERB': 1.0,
#  'notice_VERB': 0.6333333333333333,
#  'injured_VERB': 0.2857142857142857,
#  'his_PRON': 1.0,
#  'foot_SUBST': 0.9893048128342246,
#  'slips_VERB': 0.7142857142857143,
#  'into_PREP': 1.0,
#  'gap_SUBST': 1.0,
#  'Broken_ADJ': 0.5,
#  'ankles_SUBST': 1.0,
#  'not_ADV': 1.0,
#  'uncommon_ADJ': 1.0,
#  'karate_SUBST': 1.0,
#  'Secondly_ADV': 1.0,
#  'some_ADJ': 1.0,
#  'sticky_ADJ': 1.0,
#  'preventing_VERB': 1.0,
#  'feet_SUBST': 1.0,
#  'sliding_VERB': 0.6666666666666666,
#  'easily_ADV': 1.0,
#  'over_PREP': 0.5182555780933062,
#  'them_PRON': 1.0,
#  'throw_VERB': 0.975609756097561,
#  'roundhouse_SUBST': 1.0,
#  'kick_SUBST': 0.8623188405797102,
#  'supporting_ADJ': 0.5652173913043478,
#  'prevented_VERB': 1.0,
#  'swivelling_VERB': 1.0,
#  'Finally_ADV': 1.0,
#  'spongy_ADJ': 1.0,
#  'requiring_VERB': 1.0,
#  'lift_VERB': 0.3684210526315789,
#  'well_ADV': 0.9622641509433962,
#  'clear_ADJ': 0.8869565217391304,
#  'before_PREP': 0.4444444444444444,
#  'Obviously_ADV': 1.0,
#  'know_VERB': 1.0,
#  'advance_SUBST': 0.7045454545454546,
#  'which_PRON': 1.0,
#  'type_SUBST': 0.9724137931034482,
#  'particular_ADJ': 0.9915966386554622,
#  'just_ADV': 0.9841101694915254,
#  'feel_SUBST': 0.046875,
#  'then_ADV': 0.9951690821256038,
#  'try_VERB': 0.9849056603773585,
#  'use_VERB': 0.5532710280373832,
#  'free_ADJ': 0.9681818181818181,
#  'time_SUBST': 0.9936753338018272,
#  'actual_ADJ': 1.0,
#  'little_ADJ': 0.7516447368421053,
#  'beforehand_ADV': 1.0,
#  'Some_ADJ': 1.0,
#  'competitions_SUBST': 1.0,
#  'provide_VERB': 1.0,
#  'warm-up_SUBST': 1.0,
#  'matted_VERB': 0.3333333333333333,
#  'same_ADJ': 1.0,
#  'material_SUBST': 0.9829059829059829,
#  'as_CONJ': 0.5957062962294786,
#  'Check_VERB': 1.0,
#  'Get_VERB': 1.0,
#  'those_ADJ': 1.0,
#  'who_PRON': 1.0,
#  'sit_VERB': 1.0,
#  'down_ADV': 0.888641425389755,
#  'so_ADV': 0.8625911385305665,
#  'emergency_SUBST': 1.0,
#  'services_SUBST': 1.0,
#  'across_PREP': 0.8266666666666667,
#  'move_VERB': 0.7611940298507462,
#  'quickly_ADV': 1.0,
#  'event_SUBST': 1.0,
#  'accident_SUBST': 1.0,
#  'such_ADJ': 1.0,
#  'as_PREP': 0.31733718203139094,
#  'pillars_SUBST': 1.0,
#  'radiators_SUBST': 1.0,
#  'chairs_SUBST': 1.0,
#  'or_CONJ': 1.0,
#  'bags_SUBST': 1.0,
#  'near_PREP': 0.7295081967213115,
#  'anything_PRON': 1.0,
#  'fact_SUBST': 1.0,
#  'that_ADJ': 0.2671335667833917,
#  'might_VERB': 0.9881656804733728,
#  'cause_VERB': 0.48299319727891155,
#  'injury_SUBST': 1.0,
#  'ploughed_VERB': 0.5,
#  'speed_SUBST': 0.9502762430939227,
#  'Clothing_SUBST': 1.0,
#  'Ensure_VERB': 1.0,
#  'turned_VERB': 0.9848484848484849,
#  'clean_ADJ': 0.8,
#  'white_ADJ': 0.9375,
#  'karategi_SUBST': 1.0,
#  'open_ADJ': 0.6572769953051644,
#  'tears_SUBST': 0.9743589743589743,
#  'rips_SUBST': 1.0,
#  'Coloured_ADJ': 1.0,
#  'gis_SUBST': 1.0,
#  'black_ADJ': 0.9281767955801105,
#  'edging_SUBST': 0.7692307692307693,
#  'stripes_SUBST': 1.0,
#  'normally_ADV': 1.0,
#  'permitted_VERB': 0.8235294117647058,
#  'sleeves_SUBST': 1.0,
#  'least_ADV': 0.9739884393063584,
#  'mid-way_ADV': 1.0,
#  'forearm_SUBST': 1.0,
#  'folded_VERB': 0.75,
#  'lead_VERB': 0.7792207792207793,
#  'Similarly_ADV': 1.0,
#  'trousers_SUBST': 1.0,
#  'shins_SUBST': 1.0,
#  'fraying_ADJ': 1.0,
#  'edges_SUBST': 1.0,
#  'whip_VERB': 0.4,
#  "'s_UNC": 0.6833861644601902,
#  'eyes_SUBST': 1.0,
#  'intend_VERB': 1.0,
#  'wear_VERB': 0.9423076923076923,
#  'badge_SUBST': 1.0,
#  'being_VERB': 0.9636608344549125,
#  'strictly_ADV': 1.0,
#  'interpreted_VERB': 0.9565217391304348,
#  'single_ADJ': 1.0,
#  'national_ADJ': 1.0,
#  'association_SUBST': 1.0,
#  'identifying_ADJ': 0.07692307692307693,
#  'red_SUBST': 0.19375,
#  'belt_SUBST': 1.0,
#  'either_ADV': 0.821917808219178,
#  'normal_ADJ': 1.0,
#  'grade_SUBST': 1.0,
#  'addition_SUBST': 1.0,
#  'Japanese_ADJ': 0.9444444444444444,
#  'word_SUBST': 1.0,
#  'aka_SUBST': 1.0,
#  'shiro_VERB': 0.5,
#  'Remember_VERB': 1.0,
#  'bearing_VERB': 0.7857142857142857,
#  'mind_SUBST': 0.8325471698113207,
#  'like_PREP': 0.749098774333093,
#  'has_VERB': 1.0,
#  'three_ADJ': 1.0,
#  'letters_SUBST': 1.0,
#  'while_CONJ': 0.8200455580865603,
#  'shiro_ADJ': 0.5,
#  'five_ADJ': 1.0,
#  'colour_SUBST': 0.9717514124293786,
#  'assigned_VERB': 1.0,
#  'arises_VERB': 1.0,
#  'draw_SUBST': 0.18840579710144928,
#  'change_VERB': 0.46859903381642515,
#  'round_SUBST': 0.07236842105263158,
#  "n't_ADV": 1.0,
#  'go_VERB': 0.9728915662650602,
#  'went_VERB': 1.0,
#  'previously_ADV': 1.0,
#  'Make_VERB': 1.0,
#  'rule_SUBST': 0.8888888888888888,
#  'check_VERB': 0.7241379310344828,
#  'scorekeeper_SUBST': 1.0,
#  'going_VERB': 0.996268656716418,
#  'on_ADV': 0.13909774436090225,
#  'times_SUBST': 0.9900497512437811,
#  'wrong_ADJ': 0.9425287356321839,
#  'name_SUBST': 0.9166666666666666,
#  'gone_VERB': 1.0,
#  'forwards_ADV': 1.0,
#  'next_ADJ': 1.0,
#  'confused_VERB': 0.2727272727272727,
#  'was_VERB': 1.0,
#  'red_ADJ': 0.80625,
#  'Take_VERB': 1.0,
#  'off_ADV': 0.7469512195121951,
#  'after_CONJ': 0.16393442622950818,
#  'leave_VERB': 0.9634146341463414,
#  'wo_VERB': 1.0,
#  'stewards_SUBST': 1.0,
#  'chasing_VERB': 1.0,
#  'after_PREP': 0.8265027322404371,
#  'Protective_ADJ': 1.0,
#  'equipment_SUBST': 1.0,
#  'fist_SUBST': 1.0,
#  'protectors_SUBST': 1.0,
#  'approved_ADJ': 0.4,
#  'These_ADJ': 1.0,
#  'centimetre_SUBST': 1.0,
#  'padding_SUBST': 0.6666666666666666,
#  'thumb_SUBST': 1.0,
#  'fold_VERB': 0.7,
#  'in_ADV': 0.03438296699510784,
#  'safely_ADV': 1.0,
#  'Always_ADV': 1.0,
#  'train_VERB': 0.5116279069767442,
#  'mitts_SUBST': 1.0,
#  'additional_ADJ': 1.0,
#  'range_SUBST': 0.9766081871345029,
#  'allow_VERB': 1.0,
#  'experience_VERB': 0.1132596685082873,
#  'what_PRON': 1.0,
#  'acceptable_ADJ': 1.0,
#  'impact_SUBST': 1.0,
#  'feels_VERB': 0.9767441860465116,
#  'Never_ADV': 1.0,
#  'heavily_ADV': 1.0,
#  'padded_ADJ': 0.7272727272727273,
#  'rely_VERB': 1.0,
#  'upon_PREP': 1.0,
#  'extra_ADJ': 0.9809523809523809,
#  'cushioning_SUBST': 1.0,
#  'effect_SUBST': 0.9497206703910615,
#  'version_SUBST': 1.0,
#  'shin/instep_SUBST': 1.0,
#  'early_ADV': 0.21656050955414013,
#  'whether_CONJ': 1.0,
#  'allowed_VERB': 1.0,
#  'information_SUBST': 1.0,
#  'contained_VERB': 1.0,
#  'details_SUBST': 0.9894736842105263,
#  'accompany_VERB': 1.0,
#  'application_SUBST': 1.0,
#  'form_SUBST': 0.7975460122699386,
#  'If_CONJ': 1.0,
#  'missing_ADJ': 0.24242424242424243,
#  'when_ADV': 0.20270270270270271,
#  'contact_VERB': 0.47368421052631576,
#  'organiser_SUBST': 1.0,
#  'find_VERB': 0.9978813559322034,
#  'Then_ADV': 1.0,
#  'tailor_VERB': 0.5,
#  'accordingly_ADV': 1.0,
#  'Shin/instep_SUBST': 1.0,
#  'close_VERB': 0.15789473684210525,
#  'velcro_SUBST': 1.0,
#  'more_ADV': 0.6540682414698162,
#  'tube_SUBST': 1.0,
#  'variety_SUBST': 1.0,
#  'greater_ADJ': 1.0,
#  'leeway_SUBST': 1.0,
#  'soon_ADV': 1.0,
#  'difference_SUBST': 1.0,
#  'sudden_ADJ': 0.9148936170212766,
#  'switch_SUBST': 0.3333333333333333,
#  'between_PREP': 0.9972337482710927,
#  'two_ADJ': 1.0,
#  'Although_CONJ': 1.0,
#  'groin_SUBST': 1.0,
#  'guards_SUBST': 1.0,
#  'mandatory_ADJ': 1.0,
#  'male_ADJ': 0.7560975609756098,
#  'no_ART': 0.8485868102288021,
#  'way_SUBST': 1.0,
#  'checking_VERB': 0.9629629629629629,
#  'worn_VERB': 0.9583333333333334,
#  'receive_VERB': 1.0,
#  'discovered_VERB': 0.9821428571428571,
#  'wearing_VERB': 0.975,
#  'guard_SUBST': 0.9516129032258065,
#  'automatically_ADV': 1.0,
#  'disqualified_VERB': 1.0,
#  'regardless_ADV': 1.0,
#  'whose_PRON': 1.0,
#  'fault_SUBST': 0.95,
#  'low_ADJ': 0.9441340782122905,
#  'Do_VERB': 1.0,
#  'plastic_SUBST': 1.0,
#  'cups_SUBST': 0.8888888888888888,
#  'slip_VERB': 0.43333333333333335,
#  'inside_ADV': 0.3835616438356164,
#  'jock_VERB': 1.0,
#  'straps_SUBST': 1.0,
#  'Not_ADV': 1.0,
#  'shatter_VERB': 1.0,
#  'been_VERB': 1.0,
#  'nip_VERB': 1.0,
#  'parts_SUBST': 0.9905660377358491,
#  'straying_VERB': 1.0,
#  'outside_ADV': 0.28921568627450983,
#  'incoming_ADJ': 1.0,
#  'struck_VERB': 1.0,
#  'home_ADV': 0.32873563218390806,
#  'Buy_VERB': 1.0,
#  'boxing-type_ADJ': 1.0,
#  'instead_ADV': 1.0,
#  'Female_ADJ': 0.6,
#  'contestants_SUBST': 1.0,
#  'advised_VERB': 1.0,
#  'sanitary_ADJ': 1.0,
#  'towel_SUBST': 1.0,
#  'protect_VERB': 1.0,
#  'perineum_SUBST': 1.0,
#  'I_PRON': 0.9948979591836735,
#  'never_ADV': 1.0,
#  'arise_VERB': 1.0,
#  'breasts_SUBST': 1.0,
#  'more_ADJ': 0.3459317585301837,
#  'their_PRON': 1.0,
#  'fair_ADJ': 0.9714285714285714,
#  'share_SUBST': 0.25,
#  'impacts_SUBST': 1.0,
#  'both_ADV': 0.601063829787234,
#  'during_PREP': 1.0,
#  'close_ADJ': 0.583732057416268,
#  'frequently_ADV': 1.0,
#  'attacked_VERB': 1.0,
#  'scoring_VERB': 0.25806451612903225,
#  'less_ADV': 0.7323529411764705,
#  'protected_VERB': 0.8518518518518519,
#  'follows_VERB': 1.0,
#  'chest_SUBST': 1.0,
#  'ought_VERB': 1.0,
#  'compulsory_ADJ': 1.0,
#  'female_ADJ': 0.7894736842105263,
#  'shields_SUBST': 1.0,
#  'cover_VERB': 0.7125,
#  'am_VERB': 0.9939024390243902,
#  'happy_ADJ': 1.0,
#  'seen_VERB': 1.0,
#  'would_VERB': 1.0,
#  'advise_VERB': 1.0,
#  'buy_VERB': 1.0,
#  'World_SUBST': 1.0,
#  'Taekwondo_SUBST': 1.0,
#  'Federation_SUBST': 1.0,
#  'WTF_SUBST': 1.0,
#  'jacket_SUBST': 1.0,
#  'sparring_SUBST': 0.5,
#  'much_ADV': 0.43370508054522927,
#  'effective_ADJ': 1.0,
#  'muting_VERB': 1.0,
#  'breast_SUBST': 1.0,
#  'shield_SUBST': 0.4,
#  'though_CONJ': 0.8653465346534653,
#  'proper_ADJ': 1.0,
#  'removes_VERB': 1.0,
#  'much_ADJ': 0.5662949194547707,
#  'risk_SUBST': 0.8305084745762712,
#  'pre-competition_ADJ': 1.0,
#  'firm_ADJ': 0.5423728813559322,
#  'bra_SUBST': 1.0,
#  'means_SUBST': 0.3892857142857143,
#  'protection_SUBST': 1.0,
#  'does_VERB': 1.0,
#  'hold_VERB': 0.8503401360544217,
#  'ca_VERB': 1.0,
#  'freely_ADV': 1.0,
#  'under_PREP': 0.9625550660792952,
#  'my_PRON': 1.0,
#  'bras_SUBST': 1.0,
#  'capable_ADJ': 1.0,
#  'causing_VERB': 1.0,
#  'damage_SUBST': 0.7640449438202247,
#  'trapping_VERB': 1.0,
#  'tissue_SUBST': 1.0,
#  'rib_SUBST': 1.0,
#  'cage_SUBST': 1.0,
#  'blow_SUBST': 0.5185185185185185,
#  'Choose_VERB': 1.0,
#  'feel_VERB': 0.953125,
#  'best_ADV': 0.19794344473007713,
#  'suits_VERB': 0.391304347826087,
#  'become_VERB': 1.0,
#  'use_SUBST': 0.44672897196261685,
#  'constrictions_SUBST': 1.0,
#  'causes_VERB': 0.7954545454545454,
#  'also_ADV': 1.0,
#  'plain_ADJ': 0.6388888888888888,
#  'T-shirt_SUBST': 1.0,
#  'beneath_PREP': 0.972972972972973,
#  'jackets_SUBST': 1.0,
#  'Spectacles_SUBST': 1.0,
#  'see_VERB': 1.0,
#  'enough_ADV': 0.7656675749318801,
#  'want_VERB': 0.9956331877729258,
#  'compete_VERB': 1.0,
#  'anyway_ADV': 1.0,
#  'pair_SUBST': 0.9387755102040817,
#  'soft_ADJ': 1.0,
#  'contact_SUBST': 0.5263157894736842,
#  'lenses_SUBST': 1.0,
#  'manage_VERB': 1.0,
#  'glasses_SUBST': 1.0,
#  'Contact_VERB': 0.9,
#  'lost_ADJ': 0.17218543046357615,
#  'bear_VERB': 0.7758620689655172,
#  'before_CONJ': 0.3713450292397661,
#  'spend_VERB': 0.9807692307692307,
#  'hefty_ADJ': 1.0,
#  'sum_SUBST': 0.9629629629629629,
#  'about_PREP': 0.8460732984293193,
#  'landing_VERB': 0.21323529411764705,
#  'controlled_ADJ': 0.3225806451612903,
#  'shortsighted_ADJ': 1.0,
#  'danger_SUBST': 1.0,
#  'opponents_SUBST': 1.0,
#  'sweatband_SUBST': 1.0,
#  'jewellery_SUBST': 1.0,
#  'earrings_SUBST': 1.0,
#  'necklaces_SUBST': 1.0,
#  'bracelets_SUBST': 1.0,
#  'rings_SUBST': 0.7272727272727273,
#  'Smooth_ADJ': 1.0,
#  'removed_VERB': 1.0,
#  'taped_VERB': 0.75,
#  'over_ADV': 0.4817444219066937,
#  'remove_VERB': 0.9705882352941176,
#  'otherwise_ADV': 1.0,
#  'dangerous_ADJ': 1.0,
#  'ring_SUBST': 0.5357142857142857,
#  'opinion_SUBST': 1.0,
#  'disbarred_VERB': 1.0,
#  'Sikh_ADJ': 1.0,
#  'prior_ADJ': 1.0,
#  'Chief_ADJ': 0.6,
#  'Referee_SUBST': 1.0,
#  'modified_ADJ': 0.42857142857142855,
#  'ritual_ADJ': 0.375,
#  'headgear_SUBST': 1.0,
#  'Long_ADJ': 0.2916666666666667,
#  'hair_SUBST': 1.0,
#  'held_VERB': 0.9955357142857143,
#  'back_ADV': 0.7311827956989247,
#  'elastic_ADJ': 1.0,
#  'clasps_SUBST': 0.5,
#  'metal_SUBST': 1.0,
#  'grips_SUBST': 1.0,
#  'fingernails_SUBST': 1.0,
#  'toenails_SUBST': 1.0,
#  'cut_VERB': 0.7843137254901961,
#  'short_ADV': 0.037037037037037035,
#  'Organization_SUBST': 1.0,
#  'Sparring_VERB': 1.0,
#  'divided_VERB': 0.85,
#  'categories_SUBST': 1.0,
#  'Men_SUBST': 1.0,
#  'Senior_ADJ': 1.0,
#  '21_ADJ': 1.0,
#  'years_SUBST': 1.0,
#  'age_SUBST': 0.9931972789115646,
#  'day_SUBST': 1.0,
#  'Women_SUBST': 1.0,
#  '18_ADJ': 1.0,
#  'junior_ADJ': 0.9166666666666666,
#  'below_ADV': 0.5887096774193549,
#  'Male_ADJ': 0.8,
#  'Cadets_SUBST': 1.0,
#  '16_ADJ': 1.0,
#  'Juniors_SUBST': 1.0,
#  'fight_VERB': 0.7307692307692307,
#  'associations_SUBST': 1.0,
#  '12_ADJ': 1.0,
#  'year_SUBST': 1.0,
#  'olds_SUBST': 1.0,
#  'Coaches_SUBST': 1.0,
#  'generally_ADV': 1.0,
#  'asked_VERB': 1.0,
#  'give_VERB': 1.0,
#  'undertaking_SUBST': 0.625,
#  'entries_SUBST': 1.0,
#  'comply_VERB': 1.0,
#  'ceilings_SUBST': 1.0,
#  'subsequently_ADV': 1.0,
#  'challenged_VERB': 1.0,
#  'found_VERB': 1.0,
#  'wanting_ADJ': 0.125,
#  'entire_ADJ': 1.0,
#  'titles_SUBST': 1.0,
#  'won_VERB': 1.0,
#  'forfeited_VERB': 1.0,
#  'International_ADJ': 1.0,
#  'requires_VERB': 1.0,
#  'passport_SUBST': 1.0,
#  'date_SUBST': 0.8888888888888888,
#  'birth_SUBST': 1.0,
#  'eliminates_VERB': 1.0,
#  'ineligible_ADJ': 1.0,
#  'grounds_SUBST': 1.0,
#  'shows_VERB': 0.8064516129032258,
#  'citizen_SUBST': 1.0,
#  'country_SUBST': 1.0,
#  'he_PRON': 0.9997645396750647,
#  'represents_VERB': 1.0,
#  'karateka_SUBST': 1.0,
#  'travelled_VERB': 1.0,
#  'international_ADJ': 1.0,
#  'took_VERB': 1.0,
#  'passports_SUBST': 1.0,
#  'Team_SUBST': 1.0,
#  'events_SUBST': 1.0,
#  'There_PRON': 0.976158940397351,
#  'team_SUBST': 0.9891304347826086,
#  'individual_ADJ': 0.7132867132867133,
#  'teams_SUBST': 0.9523809523809523,
#  'consist_VERB': 1.0,
#  'plus_PREP': 0.9166666666666666,
#  'reserve_SUBST': 0.6363636363636364,
#  'comprise_VERB': 1.0,
#  'reserves_SUBST': 1.0,
#  'sizes_SUBST': 1.0,
#  'varied_VERB': 0.45454545454545453,
#  'made_VERB': 1.0,
#  'odd_ADJ': 1.0,
#  'Fighting_VERB': 1.0,
#  'Before_CONJ': 0.4523809523809524,
#  'each_ADJ': 1.0,
#  'match_VERB': 0.2608695652173913,
#  'representative_SUBST': 0.7222222222222222,
#  'hand_SUBST': 0.9894179894179894,
#  'list_SUBST': 0.9052631578947369,
#  'specifying_VERB': 1.0,
#  'submitted_VERB': 1.0,
#  'earlier_ADJ': 0.49523809523809526,
#  'rounds_SUBST': 1.0,
#  'deemed_VERB': 1.0,
#  'still_ADV': 0.9504950495049505,
#  'apply_VERB': 1.0,
#  'something_PRON': 1.0,
#  'lightly_ADV': 1.0,
#  'field_VERB': 0.016574585635359115,
#  'described_VERB': 1.0,
#  'new_ADJ': 1.0,
#  'notice_SUBST': 0.36666666666666664,
#  'fighting_SUBST': 0.4642857142857143,
#  'Reserves_SUBST': 1.0,
#  'substituted_VERB': 1.0,
#  'discretion_SUBST': 1.0,
#  'coach_SUBST': 0.9411764705882353,
#  'Generally_ADV': 1.0,
#  'best_ADJ': 0.8020565552699229,
#  'send_VERB': 1.0,
#  'strong_ADJ': 0.9940119760479041,
#  'opener_SUBST': 1.0,
#  'someone_PRON': 0.9960159362549801,
#  'relied_VERB': 1.0,
#  'victory_SUBST': 1.0,
#  'lifts_VERB': 0.23529411764705882,
#  'morale_SUBST': 1.0,
#  'encourages_VERB': 1.0,
#  'line_SUBST': 0.9754601226993865,
#  'member_SUBST': 1.0,
#  'suspect_VERB': 0.78125,
#  'put_VERB': 1.0,
#  'third_ADJ': 1.0,
#  'With_PREP': 1.0,
#  'wins_VERB': 0.8125,
#  'already_ADV': 1.0,
#  'gained_VERB': 1.0,
#  'performers_SUBST': 1.0,
#  'middle_ADJ': 0.3793103448275862,
#  'ideally_ADV': 1.0,
#  'suited_VERB': 1.0,
#  'weakest_ADJ': 1.0,
#  'last_ADJ': 0.9342105263157895,
#  'called_VERB': 0.9919028340080972,
#  'save_VERB': 1.0,
#  'keep_VERB': 0.9929328621908127,
#  'good_ADJ': 0.9620081411126187,
#  'finisher_SUBST': 1.0,
#  'Such_ADJ': 1.0,
#  'lagging_SUBST': 0.5,
#  'Each_ADJ': 1.0,
#  'short-handed_ADJ': 0.5,
#  'chance_SUBST': 1.0,
#  'win_VERB': 0.9545454545454546,
#  'match_SUBST': 0.7391304347826086,
#  'therefore_ADV': 1.0,
#  'meaningful_ADJ': 1.0,
#  'A_ART': 0.910267471958585,
#  'successful_ADJ': 1.0,
#  'fights_SUBST': 0.42857142857142855,
#  'course_SUBST': 1.0,
#  'unusual_ADJ': 1.0,
#  'short-handed_ADV': 0.5,
#  'stages_SUBST': 0.9655172413793104,
#  'tempted_VERB': 1.0,
#  'forfeit_VERB': 1.0,
#  'bouts_SUBST': 1.0,
#  'bout_SUBST': 1.0,
#  'deciding_ADJ': 0.19047619047619047,
#  'first_ADJ': 1.0,
#  'three/two_ADJ': 1.0,
#  'victories_SUBST': 1.0,
#  'opposing_ADJ': 0.6666666666666666,
#  'winning_VERB': 0.7567567567567568,
#  'attempt_SUBST': 0.7391304347826086,
#  'withdraw_VERB': 1.0,
#  'remaining_ADJ': 0.7317073170731707,
#  'team-member(s)_SUBST': 1.0,
#  'rewarded_VERB': 1.0,
#  'disqualification_SUBST': 1.0,
#  'sportsmanship_SUBST': 1.0,
#  'Sometimes_ADV': 1.0,
#  'delayed_VERB': 0.7857142857142857,
#  'things_SUBST': 1.0,
#  'happen_VERB': 1.0,
#  'fast_ADV': 0.379746835443038,
#  'Should_VERB': 1.0,
#  'occur_VERB': 1.0,
#  'relaxing_VERB': 0.8181818181818182,
#  'itself_PRON': 1.0,
#  'earshot_SUBST': 1.0,
#  'vital_ADJ': 1.0,
#  'nominates_VERB': 1.0,
#  'observer_SUBST': 1.0,
#  'monitor_VERB': 0.875,
#  'happening_VERB': 0.9193548387096774,
#  'arena_SUBST': 1.0,
#  'Otherwise_ADV': 1.0,
#  'public_ADJ': 0.7041666666666667,
#  'announcements_SUBST': 1.0,
#  'Any_ADJ': 1.0,
#  'withdraws_VERB': 1.0,
#  'short_ADJ': 0.9470899470899471,
#  'whole_SUBST': 0.29965156794425085,
#  'cancelled_VERB': 1.0,
#  'arrives_VERB': 1.0,
#  'venue_SUBST': 1.0,
#  'sufficient_ADJ': 1.0,
#  'register_VERB': 0.5652173913043478,
#  'weigh-in_SUBST': 1.0,
#  'face_VERB': 0.19047619047619047,
#  'unexpected_ADJ': 1.0,
#  'travel_SUBST': 0.41304347826086957,
#  'delays_SUBST': 0.75,
#  'arrive_VERB': 1.0,
#  'progressed_VERB': 1.0,
#  'beyond_PREP': 0.9074074074074074,
#  'Important_ADJ': 1.0,
#  'preparation_SUBST': 1.0,
#  'adequate_ADJ': 1.0,
#  'rest_SUBST': 0.8700564971751412,
#  'night_SUBST': 1.0,
#  'before_ADV': 0.18421052631578946,
#  'duty_SUBST': 1.0,
#  'arriving_VERB': 1.0,
#  'hold_SUBST': 0.14965986394557823,
#  'current_ADJ': 0.9367088607594937,
#  'sheet_SUBST': 1.0,
#  'identify_VERB': 1.0,
#  'competing_ADJ': 0.25,
#  'confirm_VERB': 1.0,
#  'timetable_SUBST': 1.0,
#  'Weight_SUBST': 1.0,
#  'Individual_ADJ': 1.0,
#  'fought_VERB': 1.0,
#  'weight_SUBST': 1.0,
#  '60_ADJ': 1.0,
#  'kilos_SUBST': 1.0,
#  '65_ADJ': 1.0,
#  '70_ADJ': 1.0,
#  '53_ADJ': 1.0,
#  '75_ADJ': 1.0,
#  '80_ADJ': 1.0,
#  '+_UNC': 1.0,
#  '+60_ADJ': 1.0,
#  'Open_ADJ': 0.96,
#  'Min._SUBST': 1.0,
#  '43_ADJ': 1.0,
#  'individuals_SUBST': 1.0,
#  'closely_ADV': 1.0,
#  'matched_VERB': 0.9166666666666666,
#  'kilo_SUBST': 1.0,
#  'male_SUBST': 0.24390243902439024,
#  '+90_ADJ': 1.0,
#  'category_SUBST': 1.0,
#  'outcome_SUBST': 1.0,
#  'pretty_ADJ': 0.36666666666666664,
#  'My_PRON': 1.0,
#  'advice_SUBST': 1.0,
#  'lightweights_SUBST': 1.0,
#  'consider_VERB': 1.0,
#  'heavyweights_SUBST': 1.0,
#  'great_ADJ': 1.0,
#  'advantage_SUBST': 1.0,
#  'forget_VERB': 1.0,
#  'glass_SUBST': 0.9973045822102425,
#  'water_SUBST': 0.9902912621359223,
#  'tip_VERB': 0.13513513513513514,
#  'At_PREP': 1.0,
#  'every_ART': 1.0,
#  'working_VERB': 0.7359307359307359,
#  'hard_ADV': 0.34285714285714286,
#  'sweat_VERB': 0.16666666666666666,
#  'off_PREP': 0.25,
#  're-weigh_SUBST': 0.5,
#  'Usually_ADV': 1.0,
#  'lost_VERB': 0.8278145695364238,
#  'totally_ADV': 1.0,
#  'fatigued_VERB': 1.0,
#  'An_ART': 1.0,
#  'diuretic_SUBST': 0.5,
#  'reduce_VERB': 1.0,
#  'constitutes_VERB': 1.0,
#  'drug-taking_SUBST': 1.0,
#  'lifetime_SUBST': 1.0,
#  'ban_SUBST': 0.7857142857142857,
#  'few_ADJ': 1.0,
#  'grams_SUBST': 1.0,
#  'legitimately_ADV': 1.0,
#  'shed_VERB': 0.47058823529411764,
#  'stripping_VERB': 1.0,
#  'undershorts_SUBST': 1.0,
#  'T_SUBST': 0.47619047619047616,
#  'shirts_SUBST': 1.0,
#  'weighs_VERB': 1.0,
#  'accurate_ADJ': 1.0,
#  'scales_SUBST': 0.875,
#  'warns_VERB': 1.0,
#  'marginals_SUBST': 1.0,
#  'care_SUBST': 0.8174603174603174,
#  'Normally_ADV': 1.0,
#  're-weigh_VERB': 0.5,
#  'another_ADJ': 1.0,
#  'set_SUBST': 0.24858757062146894,
#  'believe_VERB': 1.0,
#  'reading_VERB': 0.5075757575757576,
#  'heavy_ADJ': 1.0,
#  'Documentation_SUBST': 1.0,
#  'bring_VERB': 1.0,
#  'required_ADJ': 0.09473684210526316,
#  'documentation_SUBST': 1.0,
#  'For_PREP': 0.8879492600422833,
#  'example_SUBST': 1.0,
#  'British_ADJ': 1.0,
#  'require_VERB': 1.0,
#  'produce_VERB': 0.9173553719008265,
#  'Martial_ADJ': 1.0,
#  'Arts_SUBST': 1.0,
#  'Commission_SUBST': 1.0,
#  'licence_SUBST': 1.0,
#  'faces_SUBST': 0.8289473684210527,
#  'sidelined_VERB': 1.0,
#  'forgetting_VERB': 1.0,
#  'requirement_SUBST': 1.0,
#  'properly_ADV': 1.0,
#  'prepared_VERB': 0.40350877192982454,
#  'unissued_ADJ': 1.0,
#  'licences_SUBST': 1.0,
#  'along_ADV': 0.5666666666666667,
#  'forgotten_VERB': 0.9523809523809523,
#  'theirs_PRON': 1.0,
#  'contest_SUBST': 0.6923076923076923,
#  'Karate_SUBST': 1.0,
#  'two-minute_ADJ': 1.0,
#  'extended_VERB': 0.7037037037037037,
#  'minutes_SUBST': 1.0,
#  'taken_VERB': 0.9961832061068703,
#  'pauses_SUBST': 0.6666666666666666,
#  'counted_VERB': 1.0,
#  'defines_VERB': 1.0,
#  'extent_SUBST': 1.0,
#  'stamina_SUBST': 1.0,
#  'programme_SUBST': 1.0,
#  'develop_VERB': 1.0,
#  'maintaining_VERB': 1.0,
#  'relentless_ADJ': 1.0,
#  'powerful_ADJ': 1.0,
#  'onslaught_SUBST': 1.0,
#  'whole_ADJ': 0.7003484320557491,
#  'Aim_VERB': 1.0,
#  'margin_SUBST': 1.0,
#  'allowing_VERB': 1.0,
#  'further_ADJ': 0.6174242424242424,
#  'death_SUBST': 1.0,
#  'extension_SUBST': 1.0,
#  'there_PRON': 0.7483774338492262,
#  'pause_SUBST': 0.9090909090909091,
#  'minute_SUBST': 0.9272727272727272,
#  'successive_ADJ': 1.0,
#  'Bout_SUBST': 1.0,
#  'bell_SUBST': 1.0,
#  'hear_VERB': 1.0,
#  '30_ADJ': 1.0,
#  'seconds_SUBST': 1.0,
#  'warning_SUBST': 0.8387096774193549,
#  ...}

# %%
input_tag = input("Give tag input...")
# Out:
# Give tag input...VERB

# %%
for key in probab_w_t:
    component = key.split("_")
    if component[1] == input_tag:
        print(" "key + " " + probab_w_t.get(key))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-996ec1859b3d> in <module>
#       2     component = key.split("_")
#       3     if component[1] == input_tag:
# ----> 4         print(key + " " + probab_w_t.get(key))
#
# TypeError: can only concatenate str (not "float") to str
