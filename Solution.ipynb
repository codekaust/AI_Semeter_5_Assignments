# %% [markdown]
# # PREPROCESSING

# %%
# import ElementTree to parse XML test corpus
import xml.etree.ElementTree as ET

# %%
# get all files in the Train-corpus folder
import glob
path = '/home/kaustubh/Dropbox/Sem5/AI/Assignments/Train-corups/*.xml'
files = glob.glob(path)

# %%
# open a file to write the cleaned data
writer = open("train_data.txt", "w+")

# iterate over all files
for file in files:
    
    # parse each XML file
    tree = ET.parse(file)
    root = tree.getroot()   
    
    # get w elements in the file
    for word in root.iter('w'):      
        writer.write("%s_%s\n" % (word.text.strip(), word.attrib['pos'].strip()))
        
writer.close()

# %% [markdown]
# # WORD+TAG FREQUENCY COUNT

# %%
freq = {}

reader = open("train_data.txt", "r")
for line in reader:
    freq[line.strip()] = freq.get(line.strip(), 0) + 1

reader.close()

# %%
freq
# Out:
# {'USING_VERB': 3,
#  'THE_ART': 219,
#  'RULES_SUBST': 1,
#  'TO_PREP': 49,
#  'HELP_VERB': 5,
#  'YOU_PRON': 26,
#  'WIN_VERB': 9,
#  'It_PRON': 2123,
#  'is_VERB': 10777,
#  'surprising_ADJ': 33,
#  'how_ADV': 822,
#  'many_ADJ': 693,
#  'people_SUBST': 1015,
#  'take_VERB': 583,
#  'part_SUBST': 464,
#  'in_PREP': 14009,
#  'competition_SUBST': 161,
#  'without_PREP': 463,
#  'knowing_VERB': 67,
#  'the_ART': 46249,
#  'rules_SUBST': 63,
#  'even_ADV': 833,
#  'at_PREP': 4222,
#  'élite_UNC': 24,
#  'level_SUBST': 156,
#  'This_ADJ': 1175,
#  'chapter_SUBST': 49,
#  'will_VERB': 2500,
#  'examine_VERB': 14,
#  'of_PREP': 25860,
#  'from_PREP': 3561,
#  'competitors_SUBST': 27,
#  "'_UNC": 431,
#  'point_SUBST': 345,
#  'view_SUBST': 206,
#  'rather_ADV': 390,
#  'than_CONJ': 1214,
#  'referees_SUBST': 11,
#  'show_VERB': 136,
#  'a_ART': 19068,
#  'knowledge_SUBST': 174,
#  'can_VERB': 2719,
#  'be_VERB': 6167,
#  'used_VERB': 432,
#  'to_PREP': 23319,
#  'help_VERB': 292,
#  'your_PRON': 2218,
#  'tournament_SUBST': 41,
#  'training_SUBST': 339,
#  'by_PREP': 3827,
#  'outlining_VERB': 5,
#  'following_ADJ': 101,
#  'kind_SUBST': 247,
#  'fitness_SUBST': 29,
#  'requirements_SUBST': 35,
#  'you_PRON': 6133,
#  'need_VERB': 465,
#  'most_ADV': 519,
#  'often_ADV': 468,
#  'scored_VERB': 15,
#  'techniques_SUBST': 73,
#  'explaining_VERB': 31,
#  'why_ADV': 316,
#  'they_PRON': 2697,
#  'failed_VERB': 54,
#  'score_VERB': 26,
#  'when_CONJ': 1239,
#  'felt_VERB': 245,
#  'should_VERB': 1043,
#  'have_VERB': 4154,
#  'injuries_SUBST': 21,
#  'are_VERB': 4697,
#  'dealt_VERB': 18,
#  'with_PREP': 5918,
#  'ensure_VERB': 72,
#  'that_CONJ': 5832,
#  'any_ADJ': 1056,
#  'complaint_SUBST': 9,
#  'make_VERB': 849,
#  'correctly_ADV': 39,
#  'The_ART': 5050,
#  'area_SUBST': 220,
#  'In_PREP': 1315,
#  'principle_SUBST': 55,
#  'this_ADJ': 3224,
#  '8m_SUBST': 5,
#  'x_PREP': 10,
#  '9.5yd_SUBST': 3,
#  'but_CONJ': 2700,
#  'practice_SUBST': 174,
#  'it_PRON': 7085,
#  'may_VERB': 1271,
#  'shrink_VERB': 2,
#  'only_ADV': 1101,
#  '7m_SUBST': 2,
#  '8.3yd_SUBST': 2,
#  'order_SUBST': 238,
#  'fit_VERB': 64,
#  'enough_ADJ': 86,
#  'areas_SUBST': 157,
#  'available_ADJ': 290,
#  'space_SUBST': 117,
#  'Many_ADJ': 123,
#  'organisers_SUBST': 10,
#  'miscalculate_VERB': 1,
#  'entry_SUBST': 45,
#  'levels_SUBST': 49,
#  'result_SUBST': 121,
#  'adjacent_ADJ': 18,
#  'crowded_VERB': 5,
#  'together_ADV': 299,
#  'and_CONJ': 22704,
#  'safety_SUBST': 62,
#  'imperilled_VERB': 1,
#  'Often_ADV': 23,
#  'run-off_SUBST': 1,
#  'zone_SUBST': 5,
#  'missing_VERB': 25,
#  'one_ADJ': 1479,
#  'metre_SUBST': 2,
#  'band_SUBST': 29,
#  'marked_VERB': 23,
#  'inside_PREP': 64,
#  'outer_ADJ': 12,
#  'perimeter_SUBST': 2,
#  'sometimes_ADV': 173,
#  'highlighted_VERB': 8,
#  'using_VERB': 211,
#  'different_ADJ': 415,
#  'coloured_ADJ': 24,
#  'mats_SUBST': 6,
#  'its_PRON': 1296,
#  'purpose_SUBST': 45,
#  'alert_VERB': 9,
#  'approach_VERB': 19,
#  'mat_SUBST': 15,
#  'boundary_SUBST': 26,
#  'Since_CONJ': 47,
#  'pick_VERB': 56,
#  'up_ADV': 1832,
#  'penalties_SUBST': 13,
#  'for_PREP': 6785,
#  'stepping_VERB': 18,
#  'out_ADV': 1887,
#  'inadvertently_ADV': 6,
#  'makes_VERB': 178,
#  'sense_SUBST': 285,
#  'get_VERB': 761,
#  'used_ADJ': 40,
#  'sparring_VERB': 2,
#  'competition-sized_ADJ': 1,
#  'square_SUBST': 20,
#  'very_ADV': 955,
#  'important_ADJ': 395,
#  'because_CONJ': 712,
#  'tactically-minded_ADJ': 1,
#  'competitor_SUBST': 19,
#  'crowd_VERB': 2,
#  'an_ART': 2974,
#  'inexperienced_ADJ': 31,
#  'opponent_SUBST': 295,
#  'picking_VERB': 17,
#  'points_SUBST': 67,
#  'exchanging_VERB': 3,
#  'technique_SUBST': 116,
#  'You_PRON': 1039,
#  'must_VERB': 769,
#  'always_ADV': 582,
#  'able_ADJ': 352,
#  'locate_VERB': 11,
#  'position_SUBST': 245,
#  'within_PREP': 254,
#  '8-metre_SUBST': 1,
#  'Normal_ADJ': 2,
#  'free-sparring_ADJ': 1,
#  'hall_SUBST': 38,
#  'limited_VERB': 29,
#  'number_SUBST': 297,
#  'there_ADV': 504,
#  'so_CONJ': 245,
#  'bad_ADJ': 136,
#  'habits_SUBST': 12,
#  'through_PREP': 607,
#  'uneconomically_ADV': 1,
#  'Therefore_ADV': 28,
#  'do_VERB': 2050,
#  'all_ADV': 225,
#  'final_ADJ': 126,
#  '8_ADJ': 42,
#  'm_SUBST': 8,
#  'x_SUBST': 29,
#  '9.5_ADJ': 3,
#  'yd_SUBST': 8,
#  'exactly_ADV': 88,
#  'where_CONJ': 359,
#  'Safety_SUBST': 15,
#  'Virtually_ADV': 1,
#  'all_ADJ': 2113,
#  'now_ADV': 987,
#  'takes_VERB': 140,
#  'place_SUBST': 484,
#  'on_PREP': 5038,
#  'since_CONJ': 162,
#  'hard_ADJ': 160,
#  'floors_SUBST': 7,
#  'known_VERB': 213,
#  'present_VERB': 39,
#  'hazard_SUBST': 14,
#  'falling_ADJ': 1,
#  'However_ADV': 281,
#  'themselves_PRON': 216,
#  'pose_VERB': 8,
#  'hazards_SUBST': 15,
#  'as_ADV': 482,
#  'well_ADJ': 32,
#  'if_CONJ': 1857,
#  'aware_ADJ': 133,
#  'these_ADJ': 817,
#  'Firstly_ADV': 10,
#  'modules_SUBST': 4,
#  'come_VERB': 526,
#  'apart_ADV': 87,
#  'referee_SUBST': 41,
#  'fails_VERB': 18,
#  'notice_VERB': 38,
#  'injured_VERB': 4,
#  'his_PRON': 3740,
#  'foot_SUBST': 185,
#  'slips_VERB': 5,
#  'into_PREP': 1513,
#  'gap_SUBST': 18,
#  'Broken_ADJ': 1,
#  'ankles_SUBST': 10,
#  'not_ADV': 4226,
#  'uncommon_ADJ': 10,
#  'karate_SUBST': 24,
#  'Secondly_ADV': 17,
#  'some_ADJ': 1351,
#  'sticky_ADJ': 18,
#  'preventing_VERB': 16,
#  'feet_SUBST': 186,
#  'sliding_VERB': 10,
#  'easily_ADV': 133,
#  'over_PREP': 511,
#  'them_PRON': 1584,
#  'throw_VERB': 40,
#  'roundhouse_SUBST': 42,
#  'kick_SUBST': 119,
#  'supporting_ADJ': 13,
#  'prevented_VERB': 23,
#  'swivelling_VERB': 1,
#  'Finally_ADV': 41,
#  'spongy_ADJ': 1,
#  'requiring_VERB': 11,
#  'lift_VERB': 42,
#  'well_ADV': 816,
#  'clear_ADJ': 204,
#  'before_PREP': 304,
#  'Obviously_ADV': 21,
#  'know_VERB': 862,
#  'advance_SUBST': 31,
#  'which_PRON': 3420,
#  'type_SUBST': 141,
#  'particular_ADJ': 236,
#  'just_ADV': 929,
#  'feel_SUBST': 15,
#  'then_ADV': 1236,
#  'try_VERB': 261,
#  'use_VERB': 296,
#  'free_ADJ': 213,
#  'time_SUBST': 1414,
#  'actual_ADJ': 50,
#  'little_ADJ': 457,
#  'beforehand_ADV': 12,
#  'Some_ADJ': 256,
#  'competitions_SUBST': 21,
#  'provide_VERB': 166,
#  'warm-up_SUBST': 4,
#  'matted_VERB': 1,
#  'same_ADJ': 500,
#  'material_SUBST': 115,
#  'as_CONJ': 3302,
#  'Check_VERB': 19,
#  'Get_VERB': 28,
#  'those_ADJ': 673,
#  'who_PRON': 1772,
#  'sit_VERB': 67,
#  'down_ADV': 798,
#  'so_ADV': 1538,
#  'emergency_SUBST': 29,
#  'services_SUBST': 134,
#  'across_PREP': 186,
#  'move_VERB': 153,
#  'quickly_ADV': 152,
#  'event_SUBST': 116,
#  'accident_SUBST': 52,
#  'such_ADJ': 948,
#  'as_PREP': 1759,
#  'pillars_SUBST': 4,
#  'radiators_SUBST': 7,
#  'chairs_SUBST': 26,
#  'or_CONJ': 4030,
#  'bags_SUBST': 18,
#  'near_PREP': 89,
#  'anything_PRON': 252,
#  'fact_SUBST': 290,
#  'that_ADJ': 2136,
#  'might_VERB': 501,
#  'cause_VERB': 71,
#  'injury_SUBST': 66,
#  'ploughed_VERB': 1,
#  'speed_SUBST': 172,
#  'Clothing_SUBST': 1,
#  'Ensure_VERB': 10,
#  'turned_VERB': 260,
#  'clean_ADJ': 48,
#  'white_ADJ': 195,
#  'karategi_SUBST': 3,
#  'open_ADJ': 140,
#  'tears_SUBST': 38,
#  'rips_SUBST': 2,
#  'Coloured_ADJ': 1,
#  'gis_SUBST': 1,
#  'black_ADJ': 168,
#  'edging_SUBST': 10,
#  'stripes_SUBST': 6,
#  'normally_ADV': 67,
#  'permitted_VERB': 14,
#  'sleeves_SUBST': 7,
#  'least_ADV': 337,
#  'mid-way_ADV': 7,
#  'forearm_SUBST': 15,
#  'folded_VERB': 12,
#  'lead_VERB': 60,
#  'Similarly_ADV': 19,
#  'trousers_SUBST': 27,
#  'shins_SUBST': 3,
#  'fraying_ADJ': 1,
#  'edges_SUBST': 26,
#  'whip_VERB': 2,
#  "'s_UNC": 3665,
#  'eyes_SUBST': 320,
#  'intend_VERB': 9,
#  'wear_VERB': 49,
#  'badge_SUBST': 7,
#  'being_VERB': 716,
#  'strictly_ADV': 9,
#  'interpreted_VERB': 22,
#  'single_ADJ': 116,
#  'national_ADJ': 135,
#  'association_SUBST': 43,
#  'identifying_ADJ': 1,
#  'red_SUBST': 31,
#  'belt_SUBST': 12,
#  'either_ADV': 180,
#  'normal_ADJ': 124,
#  'grade_SUBST': 6,
#  'addition_SUBST': 78,
#  'Japanese_ADJ': 17,
#  'word_SUBST': 181,
#  'aka_SUBST': 2,
#  'shiro_VERB': 1,
#  'Remember_VERB': 53,
#  'bearing_VERB': 11,
#  'mind_SUBST': 353,
#  'like_PREP': 1039,
#  'has_VERB': 2250,
#  'three_ADJ': 410,
#  'letters_SUBST': 78,
#  'while_CONJ': 360,
#  'shiro_ADJ': 1,
#  'five_ADJ': 148,
#  'colour_SUBST': 172,
#  'assigned_VERB': 7,
#  'arises_VERB': 15,
#  'draw_SUBST': 13,
#  'change_VERB': 97,
#  'round_SUBST': 22,
#  "n't_ADV": 2105,
#  'go_VERB': 646,
#  'went_VERB': 457,
#  'previously_ADV': 38,
#  'Make_VERB': 49,
#  'rule_SUBST': 40,
#  'check_VERB': 84,
#  'scorekeeper_SUBST': 2,
#  'going_VERB': 534,
#  'on_ADV': 814,
#  'times_SUBST': 199,
#  'wrong_ADJ': 164,
#  'name_SUBST': 209,
#  'gone_VERB': 176,
#  'forwards_ADV': 134,
#  'next_ADJ': 324,
#  'confused_VERB': 3,
#  'was_VERB': 6284,
#  'red_ADJ': 129,
#  'Take_VERB': 52,
#  'off_ADV': 490,
#  'after_CONJ': 120,
#  'leave_VERB': 158,
#  'wo_VERB': 95,
#  'stewards_SUBST': 2,
#  'chasing_VERB': 7,
#  'after_PREP': 605,
#  'Protective_ADJ': 2,
#  'equipment_SUBST': 69,
#  'fist_SUBST': 38,
#  'protectors_SUBST': 6,
#  'approved_ADJ': 8,
#  'These_ADJ': 222,
#  'centimetre_SUBST': 1,
#  'padding_SUBST': 2,
#  'thumb_SUBST': 14,
#  'fold_VERB': 7,
#  'in_ADV': 499,
#  'safely_ADV': 31,
#  'Always_ADV': 57,
#  'train_VERB': 44,
#  'mitts_SUBST': 3,
#  'additional_ADJ': 48,
#  'range_SUBST': 167,
#  'allow_VERB': 95,
#  'experience_VERB': 41,
#  'what_PRON': 1637,
#  'acceptable_ADJ': 27,
#  'impact_SUBST': 58,
#  'feels_VERB': 42,
#  'Never_ADV': 42,
#  'heavily_ADV': 42,
#  'padded_ADJ': 8,
#  'rely_VERB': 17,
#  'upon_PREP': 154,
#  'extra_ADJ': 103,
#  'cushioning_SUBST': 3,
#  'effect_SUBST': 170,
#  'version_SUBST': 67,
#  'shin/instep_SUBST': 3,
#  'early_ADV': 68,
#  'whether_CONJ': 221,
#  'allowed_VERB': 101,
#  'information_SUBST': 297,
#  'contained_VERB': 41,
#  'details_SUBST': 94,
#  'accompany_VERB': 12,
#  'application_SUBST': 45,
#  'form_SUBST': 260,
#  'If_CONJ': 899,
#  'missing_ADJ': 8,
#  'when_ADV': 315,
#  'contact_VERB': 63,
#  'organiser_SUBST': 4,
#  'find_VERB': 471,
#  'Then_ADV': 228,
#  'tailor_VERB': 1,
#  'accordingly_ADV': 11,
#  'Shin/instep_SUBST': 1,
#  'close_VERB': 33,
#  'velcro_SUBST': 1,
#  'more_ADV': 1246,
#  'tube_SUBST': 26,
#  'variety_SUBST': 96,
#  'greater_ADJ': 92,
#  'leeway_SUBST': 4,
#  'soon_ADV': 218,
#  'difference_SUBST': 101,
#  'sudden_ADJ': 43,
#  'switch_SUBST': 6,
#  'between_PREP': 721,
#  'two_ADJ': 907,
#  'Although_CONJ': 82,
#  'groin_SUBST': 12,
#  'guards_SUBST': 8,
#  'mandatory_ADJ': 4,
#  'male_ADJ': 31,
#  'no_ART': 1261,
#  'way_SUBST': 878,
#  'checking_VERB': 26,
#  'worn_VERB': 23,
#  'receive_VERB': 82,
#  'discovered_VERB': 55,
#  'wearing_VERB': 39,
#  'guard_SUBST': 59,
#  'automatically_ADV': 25,
#  'disqualified_VERB': 7,
#  'regardless_ADV': 25,
#  'whose_PRON': 212,
#  'fault_SUBST': 38,
#  'low_ADJ': 169,
#  'Do_VERB': 291,
#  'plastic_SUBST': 52,
#  'cups_SUBST': 16,
#  'slip_VERB': 13,
#  'inside_ADV': 56,
#  'jock_VERB': 1,
#  'straps_SUBST': 4,
#  'Not_ADV': 260,
#  'shatter_VERB': 2,
#  'been_VERB': 1905,
#  'nip_VERB': 3,
#  'parts_SUBST': 105,
#  'straying_VERB': 2,
#  'outside_ADV': 59,
#  'incoming_ADJ': 15,
#  'struck_VERB': 29,
#  'home_ADV': 143,
#  'Buy_VERB': 5,
#  'boxing-type_ADJ': 1,
#  'instead_ADV': 90,
#  'Female_ADJ': 3,
#  'contestants_SUBST': 15,
#  'advised_VERB': 17,
#  'sanitary_ADJ': 1,
#  'towel_SUBST': 11,
#  'protect_VERB': 45,
#  'perineum_SUBST': 1,
#  'I_PRON': 8385,
#  'never_ADV': 619,
#  'arise_VERB': 25,
#  'breasts_SUBST': 28,
#  'more_ADJ': 659,
#  'their_PRON': 2079,
#  'fair_ADJ': 68,
#  'share_SUBST': 12,
#  'impacts_SUBST': 6,
#  'both_ADV': 339,
#  'during_PREP': 326,
#  'close_ADJ': 122,
#  'frequently_ADV': 81,
#  'attacked_VERB': 16,
#  'scoring_VERB': 8,
#  'less_ADV': 249,
#  'protected_VERB': 23,
#  'follows_VERB': 48,
#  'chest_SUBST': 72,
#  'ought_VERB': 34,
#  'compulsory_ADJ': 6,
#  'female_ADJ': 30,
#  'shields_SUBST': 4,
#  'cover_VERB': 57,
#  'am_VERB': 326,
#  'happy_ADJ': 79,
#  'seen_VERB': 320,
#  'would_VERB': 1743,
#  'advise_VERB': 46,
#  'buy_VERB': 63,
#  'World_SUBST': 138,
#  'Taekwondo_SUBST': 1,
#  'Federation_SUBST': 32,
#  'WTF_SUBST': 1,
#  'jacket_SUBST': 31,
#  'sparring_SUBST': 2,
#  'much_ADV': 350,
#  'effective_ADJ': 125,
#  'muting_VERB': 1,
#  'breast_SUBST': 27,
#  'shield_SUBST': 2,
#  'though_CONJ': 437,
#  'proper_ADJ': 57,
#  'removes_VERB': 4,
#  'much_ADJ': 457,
#  'risk_SUBST': 98,
#  'pre-competition_ADJ': 1,
#  'firm_ADJ': 32,
#  'bra_SUBST': 5,
#  'means_SUBST': 109,
#  'protection_SUBST': 49,
#  'does_VERB': 575,
#  'hold_VERB': 125,
#  'ca_VERB': 183,
#  'freely_ADV': 17,
#  'under_PREP': 437,
#  'my_PRON': 1813,
#  'bras_SUBST': 1,
#  'capable_ADJ': 36,
#  'causing_VERB': 37,
#  'damage_SUBST': 68,
#  'trapping_VERB': 2,
#  'tissue_SUBST': 10,
#  'rib_SUBST': 3,
#  'cage_SUBST': 4,
#  'blow_SUBST': 14,
#  'Choose_VERB': 20,
#  'feel_VERB': 305,
#  'best_ADV': 77,
#  'suits_VERB': 9,
#  'become_VERB': 275,
#  'use_SUBST': 239,
#  'constrictions_SUBST': 1,
#  'causes_VERB': 35,
#  'also_ADV': 1042,
#  'plain_ADJ': 23,
#  'T-shirt_SUBST': 3,
#  'beneath_PREP': 36,
#  'jackets_SUBST': 1,
#  'Spectacles_SUBST': 1,
#  'see_VERB': 847,
#  'enough_ADV': 281,
#  'want_VERB': 456,
#  'compete_VERB': 24,
#  'anyway_ADV': 76,
#  'pair_SUBST': 46,
#  'soft_ADJ': 64,
#  'contact_SUBST': 70,
#  'lenses_SUBST': 4,
#  'manage_VERB': 53,
#  'glasses_SUBST': 39,
#  'Contact_VERB': 9,
#  'lost_ADJ': 26,
#  'bear_VERB': 45,
#  'before_CONJ': 254,
#  'spend_VERB': 51,
#  'hefty_ADJ': 5,
#  'sum_SUBST': 26,
#  'about_PREP': 1616,
#  'landing_VERB': 29,
#  'controlled_ADJ': 10,
#  'shortsighted_ADJ': 1,
#  'danger_SUBST': 42,
#  'opponents_SUBST': 13,
#  'sweatband_SUBST': 1,
#  'jewellery_SUBST': 5,
#  'earrings_SUBST': 8,
#  'necklaces_SUBST': 1,
#  'bracelets_SUBST': 3,
#  'rings_SUBST': 8,
#  'Smooth_ADJ': 1,
#  'removed_VERB': 45,
#  'taped_VERB': 3,
#  'over_ADV': 475,
#  'remove_VERB': 33,
#  'otherwise_ADV': 66,
#  'dangerous_ADJ': 81,
#  'ring_SUBST': 30,
#  'opinion_SUBST': 49,
#  'disbarred_VERB': 3,
#  'Sikh_ADJ': 1,
#  'prior_ADJ': 28,
#  'Chief_ADJ': 12,
#  'Referee_SUBST': 3,
#  'modified_ADJ': 6,
#  'ritual_ADJ': 9,
#  'headgear_SUBST': 2,
#  'Long_ADJ': 7,
#  'hair_SUBST': 172,
#  'held_VERB': 223,
#  'back_ADV': 748,
#  'elastic_ADJ': 1,
#  'clasps_SUBST': 1,
#  'metal_SUBST': 24,
#  'grips_SUBST': 4,
#  'fingernails_SUBST': 4,
#  'toenails_SUBST': 3,
#  'cut_VERB': 120,
#  'short_ADV': 7,
#  'Organization_SUBST': 3,
#  'Sparring_VERB': 1,
#  'divided_VERB': 34,
#  'categories_SUBST': 26,
#  'Men_SUBST': 19,
#  'Senior_ADJ': 12,
#  '21_ADJ': 34,
#  'years_SUBST': 677,
#  'age_SUBST': 146,
#  'day_SUBST': 528,
#  'Women_SUBST': 35,
#  '18_ADJ': 29,
#  'junior_ADJ': 11,
#  'below_ADV': 73,
#  'Male_ADJ': 4,
#  'Cadets_SUBST': 1,
#  '16_ADJ': 36,
#  'Juniors_SUBST': 1,
#  'fight_VERB': 38,
#  'associations_SUBST': 13,
#  '12_ADJ': 55,
#  'year_SUBST': 478,
#  'olds_SUBST': 2,
#  'Coaches_SUBST': 2,
#  'generally_ADV': 79,
#  'asked_VERB': 328,
#  'give_VERB': 425,
#  'undertaking_SUBST': 5,
#  'entries_SUBST': 26,
#  'comply_VERB': 5,
#  'ceilings_SUBST': 4,
#  'subsequently_ADV': 26,
#  'challenged_VERB': 11,
#  'found_VERB': 401,
#  'wanting_ADJ': 4,
#  'entire_ADJ': 41,
#  'titles_SUBST': 23,
#  'won_VERB': 66,
#  'forfeited_VERB': 1,
#  'International_ADJ': 66,
#  'requires_VERB': 49,
#  'passport_SUBST': 7,
#  'date_SUBST': 64,
#  'birth_SUBST': 57,
#  'eliminates_VERB': 2,
#  'ineligible_ADJ': 1,
#  'grounds_SUBST': 44,
#  'shows_VERB': 75,
#  'citizen_SUBST': 9,
#  'country_SUBST': 238,
#  'he_PRON': 4246,
#  'represents_VERB': 30,
#  'karateka_SUBST': 8,
#  'travelled_VERB': 10,
#  'international_ADJ': 56,
#  'took_VERB': 303,
#  'passports_SUBST': 4,
#  'Team_SUBST': 11,
#  'events_SUBST': 132,
#  'There_PRON': 737,
#  'team_SUBST': 91,
#  'individual_ADJ': 102,
#  'teams_SUBST': 20,
#  'consist_VERB': 10,
#  'plus_PREP': 33,
#  'reserve_SUBST': 7,
#  'comprise_VERB': 4,
#  'reserves_SUBST': 2,
#  'sizes_SUBST': 18,
#  'varied_VERB': 15,
#  'made_VERB': 785,
#  'odd_ADJ': 29,
#  'Fighting_VERB': 2,
#  'Before_CONJ': 19,
#  'each_ADJ': 493,
#  'match_VERB': 12,
#  'representative_SUBST': 13,
#  'hand_SUBST': 374,
#  'list_SUBST': 86,
#  'specifying_VERB': 2,
#  'submitted_VERB': 22,
#  'earlier_ADJ': 52,
#  'rounds_SUBST': 10,
#  'deemed_VERB': 11,
#  'still_ADV': 576,
#  'apply_VERB': 74,
#  'something_PRON': 514,
#  'lightly_ADV': 19,
#  'field_VERB': 3,
#  'described_VERB': 123,
#  'new_ADJ': 702,
#  'notice_SUBST': 22,
#  'fighting_SUBST': 13,
#  'Reserves_SUBST': 1,
#  'substituted_VERB': 2,
#  'discretion_SUBST': 5,
#  'coach_SUBST': 48,
#  'Generally_ADV': 8,
#  'best_ADJ': 312,
#  'send_VERB': 73,
#  'strong_ADJ': 166,
#  'opener_SUBST': 2,
#  'someone_PRON': 250,
#  'relied_VERB': 8,
#  'victory_SUBST': 14,
#  'lifts_VERB': 4,
#  'morale_SUBST': 6,
#  'encourages_VERB': 13,
#  'line_SUBST': 159,
#  'member_SUBST': 72,
#  'suspect_VERB': 25,
#  'put_VERB': 408,
#  'third_ADJ': 101,
#  'With_PREP': 152,
#  'wins_VERB': 13,
#  'already_ADV': 273,
#  'gained_VERB': 21,
#  'performers_SUBST': 11,
#  'middle_ADJ': 33,
#  'ideally_ADV': 6,
#  'suited_VERB': 26,
#  'weakest_ADJ': 3,
#  'last_ADJ': 426,
#  'called_VERB': 245,
#  'save_VERB': 44,
#  'keep_VERB': 281,
#  'good_ADJ': 709,
#  'finisher_SUBST': 1,
#  'Such_ADJ': 71,
#  'lagging_SUBST': 1,
#  'Each_ADJ': 70,
#  'short-handed_ADJ': 1,
#  'chance_SUBST': 131,
#  'win_VERB': 63,
#  'match_SUBST': 34,
#  'therefore_ADV': 156,
#  'meaningful_ADJ': 11,
#  'A_ART': 1055,
#  'successful_ADJ': 67,
#  'fights_SUBST': 3,
#  'course_SUBST': 429,
#  'unusual_ADJ': 43,
#  'short-handed_ADV': 1,
#  'stages_SUBST': 28,
#  'tempted_VERB': 15,
#  'forfeit_VERB': 1,
#  'bouts_SUBST': 13,
#  'bout_SUBST': 40,
#  'deciding_ADJ': 4,
#  'first_ADJ': 953,
#  'three/two_ADJ': 1,
#  'victories_SUBST': 3,
#  'opposing_ADJ': 10,
#  'winning_VERB': 28,
#  'attempt_SUBST': 68,
#  'withdraw_VERB': 15,
#  'remaining_ADJ': 30,
#  'team-member(s)_SUBST': 1,
#  'rewarded_VERB': 4,
#  'disqualification_SUBST': 5,
#  'sportsmanship_SUBST': 1,
#  'Sometimes_ADV': 59,
#  'delayed_VERB': 11,
#  'things_SUBST': 400,
#  'happen_VERB': 81,
#  'fast_ADV': 30,
#  'Should_VERB': 21,
#  'occur_VERB': 68,
#  'relaxing_VERB': 9,
#  'itself_PRON': 277,
#  'earshot_SUBST': 1,
#  'vital_ADJ': 73,
#  'nominates_VERB': 2,
#  'observer_SUBST': 17,
#  'monitor_VERB': 7,
#  'happening_VERB': 57,
#  'arena_SUBST': 10,
#  'Otherwise_ADV': 20,
#  'public_ADJ': 169,
#  'announcements_SUBST': 4,
#  'Any_ADJ': 64,
#  'withdraws_VERB': 2,
#  'short_ADJ': 179,
#  'whole_SUBST': 86,
#  'cancelled_VERB': 5,
#  'arrives_VERB': 10,
#  'venue_SUBST': 7,
#  'sufficient_ADJ': 47,
#  'register_VERB': 13,
#  'weigh-in_SUBST': 1,
#  'face_VERB': 76,
#  'unexpected_ADJ': 22,
#  'travel_SUBST': 19,
#  'delays_SUBST': 3,
#  'arrive_VERB': 38,
#  'progressed_VERB': 6,
#  'beyond_PREP': 98,
#  'Important_ADJ': 3,
#  'preparation_SUBST': 33,
#  'adequate_ADJ': 35,
#  'rest_SUBST': 154,
#  'night_SUBST': 258,
#  'before_ADV': 126,
#  'duty_SUBST': 46,
#  'arriving_VERB': 17,
#  'hold_SUBST': 22,
#  'current_ADJ': 74,
#  'sheet_SUBST': 33,
#  'identify_VERB': 22,
#  'competing_ADJ': 4,
#  'confirm_VERB': 14,
#  'timetable_SUBST': 3,
#  'Weight_SUBST': 4,
#  'Individual_ADJ': 3,
#  'fought_VERB': 22,
#  'weight_SUBST': 115,
#  '60_ADJ': 37,
#  'kilos_SUBST': 10,
#  '65_ADJ': 11,
#  '70_ADJ': 21,
#  '53_ADJ': 1,
#  '75_ADJ': 11,
#  '80_ADJ': 14,
#  '+_UNC': 8,
#  '+60_ADJ': 1,
#  'Open_ADJ': 24,
#  'Min._SUBST': 1,
#  '43_ADJ': 5,
#  'individuals_SUBST': 47,
#  'closely_ADV': 28,
#  'matched_VERB': 11,
#  'kilo_SUBST': 4,
#  'male_SUBST': 10,
#  '+90_ADJ': 1,
#  'category_SUBST': 27,
#  'outcome_SUBST': 17,
#  'pretty_ADJ': 22,
#  'My_PRON': 205,
#  'advice_SUBST': 159,
#  'lightweights_SUBST': 1,
#  'consider_VERB': 79,
#  'heavyweights_SUBST': 1,
#  'great_ADJ': 356,
#  'advantage_SUBST': 55,
#  'forget_VERB': 62,
#  'glass_SUBST': 370,
#  'water_SUBST': 204,
#  'tip_VERB': 5,
#  'At_PREP': 325,
#  'every_ART': 361,
#  'working_VERB': 170,
#  'hard_ADV': 84,
#  'sweat_VERB': 3,
#  'off_PREP': 164,
#  're-weigh_SUBST': 1,
#  'Usually_ADV': 29,
#  'lost_VERB': 125,
#  'totally_ADV': 46,
#  'fatigued_VERB': 1,
#  'An_ART': 173,
#  'diuretic_SUBST': 1,
#  'reduce_VERB': 69,
#  'constitutes_VERB': 16,
#  'drug-taking_SUBST': 5,
#  'lifetime_SUBST': 15,
#  'ban_SUBST': 11,
#  'few_ADJ': 435,
#  'grams_SUBST': 1,
#  'legitimately_ADV': 2,
#  'shed_VERB': 8,
#  'stripping_VERB': 4,
#  'undershorts_SUBST': 1,
#  'T_SUBST': 10,
#  'shirts_SUBST': 18,
#  'weighs_VERB': 3,
#  'accurate_ADJ': 37,
#  'scales_SUBST': 7,
#  'warns_VERB': 8,
#  'marginals_SUBST': 2,
#  'care_SUBST': 206,
#  'Normally_ADV': 7,
#  're-weigh_VERB': 1,
#  'another_ADJ': 507,
#  'set_SUBST': 88,
#  'believe_VERB': 175,
#  'reading_VERB': 67,
#  'heavy_ADJ': 101,
#  'Documentation_SUBST': 1,
#  'bring_VERB': 135,
#  'required_ADJ': 9,
#  'documentation_SUBST': 6,
#  'For_PREP': 420,
#  'example_SUBST': 302,
#  'British_ADJ': 267,
#  'require_VERB': 46,
#  'produce_VERB': 111,
#  'Martial_ADJ': 4,
#  'Arts_SUBST': 33,
#  'Commission_SUBST': 28,
#  'licence_SUBST': 12,
#  'faces_SUBST': 63,
#  'sidelined_VERB': 1,
#  'forgetting_VERB': 11,
#  'requirement_SUBST': 18,
#  'properly_ADV': 54,
#  'prepared_VERB': 46,
#  'unissued_ADJ': 1,
#  'licences_SUBST': 1,
#  'along_ADV': 119,
#  'forgotten_VERB': 40,
#  'theirs_PRON': 13,
#  'contest_SUBST': 9,
#  'Karate_SUBST': 3,
#  'two-minute_ADJ': 1,
#  'extended_VERB': 19,
#  'minutes_SUBST': 110,
#  'taken_VERB': 261,
#  'pauses_SUBST': 2,
#  'counted_VERB': 14,
#  'defines_VERB': 7,
#  'extent_SUBST': 41,
#  'stamina_SUBST': 9,
#  'programme_SUBST': 78,
#  'develop_VERB': 75,
#  'maintaining_VERB': 16,
#  'relentless_ADJ': 1,
#  'powerful_ADJ': 84,
#  'onslaught_SUBST': 4,
#  'whole_ADJ': 201,
#  'Aim_VERB': 5,
#  'margin_SUBST': 46,
#  'allowing_VERB': 39,
#  'further_ADJ': 163,
#  'death_SUBST': 196,
#  'extension_SUBST': 25,
#  'there_PRON': 1499,
#  'pause_SUBST': 20,
#  'minute_SUBST': 51,
#  'successive_ADJ': 12,
#  'Bout_SUBST': 1,
#  'bell_SUBST': 33,
#  'hear_VERB': 102,
#  '30_ADJ': 61,
#  'seconds_SUBST': 56,
#  'warning_SUBST': 26,
#  ...}

# %% [markdown]
# # WORD AND TAG DISTRIBUTION IN THE CORPUS

# %%
word_f = {}
tag_f = {}

reader = open("train_data.txt", "r")

for line in reader:
    components = line.split("_")     # split the word_tag by '_'
    word_f[components[0]] = word_f.get(components[0], 0) + 1     # update word frequency
    tag_f[components[1].strip()] = tag_f.get(components[1].strip(), 0) + 1       # update tag frequency
    
reader.close()

# %%
# get the 10 most used words
sorted_word = sorted(word_f.items(), key = lambda x : x[1])
sorted_word.reverse()
sorted_word[:10]
# Out:
# [('the', 46249),
#  ('of', 25860),
#  ('to', 23320),
#  ('and', 22704),
#  ('a', 19111),
#  ('in', 14513),
#  ('is', 10777),
#  ('I', 8428),
#  ('that', 7996),
#  ('it', 7087)]

# %%
# get the 10 most used tags
sorted_tags = sorted(tag_f.items(), key = lambda x : x[1])
sorted_tags.reverse()
sorted_tags[:10]
# Out:
# [('SUBST', 211526),
#  ('VERB', 159864),
#  ('PREP', 110905),
#  ('ADJ', 98153),
#  ('ART', 76658),
#  ('PRON', 75307),
#  ('ADV', 59998),
#  ('CONJ', 51824),
#  ('UNC', 6664),
#  ('INTERJ', 1249)]

# %% [markdown]
# # COMPUTE PROBABILITIES

# %%
probab_w_t = {}

for key in freq:
    components = key.split("_")
    probab_w_t[key] = freq.get(key)/word_f.get(components[0])
    
probab_w_t
# Out:
# {'USING_VERB': 1.0,
#  'THE_ART': 1.0,
#  'RULES_SUBST': 1.0,
#  'TO_PREP': 1.0,
#  'HELP_VERB': 0.29411764705882354,
#  'YOU_PRON': 1.0,
#  'WIN_VERB': 1.0,
#  'It_PRON': 0.9976503759398496,
#  'is_VERB': 1.0,
#  'surprising_ADJ': 1.0,
#  'how_ADV': 1.0,
#  'many_ADJ': 1.0,
#  'people_SUBST': 1.0,
#  'take_VERB': 0.9965811965811966,
#  'part_SUBST': 0.9957081545064378,
#  'in_PREP': 0.9652725142975264,
#  'competition_SUBST': 1.0,
#  'without_PREP': 0.9935622317596566,
#  'knowing_VERB': 0.9054054054054054,
#  'the_ART': 1.0,
#  'rules_SUBST': 0.984375,
#  'even_ADV': 0.995221027479092,
#  'at_PREP': 1.0,
#  'élite_UNC': 1.0,
#  'level_SUBST': 0.8524590163934426,
#  'This_ADJ': 0.9991496598639455,
#  'chapter_SUBST': 1.0,
#  'will_VERB': 0.9819324430479183,
#  'examine_VERB': 1.0,
#  'of_PREP': 1.0,
#  'from_PREP': 1.0,
#  'competitors_SUBST': 1.0,
#  "'_UNC": 1.0,
#  'point_SUBST': 0.905511811023622,
#  'view_SUBST': 0.9279279279279279,
#  'rather_ADV': 1.0,
#  'than_CONJ': 1.0,
#  'referees_SUBST': 1.0,
#  'show_VERB': 0.6445497630331753,
#  'a_ART': 0.9977499869185286,
#  'knowledge_SUBST': 1.0,
#  'can_VERB': 0.9956060051263274,
#  'be_VERB': 1.0,
#  'used_VERB': 0.9152542372881356,
#  'to_PREP': 0.9999571183533448,
#  'help_VERB': 0.5971370143149284,
#  'your_PRON': 1.0,
#  'tournament_SUBST': 1.0,
#  'training_SUBST': 0.9416666666666667,
#  'by_PREP': 0.9917076962943768,
#  'outlining_VERB': 1.0,
#  'following_ADJ': 0.6047904191616766,
#  'kind_SUBST': 0.9686274509803922,
#  'fitness_SUBST': 1.0,
#  'requirements_SUBST': 1.0,
#  'you_PRON': 1.0,
#  'need_VERB': 0.7610474631751227,
#  'most_ADV': 0.6423267326732673,
#  'often_ADV': 1.0,
#  'scored_VERB': 1.0,
#  'techniques_SUBST': 1.0,
#  'explaining_VERB': 1.0,
#  'why_ADV': 1.0,
#  'they_PRON': 1.0,
#  'failed_VERB': 0.9310344827586207,
#  'score_VERB': 0.41935483870967744,
#  'when_CONJ': 0.7972972972972973,
#  'felt_VERB': 0.9879032258064516,
#  'should_VERB': 1.0,
#  'have_VERB': 1.0,
#  'injuries_SUBST': 1.0,
#  'are_VERB': 1.0,
#  'dealt_VERB': 1.0,
#  'with_PREP': 1.0,
#  'ensure_VERB': 1.0,
#  'that_CONJ': 0.7293646823411706,
#  'any_ADJ': 0.9768732654949122,
#  'complaint_SUBST': 1.0,
#  'make_VERB': 0.9941451990632318,
#  'correctly_ADV': 1.0,
#  'The_ART': 1.0,
#  'area_SUBST': 1.0,
#  'In_PREP': 0.9984813971146546,
#  'principle_SUBST': 1.0,
#  'this_ADJ': 0.9978334880841845,
#  '8m_SUBST': 1.0,
#  'x_PREP': 0.23255813953488372,
#  '9.5yd_SUBST': 1.0,
#  'but_CONJ': 0.9861212563915267,
#  'practice_SUBST': 0.9942857142857143,
#  'it_PRON': 0.9997177931423734,
#  'may_VERB': 1.0,
#  'shrink_VERB': 1.0,
#  'only_ADV': 0.8772908366533865,
#  '7m_SUBST': 1.0,
#  '8.3yd_SUBST': 1.0,
#  'order_SUBST': 0.9596774193548387,
#  'fit_VERB': 0.6464646464646465,
#  'enough_ADJ': 0.23433242506811988,
#  'areas_SUBST': 1.0,
#  'available_ADJ': 1.0,
#  'space_SUBST': 0.9831932773109243,
#  'Many_ADJ': 1.0,
#  'organisers_SUBST': 1.0,
#  'miscalculate_VERB': 1.0,
#  'entry_SUBST': 1.0,
#  'levels_SUBST': 1.0,
#  'result_SUBST': 0.6994219653179191,
#  'adjacent_ADJ': 1.0,
#  'crowded_VERB': 0.3333333333333333,
#  'together_ADV': 1.0,
#  'and_CONJ': 1.0,
#  'safety_SUBST': 1.0,
#  'imperilled_VERB': 1.0,
#  'Often_ADV': 1.0,
#  'run-off_SUBST': 1.0,
#  'zone_SUBST': 1.0,
#  'missing_VERB': 0.7575757575757576,
#  'one_ADJ': 0.6334047109207709,
#  'metre_SUBST': 1.0,
#  'band_SUBST': 1.0,
#  'marked_VERB': 0.6571428571428571,
#  'inside_PREP': 0.4383561643835616,
#  'outer_ADJ': 1.0,
#  'perimeter_SUBST': 1.0,
#  'sometimes_ADV': 1.0,
#  'highlighted_VERB': 1.0,
#  'using_VERB': 1.0,
#  'different_ADJ': 1.0,
#  'coloured_ADJ': 0.8275862068965517,
#  'mats_SUBST': 1.0,
#  'its_PRON': 1.0,
#  'purpose_SUBST': 1.0,
#  'alert_VERB': 0.391304347826087,
#  'approach_VERB': 0.13970588235294118,
#  'mat_SUBST': 1.0,
#  'boundary_SUBST': 1.0,
#  'Since_CONJ': 0.6527777777777778,
#  'pick_VERB': 0.9491525423728814,
#  'up_ADV': 0.9693121693121693,
#  'penalties_SUBST': 1.0,
#  'for_PREP': 0.9710891655932447,
#  'stepping_VERB': 1.0,
#  'out_ADV': 0.9963041182682154,
#  'inadvertently_ADV': 1.0,
#  'makes_VERB': 0.9834254143646409,
#  'sense_SUBST': 0.976027397260274,
#  'get_VERB': 1.0,
#  'used_ADJ': 0.0847457627118644,
#  'sparring_VERB': 0.5,
#  'competition-sized_ADJ': 1.0,
#  'square_SUBST': 0.5263157894736842,
#  'very_ADV': 0.9253875968992248,
#  'important_ADJ': 1.0,
#  'because_CONJ': 1.0,
#  'tactically-minded_ADJ': 1.0,
#  'competitor_SUBST': 1.0,
#  'crowd_VERB': 0.024390243902439025,
#  'an_ART': 1.0,
#  'inexperienced_ADJ': 1.0,
#  'opponent_SUBST': 1.0,
#  'picking_VERB': 1.0,
#  'points_SUBST': 0.7204301075268817,
#  'exchanging_VERB': 1.0,
#  'technique_SUBST': 1.0,
#  'You_PRON': 1.0,
#  'must_VERB': 0.9974059662775616,
#  'always_ADV': 1.0,
#  'able_ADJ': 1.0,
#  'locate_VERB': 1.0,
#  'position_SUBST': 0.9839357429718876,
#  'within_PREP': 0.9202898550724637,
#  '8-metre_SUBST': 1.0,
#  'Normal_ADJ': 1.0,
#  'free-sparring_ADJ': 1.0,
#  'hall_SUBST': 1.0,
#  'limited_VERB': 0.4142857142857143,
#  'number_SUBST': 0.9966442953020134,
#  'there_ADV': 0.25162256615077383,
#  'so_CONJ': 0.13740886146943354,
#  'bad_ADJ': 0.9855072463768116,
#  'habits_SUBST': 1.0,
#  'through_PREP': 0.8708751793400287,
#  'uneconomically_ADV': 1.0,
#  'Therefore_ADV': 1.0,
#  'do_VERB': 0.9985387238188017,
#  'all_ADV': 0.0962360992301112,
#  'final_ADJ': 0.8129032258064516,
#  '8_ADJ': 1.0,
#  'm_SUBST': 1.0,
#  'x_SUBST': 0.6744186046511628,
#  '9.5_ADJ': 1.0,
#  'yd_SUBST': 0.7272727272727273,
#  'exactly_ADV': 1.0,
#  'where_CONJ': 0.4662337662337662,
#  'Safety_SUBST': 1.0,
#  'Virtually_ADV': 1.0,
#  'all_ADJ': 0.9037639007698888,
#  'now_ADV': 0.9989878542510121,
#  'takes_VERB': 0.9929078014184397,
#  'place_SUBST': 0.9434697855750487,
#  'on_PREP': 0.8609022556390977,
#  'since_CONJ': 0.5912408759124088,
#  'hard_ADJ': 0.6530612244897959,
#  'floors_SUBST': 1.0,
#  'known_VERB': 0.9424778761061947,
#  'present_VERB': 0.20526315789473684,
#  'hazard_SUBST': 1.0,
#  'falling_ADJ': 0.03125,
#  'However_ADV': 1.0,
#  'themselves_PRON': 1.0,
#  'pose_VERB': 0.5,
#  'hazards_SUBST': 1.0,
#  'as_ADV': 0.08695652173913043,
#  'well_ADJ': 0.03773584905660377,
#  'if_CONJ': 1.0,
#  'aware_ADJ': 1.0,
#  'these_ADJ': 1.0,
#  'Firstly_ADV': 1.0,
#  'modules_SUBST': 1.0,
#  'come_VERB': 1.0,
#  'apart_ADV': 1.0,
#  'referee_SUBST': 1.0,
#  'fails_VERB': 1.0,
#  'notice_VERB': 0.6333333333333333,
#  'injured_VERB': 0.2857142857142857,
#  'his_PRON': 1.0,
#  'foot_SUBST': 0.9893048128342246,
#  'slips_VERB': 0.7142857142857143,
#  'into_PREP': 1.0,
#  'gap_SUBST': 1.0,
#  'Broken_ADJ': 0.5,
#  'ankles_SUBST': 1.0,
#  'not_ADV': 1.0,
#  'uncommon_ADJ': 1.0,
#  'karate_SUBST': 1.0,
#  'Secondly_ADV': 1.0,
#  'some_ADJ': 1.0,
#  'sticky_ADJ': 1.0,
#  'preventing_VERB': 1.0,
#  'feet_SUBST': 1.0,
#  'sliding_VERB': 0.6666666666666666,
#  'easily_ADV': 1.0,
#  'over_PREP': 0.5182555780933062,
#  'them_PRON': 1.0,
#  'throw_VERB': 0.975609756097561,
#  'roundhouse_SUBST': 1.0,
#  'kick_SUBST': 0.8623188405797102,
#  'supporting_ADJ': 0.5652173913043478,
#  'prevented_VERB': 1.0,
#  'swivelling_VERB': 1.0,
#  'Finally_ADV': 1.0,
#  'spongy_ADJ': 1.0,
#  'requiring_VERB': 1.0,
#  'lift_VERB': 0.3684210526315789,
#  'well_ADV': 0.9622641509433962,
#  'clear_ADJ': 0.8869565217391304,
#  'before_PREP': 0.4444444444444444,
#  'Obviously_ADV': 1.0,
#  'know_VERB': 1.0,
#  'advance_SUBST': 0.7045454545454546,
#  'which_PRON': 1.0,
#  'type_SUBST': 0.9724137931034482,
#  'particular_ADJ': 0.9915966386554622,
#  'just_ADV': 0.9841101694915254,
#  'feel_SUBST': 0.046875,
#  'then_ADV': 0.9951690821256038,
#  'try_VERB': 0.9849056603773585,
#  'use_VERB': 0.5532710280373832,
#  'free_ADJ': 0.9681818181818181,
#  'time_SUBST': 0.9936753338018272,
#  'actual_ADJ': 1.0,
#  'little_ADJ': 0.7516447368421053,
#  'beforehand_ADV': 1.0,
#  'Some_ADJ': 1.0,
#  'competitions_SUBST': 1.0,
#  'provide_VERB': 1.0,
#  'warm-up_SUBST': 1.0,
#  'matted_VERB': 0.3333333333333333,
#  'same_ADJ': 1.0,
#  'material_SUBST': 0.9829059829059829,
#  'as_CONJ': 0.5957062962294786,
#  'Check_VERB': 1.0,
#  'Get_VERB': 1.0,
#  'those_ADJ': 1.0,
#  'who_PRON': 1.0,
#  'sit_VERB': 1.0,
#  'down_ADV': 0.888641425389755,
#  'so_ADV': 0.8625911385305665,
#  'emergency_SUBST': 1.0,
#  'services_SUBST': 1.0,
#  'across_PREP': 0.8266666666666667,
#  'move_VERB': 0.7611940298507462,
#  'quickly_ADV': 1.0,
#  'event_SUBST': 1.0,
#  'accident_SUBST': 1.0,
#  'such_ADJ': 1.0,
#  'as_PREP': 0.31733718203139094,
#  'pillars_SUBST': 1.0,
#  'radiators_SUBST': 1.0,
#  'chairs_SUBST': 1.0,
#  'or_CONJ': 1.0,
#  'bags_SUBST': 1.0,
#  'near_PREP': 0.7295081967213115,
#  'anything_PRON': 1.0,
#  'fact_SUBST': 1.0,
#  'that_ADJ': 0.2671335667833917,
#  'might_VERB': 0.9881656804733728,
#  'cause_VERB': 0.48299319727891155,
#  'injury_SUBST': 1.0,
#  'ploughed_VERB': 0.5,
#  'speed_SUBST': 0.9502762430939227,
#  'Clothing_SUBST': 1.0,
#  'Ensure_VERB': 1.0,
#  'turned_VERB': 0.9848484848484849,
#  'clean_ADJ': 0.8,
#  'white_ADJ': 0.9375,
#  'karategi_SUBST': 1.0,
#  'open_ADJ': 0.6572769953051644,
#  'tears_SUBST': 0.9743589743589743,
#  'rips_SUBST': 1.0,
#  'Coloured_ADJ': 1.0,
#  'gis_SUBST': 1.0,
#  'black_ADJ': 0.9281767955801105,
#  'edging_SUBST': 0.7692307692307693,
#  'stripes_SUBST': 1.0,
#  'normally_ADV': 1.0,
#  'permitted_VERB': 0.8235294117647058,
#  'sleeves_SUBST': 1.0,
#  'least_ADV': 0.9739884393063584,
#  'mid-way_ADV': 1.0,
#  'forearm_SUBST': 1.0,
#  'folded_VERB': 0.75,
#  'lead_VERB': 0.7792207792207793,
#  'Similarly_ADV': 1.0,
#  'trousers_SUBST': 1.0,
#  'shins_SUBST': 1.0,
#  'fraying_ADJ': 1.0,
#  'edges_SUBST': 1.0,
#  'whip_VERB': 0.4,
#  "'s_UNC": 0.6833861644601902,
#  'eyes_SUBST': 1.0,
#  'intend_VERB': 1.0,
#  'wear_VERB': 0.9423076923076923,
#  'badge_SUBST': 1.0,
#  'being_VERB': 0.9636608344549125,
#  'strictly_ADV': 1.0,
#  'interpreted_VERB': 0.9565217391304348,
#  'single_ADJ': 1.0,
#  'national_ADJ': 1.0,
#  'association_SUBST': 1.0,
#  'identifying_ADJ': 0.07692307692307693,
#  'red_SUBST': 0.19375,
#  'belt_SUBST': 1.0,
#  'either_ADV': 0.821917808219178,
#  'normal_ADJ': 1.0,
#  'grade_SUBST': 1.0,
#  'addition_SUBST': 1.0,
#  'Japanese_ADJ': 0.9444444444444444,
#  'word_SUBST': 1.0,
#  'aka_SUBST': 1.0,
#  'shiro_VERB': 0.5,
#  'Remember_VERB': 1.0,
#  'bearing_VERB': 0.7857142857142857,
#  'mind_SUBST': 0.8325471698113207,
#  'like_PREP': 0.749098774333093,
#  'has_VERB': 1.0,
#  'three_ADJ': 1.0,
#  'letters_SUBST': 1.0,
#  'while_CONJ': 0.8200455580865603,
#  'shiro_ADJ': 0.5,
#  'five_ADJ': 1.0,
#  'colour_SUBST': 0.9717514124293786,
#  'assigned_VERB': 1.0,
#  'arises_VERB': 1.0,
#  'draw_SUBST': 0.18840579710144928,
#  'change_VERB': 0.46859903381642515,
#  'round_SUBST': 0.07236842105263158,
#  "n't_ADV": 1.0,
#  'go_VERB': 0.9728915662650602,
#  'went_VERB': 1.0,
#  'previously_ADV': 1.0,
#  'Make_VERB': 1.0,
#  'rule_SUBST': 0.8888888888888888,
#  'check_VERB': 0.7241379310344828,
#  'scorekeeper_SUBST': 1.0,
#  'going_VERB': 0.996268656716418,
#  'on_ADV': 0.13909774436090225,
#  'times_SUBST': 0.9900497512437811,
#  'wrong_ADJ': 0.9425287356321839,
#  'name_SUBST': 0.9166666666666666,
#  'gone_VERB': 1.0,
#  'forwards_ADV': 1.0,
#  'next_ADJ': 1.0,
#  'confused_VERB': 0.2727272727272727,
#  'was_VERB': 1.0,
#  'red_ADJ': 0.80625,
#  'Take_VERB': 1.0,
#  'off_ADV': 0.7469512195121951,
#  'after_CONJ': 0.16393442622950818,
#  'leave_VERB': 0.9634146341463414,
#  'wo_VERB': 1.0,
#  'stewards_SUBST': 1.0,
#  'chasing_VERB': 1.0,
#  'after_PREP': 0.8265027322404371,
#  'Protective_ADJ': 1.0,
#  'equipment_SUBST': 1.0,
#  'fist_SUBST': 1.0,
#  'protectors_SUBST': 1.0,
#  'approved_ADJ': 0.4,
#  'These_ADJ': 1.0,
#  'centimetre_SUBST': 1.0,
#  'padding_SUBST': 0.6666666666666666,
#  'thumb_SUBST': 1.0,
#  'fold_VERB': 0.7,
#  'in_ADV': 0.03438296699510784,
#  'safely_ADV': 1.0,
#  'Always_ADV': 1.0,
#  'train_VERB': 0.5116279069767442,
#  'mitts_SUBST': 1.0,
#  'additional_ADJ': 1.0,
#  'range_SUBST': 0.9766081871345029,
#  'allow_VERB': 1.0,
#  'experience_VERB': 0.1132596685082873,
#  'what_PRON': 1.0,
#  'acceptable_ADJ': 1.0,
#  'impact_SUBST': 1.0,
#  'feels_VERB': 0.9767441860465116,
#  'Never_ADV': 1.0,
#  'heavily_ADV': 1.0,
#  'padded_ADJ': 0.7272727272727273,
#  'rely_VERB': 1.0,
#  'upon_PREP': 1.0,
#  'extra_ADJ': 0.9809523809523809,
#  'cushioning_SUBST': 1.0,
#  'effect_SUBST': 0.9497206703910615,
#  'version_SUBST': 1.0,
#  'shin/instep_SUBST': 1.0,
#  'early_ADV': 0.21656050955414013,
#  'whether_CONJ': 1.0,
#  'allowed_VERB': 1.0,
#  'information_SUBST': 1.0,
#  'contained_VERB': 1.0,
#  'details_SUBST': 0.9894736842105263,
#  'accompany_VERB': 1.0,
#  'application_SUBST': 1.0,
#  'form_SUBST': 0.7975460122699386,
#  'If_CONJ': 1.0,
#  'missing_ADJ': 0.24242424242424243,
#  'when_ADV': 0.20270270270270271,
#  'contact_VERB': 0.47368421052631576,
#  'organiser_SUBST': 1.0,
#  'find_VERB': 0.9978813559322034,
#  'Then_ADV': 1.0,
#  'tailor_VERB': 0.5,
#  'accordingly_ADV': 1.0,
#  'Shin/instep_SUBST': 1.0,
#  'close_VERB': 0.15789473684210525,
#  'velcro_SUBST': 1.0,
#  'more_ADV': 0.6540682414698162,
#  'tube_SUBST': 1.0,
#  'variety_SUBST': 1.0,
#  'greater_ADJ': 1.0,
#  'leeway_SUBST': 1.0,
#  'soon_ADV': 1.0,
#  'difference_SUBST': 1.0,
#  'sudden_ADJ': 0.9148936170212766,
#  'switch_SUBST': 0.3333333333333333,
#  'between_PREP': 0.9972337482710927,
#  'two_ADJ': 1.0,
#  'Although_CONJ': 1.0,
#  'groin_SUBST': 1.0,
#  'guards_SUBST': 1.0,
#  'mandatory_ADJ': 1.0,
#  'male_ADJ': 0.7560975609756098,
#  'no_ART': 0.8485868102288021,
#  'way_SUBST': 1.0,
#  'checking_VERB': 0.9629629629629629,
#  'worn_VERB': 0.9583333333333334,
#  'receive_VERB': 1.0,
#  'discovered_VERB': 0.9821428571428571,
#  'wearing_VERB': 0.975,
#  'guard_SUBST': 0.9516129032258065,
#  'automatically_ADV': 1.0,
#  'disqualified_VERB': 1.0,
#  'regardless_ADV': 1.0,
#  'whose_PRON': 1.0,
#  'fault_SUBST': 0.95,
#  'low_ADJ': 0.9441340782122905,
#  'Do_VERB': 1.0,
#  'plastic_SUBST': 1.0,
#  'cups_SUBST': 0.8888888888888888,
#  'slip_VERB': 0.43333333333333335,
#  'inside_ADV': 0.3835616438356164,
#  'jock_VERB': 1.0,
#  'straps_SUBST': 1.0,
#  'Not_ADV': 1.0,
#  'shatter_VERB': 1.0,
#  'been_VERB': 1.0,
#  'nip_VERB': 1.0,
#  'parts_SUBST': 0.9905660377358491,
#  'straying_VERB': 1.0,
#  'outside_ADV': 0.28921568627450983,
#  'incoming_ADJ': 1.0,
#  'struck_VERB': 1.0,
#  'home_ADV': 0.32873563218390806,
#  'Buy_VERB': 1.0,
#  'boxing-type_ADJ': 1.0,
#  'instead_ADV': 1.0,
#  'Female_ADJ': 0.6,
#  'contestants_SUBST': 1.0,
#  'advised_VERB': 1.0,
#  'sanitary_ADJ': 1.0,
#  'towel_SUBST': 1.0,
#  'protect_VERB': 1.0,
#  'perineum_SUBST': 1.0,
#  'I_PRON': 0.9948979591836735,
#  'never_ADV': 1.0,
#  'arise_VERB': 1.0,
#  'breasts_SUBST': 1.0,
#  'more_ADJ': 0.3459317585301837,
#  'their_PRON': 1.0,
#  'fair_ADJ': 0.9714285714285714,
#  'share_SUBST': 0.25,
#  'impacts_SUBST': 1.0,
#  'both_ADV': 0.601063829787234,
#  'during_PREP': 1.0,
#  'close_ADJ': 0.583732057416268,
#  'frequently_ADV': 1.0,
#  'attacked_VERB': 1.0,
#  'scoring_VERB': 0.25806451612903225,
#  'less_ADV': 0.7323529411764705,
#  'protected_VERB': 0.8518518518518519,
#  'follows_VERB': 1.0,
#  'chest_SUBST': 1.0,
#  'ought_VERB': 1.0,
#  'compulsory_ADJ': 1.0,
#  'female_ADJ': 0.7894736842105263,
#  'shields_SUBST': 1.0,
#  'cover_VERB': 0.7125,
#  'am_VERB': 0.9939024390243902,
#  'happy_ADJ': 1.0,
#  'seen_VERB': 1.0,
#  'would_VERB': 1.0,
#  'advise_VERB': 1.0,
#  'buy_VERB': 1.0,
#  'World_SUBST': 1.0,
#  'Taekwondo_SUBST': 1.0,
#  'Federation_SUBST': 1.0,
#  'WTF_SUBST': 1.0,
#  'jacket_SUBST': 1.0,
#  'sparring_SUBST': 0.5,
#  'much_ADV': 0.43370508054522927,
#  'effective_ADJ': 1.0,
#  'muting_VERB': 1.0,
#  'breast_SUBST': 1.0,
#  'shield_SUBST': 0.4,
#  'though_CONJ': 0.8653465346534653,
#  'proper_ADJ': 1.0,
#  'removes_VERB': 1.0,
#  'much_ADJ': 0.5662949194547707,
#  'risk_SUBST': 0.8305084745762712,
#  'pre-competition_ADJ': 1.0,
#  'firm_ADJ': 0.5423728813559322,
#  'bra_SUBST': 1.0,
#  'means_SUBST': 0.3892857142857143,
#  'protection_SUBST': 1.0,
#  'does_VERB': 1.0,
#  'hold_VERB': 0.8503401360544217,
#  'ca_VERB': 1.0,
#  'freely_ADV': 1.0,
#  'under_PREP': 0.9625550660792952,
#  'my_PRON': 1.0,
#  'bras_SUBST': 1.0,
#  'capable_ADJ': 1.0,
#  'causing_VERB': 1.0,
#  'damage_SUBST': 0.7640449438202247,
#  'trapping_VERB': 1.0,
#  'tissue_SUBST': 1.0,
#  'rib_SUBST': 1.0,
#  'cage_SUBST': 1.0,
#  'blow_SUBST': 0.5185185185185185,
#  'Choose_VERB': 1.0,
#  'feel_VERB': 0.953125,
#  'best_ADV': 0.19794344473007713,
#  'suits_VERB': 0.391304347826087,
#  'become_VERB': 1.0,
#  'use_SUBST': 0.44672897196261685,
#  'constrictions_SUBST': 1.0,
#  'causes_VERB': 0.7954545454545454,
#  'also_ADV': 1.0,
#  'plain_ADJ': 0.6388888888888888,
#  'T-shirt_SUBST': 1.0,
#  'beneath_PREP': 0.972972972972973,
#  'jackets_SUBST': 1.0,
#  'Spectacles_SUBST': 1.0,
#  'see_VERB': 1.0,
#  'enough_ADV': 0.7656675749318801,
#  'want_VERB': 0.9956331877729258,
#  'compete_VERB': 1.0,
#  'anyway_ADV': 1.0,
#  'pair_SUBST': 0.9387755102040817,
#  'soft_ADJ': 1.0,
#  'contact_SUBST': 0.5263157894736842,
#  'lenses_SUBST': 1.0,
#  'manage_VERB': 1.0,
#  'glasses_SUBST': 1.0,
#  'Contact_VERB': 0.9,
#  'lost_ADJ': 0.17218543046357615,
#  'bear_VERB': 0.7758620689655172,
#  'before_CONJ': 0.3713450292397661,
#  'spend_VERB': 0.9807692307692307,
#  'hefty_ADJ': 1.0,
#  'sum_SUBST': 0.9629629629629629,
#  'about_PREP': 0.8460732984293193,
#  'landing_VERB': 0.21323529411764705,
#  'controlled_ADJ': 0.3225806451612903,
#  'shortsighted_ADJ': 1.0,
#  'danger_SUBST': 1.0,
#  'opponents_SUBST': 1.0,
#  'sweatband_SUBST': 1.0,
#  'jewellery_SUBST': 1.0,
#  'earrings_SUBST': 1.0,
#  'necklaces_SUBST': 1.0,
#  'bracelets_SUBST': 1.0,
#  'rings_SUBST': 0.7272727272727273,
#  'Smooth_ADJ': 1.0,
#  'removed_VERB': 1.0,
#  'taped_VERB': 0.75,
#  'over_ADV': 0.4817444219066937,
#  'remove_VERB': 0.9705882352941176,
#  'otherwise_ADV': 1.0,
#  'dangerous_ADJ': 1.0,
#  'ring_SUBST': 0.5357142857142857,
#  'opinion_SUBST': 1.0,
#  'disbarred_VERB': 1.0,
#  'Sikh_ADJ': 1.0,
#  'prior_ADJ': 1.0,
#  'Chief_ADJ': 0.6,
#  'Referee_SUBST': 1.0,
#  'modified_ADJ': 0.42857142857142855,
#  'ritual_ADJ': 0.375,
#  'headgear_SUBST': 1.0,
#  'Long_ADJ': 0.2916666666666667,
#  'hair_SUBST': 1.0,
#  'held_VERB': 0.9955357142857143,
#  'back_ADV': 0.7311827956989247,
#  'elastic_ADJ': 1.0,
#  'clasps_SUBST': 0.5,
#  'metal_SUBST': 1.0,
#  'grips_SUBST': 1.0,
#  'fingernails_SUBST': 1.0,
#  'toenails_SUBST': 1.0,
#  'cut_VERB': 0.7843137254901961,
#  'short_ADV': 0.037037037037037035,
#  'Organization_SUBST': 1.0,
#  'Sparring_VERB': 1.0,
#  'divided_VERB': 0.85,
#  'categories_SUBST': 1.0,
#  'Men_SUBST': 1.0,
#  'Senior_ADJ': 1.0,
#  '21_ADJ': 1.0,
#  'years_SUBST': 1.0,
#  'age_SUBST': 0.9931972789115646,
#  'day_SUBST': 1.0,
#  'Women_SUBST': 1.0,
#  '18_ADJ': 1.0,
#  'junior_ADJ': 0.9166666666666666,
#  'below_ADV': 0.5887096774193549,
#  'Male_ADJ': 0.8,
#  'Cadets_SUBST': 1.0,
#  '16_ADJ': 1.0,
#  'Juniors_SUBST': 1.0,
#  'fight_VERB': 0.7307692307692307,
#  'associations_SUBST': 1.0,
#  '12_ADJ': 1.0,
#  'year_SUBST': 1.0,
#  'olds_SUBST': 1.0,
#  'Coaches_SUBST': 1.0,
#  'generally_ADV': 1.0,
#  'asked_VERB': 1.0,
#  'give_VERB': 1.0,
#  'undertaking_SUBST': 0.625,
#  'entries_SUBST': 1.0,
#  'comply_VERB': 1.0,
#  'ceilings_SUBST': 1.0,
#  'subsequently_ADV': 1.0,
#  'challenged_VERB': 1.0,
#  'found_VERB': 1.0,
#  'wanting_ADJ': 0.125,
#  'entire_ADJ': 1.0,
#  'titles_SUBST': 1.0,
#  'won_VERB': 1.0,
#  'forfeited_VERB': 1.0,
#  'International_ADJ': 1.0,
#  'requires_VERB': 1.0,
#  'passport_SUBST': 1.0,
#  'date_SUBST': 0.8888888888888888,
#  'birth_SUBST': 1.0,
#  'eliminates_VERB': 1.0,
#  'ineligible_ADJ': 1.0,
#  'grounds_SUBST': 1.0,
#  'shows_VERB': 0.8064516129032258,
#  'citizen_SUBST': 1.0,
#  'country_SUBST': 1.0,
#  'he_PRON': 0.9997645396750647,
#  'represents_VERB': 1.0,
#  'karateka_SUBST': 1.0,
#  'travelled_VERB': 1.0,
#  'international_ADJ': 1.0,
#  'took_VERB': 1.0,
#  'passports_SUBST': 1.0,
#  'Team_SUBST': 1.0,
#  'events_SUBST': 1.0,
#  'There_PRON': 0.976158940397351,
#  'team_SUBST': 0.9891304347826086,
#  'individual_ADJ': 0.7132867132867133,
#  'teams_SUBST': 0.9523809523809523,
#  'consist_VERB': 1.0,
#  'plus_PREP': 0.9166666666666666,
#  'reserve_SUBST': 0.6363636363636364,
#  'comprise_VERB': 1.0,
#  'reserves_SUBST': 1.0,
#  'sizes_SUBST': 1.0,
#  'varied_VERB': 0.45454545454545453,
#  'made_VERB': 1.0,
#  'odd_ADJ': 1.0,
#  'Fighting_VERB': 1.0,
#  'Before_CONJ': 0.4523809523809524,
#  'each_ADJ': 1.0,
#  'match_VERB': 0.2608695652173913,
#  'representative_SUBST': 0.7222222222222222,
#  'hand_SUBST': 0.9894179894179894,
#  'list_SUBST': 0.9052631578947369,
#  'specifying_VERB': 1.0,
#  'submitted_VERB': 1.0,
#  'earlier_ADJ': 0.49523809523809526,
#  'rounds_SUBST': 1.0,
#  'deemed_VERB': 1.0,
#  'still_ADV': 0.9504950495049505,
#  'apply_VERB': 1.0,
#  'something_PRON': 1.0,
#  'lightly_ADV': 1.0,
#  'field_VERB': 0.016574585635359115,
#  'described_VERB': 1.0,
#  'new_ADJ': 1.0,
#  'notice_SUBST': 0.36666666666666664,
#  'fighting_SUBST': 0.4642857142857143,
#  'Reserves_SUBST': 1.0,
#  'substituted_VERB': 1.0,
#  'discretion_SUBST': 1.0,
#  'coach_SUBST': 0.9411764705882353,
#  'Generally_ADV': 1.0,
#  'best_ADJ': 0.8020565552699229,
#  'send_VERB': 1.0,
#  'strong_ADJ': 0.9940119760479041,
#  'opener_SUBST': 1.0,
#  'someone_PRON': 0.9960159362549801,
#  'relied_VERB': 1.0,
#  'victory_SUBST': 1.0,
#  'lifts_VERB': 0.23529411764705882,
#  'morale_SUBST': 1.0,
#  'encourages_VERB': 1.0,
#  'line_SUBST': 0.9754601226993865,
#  'member_SUBST': 1.0,
#  'suspect_VERB': 0.78125,
#  'put_VERB': 1.0,
#  'third_ADJ': 1.0,
#  'With_PREP': 1.0,
#  'wins_VERB': 0.8125,
#  'already_ADV': 1.0,
#  'gained_VERB': 1.0,
#  'performers_SUBST': 1.0,
#  'middle_ADJ': 0.3793103448275862,
#  'ideally_ADV': 1.0,
#  'suited_VERB': 1.0,
#  'weakest_ADJ': 1.0,
#  'last_ADJ': 0.9342105263157895,
#  'called_VERB': 0.9919028340080972,
#  'save_VERB': 1.0,
#  'keep_VERB': 0.9929328621908127,
#  'good_ADJ': 0.9620081411126187,
#  'finisher_SUBST': 1.0,
#  'Such_ADJ': 1.0,
#  'lagging_SUBST': 0.5,
#  'Each_ADJ': 1.0,
#  'short-handed_ADJ': 0.5,
#  'chance_SUBST': 1.0,
#  'win_VERB': 0.9545454545454546,
#  'match_SUBST': 0.7391304347826086,
#  'therefore_ADV': 1.0,
#  'meaningful_ADJ': 1.0,
#  'A_ART': 0.910267471958585,
#  'successful_ADJ': 1.0,
#  'fights_SUBST': 0.42857142857142855,
#  'course_SUBST': 1.0,
#  'unusual_ADJ': 1.0,
#  'short-handed_ADV': 0.5,
#  'stages_SUBST': 0.9655172413793104,
#  'tempted_VERB': 1.0,
#  'forfeit_VERB': 1.0,
#  'bouts_SUBST': 1.0,
#  'bout_SUBST': 1.0,
#  'deciding_ADJ': 0.19047619047619047,
#  'first_ADJ': 1.0,
#  'three/two_ADJ': 1.0,
#  'victories_SUBST': 1.0,
#  'opposing_ADJ': 0.6666666666666666,
#  'winning_VERB': 0.7567567567567568,
#  'attempt_SUBST': 0.7391304347826086,
#  'withdraw_VERB': 1.0,
#  'remaining_ADJ': 0.7317073170731707,
#  'team-member(s)_SUBST': 1.0,
#  'rewarded_VERB': 1.0,
#  'disqualification_SUBST': 1.0,
#  'sportsmanship_SUBST': 1.0,
#  'Sometimes_ADV': 1.0,
#  'delayed_VERB': 0.7857142857142857,
#  'things_SUBST': 1.0,
#  'happen_VERB': 1.0,
#  'fast_ADV': 0.379746835443038,
#  'Should_VERB': 1.0,
#  'occur_VERB': 1.0,
#  'relaxing_VERB': 0.8181818181818182,
#  'itself_PRON': 1.0,
#  'earshot_SUBST': 1.0,
#  'vital_ADJ': 1.0,
#  'nominates_VERB': 1.0,
#  'observer_SUBST': 1.0,
#  'monitor_VERB': 0.875,
#  'happening_VERB': 0.9193548387096774,
#  'arena_SUBST': 1.0,
#  'Otherwise_ADV': 1.0,
#  'public_ADJ': 0.7041666666666667,
#  'announcements_SUBST': 1.0,
#  'Any_ADJ': 1.0,
#  'withdraws_VERB': 1.0,
#  'short_ADJ': 0.9470899470899471,
#  'whole_SUBST': 0.29965156794425085,
#  'cancelled_VERB': 1.0,
#  'arrives_VERB': 1.0,
#  'venue_SUBST': 1.0,
#  'sufficient_ADJ': 1.0,
#  'register_VERB': 0.5652173913043478,
#  'weigh-in_SUBST': 1.0,
#  'face_VERB': 0.19047619047619047,
#  'unexpected_ADJ': 1.0,
#  'travel_SUBST': 0.41304347826086957,
#  'delays_SUBST': 0.75,
#  'arrive_VERB': 1.0,
#  'progressed_VERB': 1.0,
#  'beyond_PREP': 0.9074074074074074,
#  'Important_ADJ': 1.0,
#  'preparation_SUBST': 1.0,
#  'adequate_ADJ': 1.0,
#  'rest_SUBST': 0.8700564971751412,
#  'night_SUBST': 1.0,
#  'before_ADV': 0.18421052631578946,
#  'duty_SUBST': 1.0,
#  'arriving_VERB': 1.0,
#  'hold_SUBST': 0.14965986394557823,
#  'current_ADJ': 0.9367088607594937,
#  'sheet_SUBST': 1.0,
#  'identify_VERB': 1.0,
#  'competing_ADJ': 0.25,
#  'confirm_VERB': 1.0,
#  'timetable_SUBST': 1.0,
#  'Weight_SUBST': 1.0,
#  'Individual_ADJ': 1.0,
#  'fought_VERB': 1.0,
#  'weight_SUBST': 1.0,
#  '60_ADJ': 1.0,
#  'kilos_SUBST': 1.0,
#  '65_ADJ': 1.0,
#  '70_ADJ': 1.0,
#  '53_ADJ': 1.0,
#  '75_ADJ': 1.0,
#  '80_ADJ': 1.0,
#  '+_UNC': 1.0,
#  '+60_ADJ': 1.0,
#  'Open_ADJ': 0.96,
#  'Min._SUBST': 1.0,
#  '43_ADJ': 1.0,
#  'individuals_SUBST': 1.0,
#  'closely_ADV': 1.0,
#  'matched_VERB': 0.9166666666666666,
#  'kilo_SUBST': 1.0,
#  'male_SUBST': 0.24390243902439024,
#  '+90_ADJ': 1.0,
#  'category_SUBST': 1.0,
#  'outcome_SUBST': 1.0,
#  'pretty_ADJ': 0.36666666666666664,
#  'My_PRON': 1.0,
#  'advice_SUBST': 1.0,
#  'lightweights_SUBST': 1.0,
#  'consider_VERB': 1.0,
#  'heavyweights_SUBST': 1.0,
#  'great_ADJ': 1.0,
#  'advantage_SUBST': 1.0,
#  'forget_VERB': 1.0,
#  'glass_SUBST': 0.9973045822102425,
#  'water_SUBST': 0.9902912621359223,
#  'tip_VERB': 0.13513513513513514,
#  'At_PREP': 1.0,
#  'every_ART': 1.0,
#  'working_VERB': 0.7359307359307359,
#  'hard_ADV': 0.34285714285714286,
#  'sweat_VERB': 0.16666666666666666,
#  'off_PREP': 0.25,
#  're-weigh_SUBST': 0.5,
#  'Usually_ADV': 1.0,
#  'lost_VERB': 0.8278145695364238,
#  'totally_ADV': 1.0,
#  'fatigued_VERB': 1.0,
#  'An_ART': 1.0,
#  'diuretic_SUBST': 0.5,
#  'reduce_VERB': 1.0,
#  'constitutes_VERB': 1.0,
#  'drug-taking_SUBST': 1.0,
#  'lifetime_SUBST': 1.0,
#  'ban_SUBST': 0.7857142857142857,
#  'few_ADJ': 1.0,
#  'grams_SUBST': 1.0,
#  'legitimately_ADV': 1.0,
#  'shed_VERB': 0.47058823529411764,
#  'stripping_VERB': 1.0,
#  'undershorts_SUBST': 1.0,
#  'T_SUBST': 0.47619047619047616,
#  'shirts_SUBST': 1.0,
#  'weighs_VERB': 1.0,
#  'accurate_ADJ': 1.0,
#  'scales_SUBST': 0.875,
#  'warns_VERB': 1.0,
#  'marginals_SUBST': 1.0,
#  'care_SUBST': 0.8174603174603174,
#  'Normally_ADV': 1.0,
#  're-weigh_VERB': 0.5,
#  'another_ADJ': 1.0,
#  'set_SUBST': 0.24858757062146894,
#  'believe_VERB': 1.0,
#  'reading_VERB': 0.5075757575757576,
#  'heavy_ADJ': 1.0,
#  'Documentation_SUBST': 1.0,
#  'bring_VERB': 1.0,
#  'required_ADJ': 0.09473684210526316,
#  'documentation_SUBST': 1.0,
#  'For_PREP': 0.8879492600422833,
#  'example_SUBST': 1.0,
#  'British_ADJ': 1.0,
#  'require_VERB': 1.0,
#  'produce_VERB': 0.9173553719008265,
#  'Martial_ADJ': 1.0,
#  'Arts_SUBST': 1.0,
#  'Commission_SUBST': 1.0,
#  'licence_SUBST': 1.0,
#  'faces_SUBST': 0.8289473684210527,
#  'sidelined_VERB': 1.0,
#  'forgetting_VERB': 1.0,
#  'requirement_SUBST': 1.0,
#  'properly_ADV': 1.0,
#  'prepared_VERB': 0.40350877192982454,
#  'unissued_ADJ': 1.0,
#  'licences_SUBST': 1.0,
#  'along_ADV': 0.5666666666666667,
#  'forgotten_VERB': 0.9523809523809523,
#  'theirs_PRON': 1.0,
#  'contest_SUBST': 0.6923076923076923,
#  'Karate_SUBST': 1.0,
#  'two-minute_ADJ': 1.0,
#  'extended_VERB': 0.7037037037037037,
#  'minutes_SUBST': 1.0,
#  'taken_VERB': 0.9961832061068703,
#  'pauses_SUBST': 0.6666666666666666,
#  'counted_VERB': 1.0,
#  'defines_VERB': 1.0,
#  'extent_SUBST': 1.0,
#  'stamina_SUBST': 1.0,
#  'programme_SUBST': 1.0,
#  'develop_VERB': 1.0,
#  'maintaining_VERB': 1.0,
#  'relentless_ADJ': 1.0,
#  'powerful_ADJ': 1.0,
#  'onslaught_SUBST': 1.0,
#  'whole_ADJ': 0.7003484320557491,
#  'Aim_VERB': 1.0,
#  'margin_SUBST': 1.0,
#  'allowing_VERB': 1.0,
#  'further_ADJ': 0.6174242424242424,
#  'death_SUBST': 1.0,
#  'extension_SUBST': 1.0,
#  'there_PRON': 0.7483774338492262,
#  'pause_SUBST': 0.9090909090909091,
#  'minute_SUBST': 0.9272727272727272,
#  'successive_ADJ': 1.0,
#  'Bout_SUBST': 1.0,
#  'bell_SUBST': 1.0,
#  'hear_VERB': 1.0,
#  '30_ADJ': 1.0,
#  'seconds_SUBST': 1.0,
#  'warning_SUBST': 0.8387096774193549,
#  ...}

# %%
input_tag = input("Give tag input...")
# Out:
# Give tag input...VERB

# %%
for key in probab_w_t:
    component = key.split("_")
    if component[1] == input_tag:
        print(key,probab_w_t.get(key))
# Out:
# USING_VERB 1.0
# HELP_VERB 0.29411764705882354
# WIN_VERB 1.0
# is_VERB 1.0
# take_VERB 0.9965811965811966
# knowing_VERB 0.9054054054054054
# will_VERB 0.9819324430479183
# examine_VERB 1.0
# show_VERB 0.6445497630331753
# can_VERB 0.9956060051263274
# be_VERB 1.0
# used_VERB 0.9152542372881356
# help_VERB 0.5971370143149284
# outlining_VERB 1.0
# need_VERB 0.7610474631751227
# scored_VERB 1.0
# explaining_VERB 1.0
# failed_VERB 0.9310344827586207
# score_VERB 0.41935483870967744
# felt_VERB 0.9879032258064516
# should_VERB 1.0
# have_VERB 1.0
# are_VERB 1.0
# dealt_VERB 1.0
# ensure_VERB 1.0
# make_VERB 0.9941451990632318
# may_VERB 1.0
# shrink_VERB 1.0
# fit_VERB 0.6464646464646465
# miscalculate_VERB 1.0
# crowded_VERB 0.3333333333333333
# imperilled_VERB 1.0
# missing_VERB 0.7575757575757576
# marked_VERB 0.6571428571428571
# highlighted_VERB 1.0
# using_VERB 1.0
# alert_VERB 0.391304347826087
# approach_VERB 0.13970588235294118
# pick_VERB 0.9491525423728814
# stepping_VERB 1.0
# makes_VERB 0.9834254143646409
# get_VERB 1.0
# sparring_VERB 0.5
# crowd_VERB 0.024390243902439025
# picking_VERB 1.0
# exchanging_VERB 1.0
# must_VERB 0.9974059662775616
# locate_VERB 1.0
# limited_VERB 0.4142857142857143
# do_VERB 0.9985387238188017
# takes_VERB 0.9929078014184397
# known_VERB 0.9424778761061947
# present_VERB 0.20526315789473684
# pose_VERB 0.5
# come_VERB 1.0
# fails_VERB 1.0
# notice_VERB 0.6333333333333333
# injured_VERB 0.2857142857142857
# slips_VERB 0.7142857142857143
# preventing_VERB 1.0
# sliding_VERB 0.6666666666666666
# throw_VERB 0.975609756097561
# prevented_VERB 1.0
# swivelling_VERB 1.0
# requiring_VERB 1.0
# lift_VERB 0.3684210526315789
# know_VERB 1.0
# try_VERB 0.9849056603773585
# use_VERB 0.5532710280373832
# provide_VERB 1.0
# matted_VERB 0.3333333333333333
# Check_VERB 1.0
# Get_VERB 1.0
# sit_VERB 1.0
# move_VERB 0.7611940298507462
# might_VERB 0.9881656804733728
# cause_VERB 0.48299319727891155
# ploughed_VERB 0.5
# Ensure_VERB 1.0
# turned_VERB 0.9848484848484849
# permitted_VERB 0.8235294117647058
# folded_VERB 0.75
# lead_VERB 0.7792207792207793
# whip_VERB 0.4
# intend_VERB 1.0
# wear_VERB 0.9423076923076923
# being_VERB 0.9636608344549125
# interpreted_VERB 0.9565217391304348
# shiro_VERB 0.5
# Remember_VERB 1.0
# bearing_VERB 0.7857142857142857
# has_VERB 1.0
# assigned_VERB 1.0
# arises_VERB 1.0
# change_VERB 0.46859903381642515
# go_VERB 0.9728915662650602
# went_VERB 1.0
# Make_VERB 1.0
# check_VERB 0.7241379310344828
# going_VERB 0.996268656716418
# gone_VERB 1.0
# confused_VERB 0.2727272727272727
# was_VERB 1.0
# Take_VERB 1.0
# leave_VERB 0.9634146341463414
# wo_VERB 1.0
# chasing_VERB 1.0
# fold_VERB 0.7
# train_VERB 0.5116279069767442
# allow_VERB 1.0
# experience_VERB 0.1132596685082873
# feels_VERB 0.9767441860465116
# rely_VERB 1.0
# allowed_VERB 1.0
# contained_VERB 1.0
# accompany_VERB 1.0
# contact_VERB 0.47368421052631576
# find_VERB 0.9978813559322034
# tailor_VERB 0.5
# close_VERB 0.15789473684210525
# checking_VERB 0.9629629629629629
# worn_VERB 0.9583333333333334
# receive_VERB 1.0
# discovered_VERB 0.9821428571428571
# wearing_VERB 0.975
# disqualified_VERB 1.0
# Do_VERB 1.0
# slip_VERB 0.43333333333333335
# jock_VERB 1.0
# shatter_VERB 1.0
# been_VERB 1.0
# nip_VERB 1.0
# straying_VERB 1.0
# struck_VERB 1.0
# Buy_VERB 1.0
# advised_VERB 1.0
# protect_VERB 1.0
# arise_VERB 1.0
# attacked_VERB 1.0
# scoring_VERB 0.25806451612903225
# protected_VERB 0.8518518518518519
# follows_VERB 1.0
# ought_VERB 1.0
# cover_VERB 0.7125
# am_VERB 0.9939024390243902
# seen_VERB 1.0
# would_VERB 1.0
# advise_VERB 1.0
# buy_VERB 1.0
# muting_VERB 1.0
# removes_VERB 1.0
# does_VERB 1.0
# hold_VERB 0.8503401360544217
# ca_VERB 1.0
# causing_VERB 1.0
# trapping_VERB 1.0
# Choose_VERB 1.0
# feel_VERB 0.953125
# suits_VERB 0.391304347826087
# become_VERB 1.0
# causes_VERB 0.7954545454545454
# see_VERB 1.0
# want_VERB 0.9956331877729258
# compete_VERB 1.0
# manage_VERB 1.0
# Contact_VERB 0.9
# bear_VERB 0.7758620689655172
# spend_VERB 0.9807692307692307
# landing_VERB 0.21323529411764705
# removed_VERB 1.0
# taped_VERB 0.75
# remove_VERB 0.9705882352941176
# disbarred_VERB 1.0
# held_VERB 0.9955357142857143
# cut_VERB 0.7843137254901961
# Sparring_VERB 1.0
# divided_VERB 0.85
# fight_VERB 0.7307692307692307
# asked_VERB 1.0
# give_VERB 1.0
# comply_VERB 1.0
# challenged_VERB 1.0
# found_VERB 1.0
# won_VERB 1.0
# forfeited_VERB 1.0
# requires_VERB 1.0
# eliminates_VERB 1.0
# shows_VERB 0.8064516129032258
# represents_VERB 1.0
# travelled_VERB 1.0
# took_VERB 1.0
# consist_VERB 1.0
# comprise_VERB 1.0
# varied_VERB 0.45454545454545453
# made_VERB 1.0
# Fighting_VERB 1.0
# match_VERB 0.2608695652173913
# specifying_VERB 1.0
# submitted_VERB 1.0
# deemed_VERB 1.0
# apply_VERB 1.0
# field_VERB 0.016574585635359115
# described_VERB 1.0
# substituted_VERB 1.0
# send_VERB 1.0
# relied_VERB 1.0
# lifts_VERB 0.23529411764705882
# encourages_VERB 1.0
# suspect_VERB 0.78125
# put_VERB 1.0
# wins_VERB 0.8125
# gained_VERB 1.0
# suited_VERB 1.0
# called_VERB 0.9919028340080972
# save_VERB 1.0
# keep_VERB 0.9929328621908127
# win_VERB 0.9545454545454546
# tempted_VERB 1.0
# forfeit_VERB 1.0
# winning_VERB 0.7567567567567568
# withdraw_VERB 1.0
# rewarded_VERB 1.0
# delayed_VERB 0.7857142857142857
# happen_VERB 1.0
# Should_VERB 1.0
# occur_VERB 1.0
# relaxing_VERB 0.8181818181818182
# nominates_VERB 1.0
# monitor_VERB 0.875
# happening_VERB 0.9193548387096774
# withdraws_VERB 1.0
# cancelled_VERB 1.0
# arrives_VERB 1.0
# register_VERB 0.5652173913043478
# face_VERB 0.19047619047619047
# arrive_VERB 1.0
# progressed_VERB 1.0
# arriving_VERB 1.0
# identify_VERB 1.0
# confirm_VERB 1.0
# fought_VERB 1.0
# matched_VERB 0.9166666666666666
# consider_VERB 1.0
# forget_VERB 1.0
# tip_VERB 0.13513513513513514
# working_VERB 0.7359307359307359
# sweat_VERB 0.16666666666666666
# lost_VERB 0.8278145695364238
# fatigued_VERB 1.0
# reduce_VERB 1.0
# constitutes_VERB 1.0
# shed_VERB 0.47058823529411764
# stripping_VERB 1.0
# weighs_VERB 1.0
# warns_VERB 1.0
# re-weigh_VERB 0.5
# believe_VERB 1.0
# reading_VERB 0.5075757575757576
# bring_VERB 1.0
# require_VERB 1.0
# produce_VERB 0.9173553719008265
# sidelined_VERB 1.0
# forgetting_VERB 1.0
# prepared_VERB 0.40350877192982454
# forgotten_VERB 0.9523809523809523
# extended_VERB 0.7037037037037037
# taken_VERB 0.9961832061068703
# counted_VERB 1.0
# defines_VERB 1.0
# develop_VERB 1.0
# maintaining_VERB 1.0
# Aim_VERB 1.0
# allowing_VERB 1.0
# hear_VERB 1.0
# confuse_VERB 1.0
# wait_VERB 0.9565217391304348
# stop_VERB 0.8409090909090909
# drop_VERB 0.8
# step_VERB 0.25
# generates_VERB 1.0
# achieves_VERB 1.0
# given_VERB 0.9446640316205533
# look_VERB 0.7740492170022372
# award_VERB 0.30434782608695654
# awarded_VERB 1.0
# considered_VERB 0.978494623655914
# meet_VERB 1.0
# merit_VERB 0.42857142857142855
# relaxes_VERB 1.0
# say_VERB 0.9884488448844885
# upgraded_VERB 1.0
# catch_VERB 0.9183673469387755
# attacks_VERB 0.24
# deflecting_VERB 1.0
# follow_VERB 1.0
# deliver_VERB 1.0
# sounds_VERB 0.37777777777777777
# accepted_VERB 0.8695652173913043
# Notice_VERB 0.8461538461538461
# calling_VERB 0.8378378378378378
# allows_VERB 1.0
# continue_VERB 1.0
# delivered_VERB 1.0
# matter_VERB 0.15048543689320387
# steps_VERB 0.06451612903225806
# strikes_VERB 0.5625
# happens_VERB 1.0
# missed_VERB 0.9629629629629629
# appear_VERB 1.0
# snap_VERB 0.20512820512820512
# recognise_VERB 1.0
# judge_VERB 0.6333333333333333
# remain_VERB 1.0
# circling_VERB 1.0
# end_VERB 0.13
# thumps_VERB 1.0
# disallowed_VERB 1.0
# conclude_VERB 1.0
# thinks_VERB 1.0
# benefit_VERB 0.2719298245614035
# decided_VERB 0.9791666666666666
# compared_VERB 1.0
# ties_VERB 0.38461538461538464
# selects_VERB 1.0
# determines_VERB 1.0
# team_VERB 0.010869565217391304
# select_VERB 0.8461538461538461
# broken_VERB 0.5769230769230769
# note_VERB 0.30303030303030304
# incurred_VERB 1.0
# carried_VERB 1.0
# means_VERB 0.6107142857142858
# lose_VERB 1.0
# prohibited_VERB 0.5
# aimed_VERB 1.0
# applied_VERB 0.8641975308641975
# Note_VERB 0.9166666666666666
# classed_VERB 1.0
# running_VERB 0.7368421052631579
# bounded_VERB 0.3333333333333333
# strike_VERB 0.5185185185185185
# intended_VERB 0.8947368421052632
# regard_VERB 0.6111111111111112
# regarded_VERB 1.0
# damage_VERB 0.23595505617977527
# penalised_VERB 1.0
# Compare_VERB 1.0
# looks_VERB 0.8936170212765957
# fluttering_VERB 0.8
# land_VERB 0.3564356435643564
# claim_VERB 0.45161290322580644
# control_VERB 0.17716535433070865
# done_VERB 1.0
# concerns_VERB 0.47368421052631576
# controlled_VERB 0.6774193548387096
# caused_VERB 1.0
# result_VERB 0.30057803468208094
# winding_VERB 0.6
# count_VERB 0.7619047619047619
# floored_VERB 1.0
# Face_VERB 0.8333333333333334
# defined_VERB 0.975
# extending_VERB 1.0
# said_VERB 0.9994931576279777
# appears_VERB 1.0
# following_VERB 0.3413173652694611
# moves_VERB 0.6363636363636364
# applying_VERB 1.0
# kicks_VERB 0.2413793103448276
# encouraged_VERB 1.0
# were_VERB 1.0
# could_VERB 1.0
# exaggerate_VERB 1.0
# tell_VERB 1.0
# happened_VERB 1.0
# disallowing_VERB 1.0
# impose_VERB 1.0
# feigning_VERB 1.0
# seem_VERB 1.0
# deciding_VERB 0.8095238095238095
# disallow_VERB 1.0
# restrict_VERB 1.0
# maximise_VERB 1.0
# Stepping_VERB 0.6
# imposed_VERB 0.967741935483871
# carry_VERB 1.0
# had_VERB 1.0
# incur_VERB 1.0
# pushed_VERB 1.0
# thrown_VERB 1.0
# carries_VERB 1.0
# added_VERB 0.8105263157894737
# expect_VERB 1.0
# propelled_VERB 1.0
# seize_VERB 1.0
# followed_VERB 1.0
# grasp_VERB 0.4117647058823529
# engage_VERB 1.0
# earn_VERB 1.0
# fail_VERB 0.9555555555555556
# mean_VERB 0.9761904761904762
# flinging_VERB 0.8333333333333334
# act_VERB 0.5280898876404494
# occurs_VERB 1.0
# believes_VERB 1.0
# disengages_VERB 1.0
# dances_VERB 0.5
# waving_VERB 1.0
# retains_VERB 1.0
# wiped_VERB 1.0
# becomes_VERB 1.0
# loses_VERB 1.0
# expected_VERB 0.9512195121951219
# goes_VERB 1.0
# saying_VERB 0.9338235294117647
# behave_VERB 1.0
# conduct_VERB 0.3333333333333333
# fighting_VERB 0.5357142857142857
# misbehave_VERB 1.0
# withdrawn_VERB 1.0
# gives_VERB 1.0
# examines_VERB 1.0
# resulting_VERB 0.5769230769230769
# summoned_VERB 1.0
# advises_VERB 1.0
# decides_VERB 1.0
# tied_VERB 0.75
# occurred_VERB 1.0
# Winning_VERB 1.0
# protecting_VERB 1.0
# run_VERB 0.7717391304347826
# scrutinised_VERB 1.0
# screen_VERB 0.03508771929824561
# infringed_VERB 1.0
# complain_VERB 1.0
# involved_VERB 0.4421052631578947
# justified_VERB 1.0
# calls_VERB 0.5106382978723404
# overturned_VERB 1.0
# redress_VERB 0.75
# acting_VERB 0.7058823529411765
# express_VERB 0.9444444444444444
# points_VERB 0.27956989247311825
# indicates_VERB 1.0
# extends_VERB 1.0
# brings_VERB 1.0
# 'm_VERB 1.0
# refer_VERB 1.0
# draws_VERB 1.0
# beat_VERB 0.7
# acknowledged_VERB 0.8333333333333334
# developed_VERB 0.891566265060241
# admit_VERB 1.0
# like_VERB 0.2191780821917808
# point_VERB 0.09448818897637795
# saw_VERB 0.981651376146789
# defended_VERB 1.0
# beating_VERB 1.0
# caught_VERB 1.0
# standing_VERB 0.8058252427184466
# confirmed_VERB 0.9615384615384616
# circumvented_VERB 1.0
# forced_VERB 0.9285714285714286
# acknowledge_VERB 1.0
# prove_VERB 1.0
# offer_VERB 0.7737226277372263
# interpret_VERB 1.0
# assured_VERB 0.7058823529411765
# wears_VERB 1.0
# increase_VERB 0.6021505376344086
# brought_VERB 1.0
# placing_VERB 0.7857142857142857
# trying_VERB 0.9944444444444445
# needs_VERB 0.5842105263157895
# defeat_VERB 0.3157894736842105
# hope_VERB 0.6268656716417911
# staffed_VERB 1.0
# lasts_VERB 1.0
# assume_VERB 1.0
# cope_VERB 1.0
# indicated_VERB 1.0
# built_VERB 1.0
# establish_VERB 1.0
# sustain_VERB 1.0
# raise_VERB 0.896551724137931
# stave_VERB 1.0
# argue_VERB 1.0
# moving_VERB 0.9306930693069307
# further_VERB 0.015151515151515152
# ride_VERB 0.391304347826087
# selecting_VERB 1.0
# raised_VERB 0.8452380952380952
# vary_VERB 1.0
# according_VERB 1.0
# work_VERB 0.24286878565607173
# aim_VERB 0.2535211267605634
# generate_VERB 1.0
# lower_VERB 0.15862068965517243
# last_VERB 0.06359649122807018
# Count_VERB 0.6666666666666666
# multiply_VERB 1.0
# fainting_VERB 1.0
# Begin_VERB 1.0
# increasing_VERB 0.4
# staving_VERB 1.0
# begin_VERB 1.0
# easing_VERB 1.0
# recommend_VERB 1.0
# lay_VERB 0.8849557522123894
# kick_VERB 0.13768115942028986
# building_VERB 0.10483870967741936
# build_VERB 0.9024390243902439
# Work_VERB 0.5833333333333334
# raising_VERB 0.8888888888888888
# slam_VERB 1.0
# hitting_VERB 1.0
# Switch_VERB 1.0
# dropping_VERB 0.9
# rebuild_VERB 0.75
# uses_VERB 0.8666666666666667
# produced_VERB 1.0
# tolerate_VERB 1.0
# slowing_VERB 1.0
# attack_VERB 0.17894736842105263
# making_VERB 0.9477124183006536
# slow_VERB 0.18055555555555555
# hiking_VERB 1.0
# outlined_VERB 1.0
# let_VERB 1.0
# cutting_VERB 0.5833333333333334
# feature_VERB 0.07792207792207792
# bend_VERB 0.8076923076923077
# touches_VERB 0.7
# shoot_VERB 0.9
# flies_VERB 0.5238095238095238
# cheat_VERB 1.0
# droop_VERB 1.0
# jerking_VERB 0.7142857142857143
# defeats_VERB 1.0
# lie_VERB 0.7777777777777778
# introducing_VERB 1.0
# Rest_VERB 0.6666666666666666
# repeat_VERB 0.9090909090909091
# thrust_VERB 0.7631578947368421
# catches_VERB 0.9285714285714286
# returns_VERB 0.5555555555555556
# repeated_VERB 0.8285714285714286
# modify_VERB 1.0
# Kick_VERB 1.0
# Combine_VERB 1.0
# straighten_VERB 1.0
# Train_VERB 0.7142857142857143
# Stand_VERB 1.0
# clench_VERB 0.5
# holding_VERB 0.9418604651162791
# Bend_VERB 0.9411764705882353
# Perform_VERB 1.0
# squats_VERB 0.3333333333333333
# Try_VERB 1.0
# jumping_VERB 0.8333333333333334
# spring_VERB 0.10101010101010101
# jump_VERB 0.8571428571428571
# leap_VERB 0.6
# Use_VERB 0.8378378378378378
# switch_VERB 0.6666666666666666
# alternate_VERB 0.3333333333333333
# absorb_VERB 1.0
# changing_VERB 0.5333333333333333
# tucked_VERB 1.0
# curl_VERB 0.6363636363636364
# lifting_VERB 0.71875
# Increase_VERB 1.0
# strengthen_VERB 1.0
# Change_VERB 0.6666666666666666
# varying_VERB 0.25
# leading_VERB 0.32575757575757575
# settles_VERB 1.0
# Repeat_VERB 1.0
# Practise_VERB 1.0
# punching_VERB 0.46153846153846156
# throwing_VERB 1.0
# Jump_VERB 1.0
# perform_VERB 1.0
# swung_VERB 1.0
# hit_VERB 0.9272727272727272
# shown_VERB 1.0
# weaving_VERB 1.0
# adapt_VERB 1.0
# holds_VERB 1.0
# lunges_VERB 1.0
# react_VERB 1.0
# timed_VERB 1.0
# learning_VERB 0.6981132075471698
# dig_VERB 0.9
# hurting_VERB 1.0
# worked_VERB 0.991304347826087
# finish_VERB 0.46551724137931033
# Improve_VERB 1.0
# stretching_VERB 0.5862068965517241
# gain_VERB 0.7924528301886793
# helps_VERB 0.8928571428571429
# improve_VERB 1.0
# lifted_VERB 1.0
# sitting_VERB 0.9387755102040817
# kneels_VERB 1.0
# presses_VERB 0.3
# Allow_VERB 1.0
# separate_VERB 0.23529411764705882
# driving_VERB 0.8181818181818182
# avoid_VERB 1.0
# separated_VERB 0.8421052631578947
# squeeze_VERB 0.875
# resisting_VERB 1.0
# Maintain_VERB 1.0
# relax_VERB 1.0
# open_VERB 0.3333333333333333
# did_VERB 1.0
# Lie_VERB 0.9333333333333333
# keeping_VERB 0.9382716049382716
# splayed_VERB 0.5
# Lift_VERB 1.0
# produces_VERB 1.0
# Force_VERB 0.05555555555555555
# swinging_VERB 0.65625
# exceed_VERB 1.0
# aiming_VERB 1.0
# reaching_VERB 1.0
# ensuring_VERB 1.0
# maximised_VERB 1.0
# straining_VERB 1.0
# reach_VERB 0.7191011235955056
# Swing_VERB 1.0
# loosens_VERB 1.0
# concentrated_VERB 0.72
# doing_VERB 0.9311740890688259
# stretch_VERB 0.5128205128205128
# Stretch_VERB 1.0
# Controlling_VERB 1.0
# worry_VERB 0.84
# fear_VERB 0.22093023255813954
# over-aroused_VERB 1.0
# depends_VERB 1.0
# comes_VERB 1.0
# shouting_VERB 0.9473684210526315
# Sit_VERB 1.0
# Control_VERB 0.38461538461538464
# visualise_VERB 1.0
# controlling_VERB 0.8333333333333334
# knows_VERB 1.0
# realise_VERB 1.0
# imagine_VERB 1.0
# confronts_VERB 1.0
# watching_VERB 0.9743589743589743
# measuring_VERB 1.0
# prefer_VERB 1.0
# retire_VERB 1.0
# involves_VERB 1.0
# Look_VERB 0.9797979797979798
# Breathe_VERB 1.0
# pressing_VERB 0.6470588235294118
# Select_VERB 0.8
# concentrate_VERB 1.0
# Meditate_VERB 1.0
# drawn_VERB 1.0
# avoided_VERB 1.0
# nods_VERB 0.5
# 's_VERB 0.3166138355398098
# taking_VERB 0.9760479041916168
# think_VERB 0.9924357034795764
# stand_VERB 0.7938144329896907
# competing_VERB 0.75
# applies_VERB 1.0
# founder_VERB 0.09090909090909091
# results_VERB 0.15492957746478872
# marred_VERB 1.0
# pull_VERB 0.8636363636363636
# poised_VERB 0.9090909090909091
# respond_VERB 1.0
# practise_VERB 0.9333333333333333
# retreat_VERB 0.45454545454545453
# overstep_VERB 1.0
# having_VERB 1.0
# rooted_VERB 0.875
# linked_VERB 0.96
# shifted_VERB 1.0
# distributed_VERB 0.9
# flex_VERB 0.5
# possessing_VERB 1.0
# stretched_VERB 1.0
# determining_VERB 0.5
# presented_VERB 1.0
# led_VERB 1.0
# protects_VERB 1.0
# leaves_VERB 0.3114754098360656
# relaxed_VERB 0.5862068965517241
# Narrow_VERB 0.3333333333333333
# straddle_VERB 1.0
# reduces_VERB 1.0
# rests_VERB 0.7692307692307693
# Avoid_VERB 1.0
# bouncing_VERB 0.5555555555555556
# meets_VERB 1.0
# ignored_VERB 1.0
# Straddle_VERB 1.0
# restricted_VERB 0.4642857142857143
# driven_VERB 0.9545454545454546
# Guard_VERB 0.6666666666666666
# Carry_VERB 1.0
# cross_VERB 0.35185185185185186
# crosses_VERB 0.25
# favour_VERB 0.10256410256410256
# travel_VERB 0.5869565217391305
# intercept_VERB 1.0
# rest_VERB 0.12994350282485875
# flail_VERB 1.0
# cock_VERB 0.5
# Move_VERB 1.0
# achieve_VERB 1.0
# knocking_VERB 1.0
# executing_VERB 1.0
# place_VERB 0.056530214424951264
# facing_VERB 0.9782608695652174
# turn_VERB 0.5623003194888179
# launch_VERB 0.12
# twist_VERB 0.6363636363636364
# repositioning_VERB 1.0
# sound_VERB 0.23333333333333334
# Using_VERB 1.0
# succeed_VERB 1.0
# twisted_VERB 0.6666666666666666
# faces_VERB 0.17105263157894737
# scooping_VERB 0.16666666666666666
# deflected_VERB 1.0
# remains_VERB 0.92
# Consider_VERB 1.0
# times_VERB 0.004975124378109453
# coincide_VERB 1.0
# kept_VERB 1.0
# left_VERB 0.7417840375586855
# weakens_VERB 1.0
# Withdraw_VERB 1.0
# Respond_VERB 1.0
# Keep_VERB 1.0
# positioning_VERB 0.3333333333333333
# turning_VERB 0.6702127659574468
# Disguise_VERB 1.0
# exchanged_VERB 1.0
# darting_VERB 1.0
# re-calculate_VERB 1.0
# Turning_VERB 0.8461538461538461
# slide_VERB 0.5217391304347826
# zig-zag_VERB 1.0
# twisting_VERB 0.45454545454545453
# Slide_VERB 1.0
# Bring_VERB 1.0
# separates_VERB 1.0
# warning_VERB 0.16129032258064516
# divert_VERB 1.0
# jabs_VERB 0.5
# disguising_VERB 1.0
# encourage_VERB 1.0
# diverting_VERB 1.0
# disguises_VERB 1.0
# beginning_VERB 0.375
# leaving_VERB 0.967741935483871
# discover_VERB 1.0
# prepare_VERB 1.0
# punch_VERB 0.08426966292134831
# back_VERB 0.007820136852394917
# finding_VERB 0.8840579710144928
# explore_VERB 1.0
# dealing_VERB 0.9393939393939394
# Deliver_VERB 1.0
# begins_VERB 1.0
# pursue_VERB 1.0
# claiming_VERB 0.875
# performed_VERB 1.0
# deflect_VERB 1.0
# attacking_VERB 0.6470588235294118
# counter_VERB 0.2222222222222222
# Attack_VERB 1.0
# analyse_VERB 1.0
# explain_VERB 1.0
# referring_VERB 1.0
# picture_VERB 0.026845637583892617
# lies_VERB 0.6428571428571429
# covers_VERB 0.5769230769230769
# upswinging_VERB 1.0
# forcing_VERB 1.0
# loop_VERB 0.09090909090909091
# view_VERB 0.07207207207207207
# exposing_VERB 1.0
# provides_VERB 1.0
# executed_VERB 1.0
# Underline_VERB 1.0
# unified_VERB 0.4444444444444444
# miss_VERB 0.9166666666666666
# slap_VERB 0.5
# throws_VERB 1.0
# draw_VERB 0.8115942028985508
# withdrawing_VERB 0.75
# slaps_VERB 1.0
# Being_VERB 1.0
# overlooked_VERB 1.0
# counter-punching_VERB 1.0
# borne_VERB 1.0
# Pull_VERB 1.0
# falling_VERB 0.96875
# lean_VERB 0.7058823529411765
# remember_VERB 1.0
# knock_VERB 0.5882352941176471
# retrieved_VERB 1.0
# Rock_VERB 0.5
# fire_VERB 0.04807692307692308
# Finish_VERB 0.6666666666666666
# slapping_VERB 0.16666666666666666
# Thrust_VERB 1.0
# Scooping_VERB 1.0
# discussed_VERB 1.0
# fall_VERB 0.6911764705882353
# fuelled_VERB 1.0
# pushing_VERB 1.0
# Follow_VERB 1.0
# evaded_VERB 1.0
# Scoop_VERB 1.0
# drawing_VERB 0.47540983606557374
# break_VERB 0.5729166666666666
# circle_VERB 0.0967741935483871
# countered_VERB 1.0
# catching_VERB 1.0
# puts_VERB 1.0
# kicking_VERB 0.28
# coupled_VERB 1.0
# deal_VERB 0.3474576271186441
# obtained_VERB 1.0
# discerning_VERB 0.3333333333333333
# staking_VERB 1.0
# providing_VERB 1.0
# interrupting_VERB 1.0
# clear_VERB 0.1
# scoop_VERB 0.6666666666666666
# succeeds_VERB 1.0
# thrusting_VERB 0.35714285714285715
# dumps_VERB 1.0
# unbalance_VERB 1.0
# presents_VERB 0.8846153846153846
# glancing_VERB 0.6666666666666666
# Step_VERB 0.5
# Continue_VERB 1.0
# attempts_VERB 0.10810810810810811
# rotate_VERB 1.0
# rising_VERB 0.6571428571428571
# time_VERB 0.006324666198172874
# barring_VERB 0.5
# suffer_VERB 1.0
# Stop_VERB 1.0
# reverse-punching_VERB 1.0
# Forearm_VERB 1.0
# deflects_VERB 1.0
# closes_VERB 1.0
# weakened_VERB 1.0
# slowed_VERB 1.0
# pulled_VERB 1.0
# interferes_VERB 1.0
# free_VERB 0.031818181818181815
# keeps_VERB 0.9714285714285714
# closed_VERB 0.7051282051282052
# force_VERB 0.1518987341772152
# inhibits_VERB 1.0
# provided_VERB 0.7777777777777778
# duck_VERB 0.2
# barrelling_VERB 1.0
# advance_VERB 0.25
# closing_VERB 0.5294117647058824
# lengthens_VERB 1.0
# graze_VERB 1.0
# helped_VERB 1.0
# travels_VERB 0.6153846153846154
# block_VERB 0.14285714285714285
# reverse_VERB 0.08433734939759036
# shift_VERB 0.34782608695652173
# rock_VERB 0.2903225806451613
# shout_VERB 0.68
# underline_VERB 0.9
# Drop_VERB 1.0
# blocking_VERB 0.2857142857142857
# MAKING_VERB 0.6
# entails_VERB 1.0
# mentioned_VERB 1.0
# pitched_VERB 0.8571428571428571
# lacks_VERB 1.0
# emanates_VERB 1.0
# accompanying_VERB 0.2727272727272727
# describes_VERB 1.0
# explodes_VERB 1.0
# signify_VERB 1.0
# ignore_VERB 1.0
# mistaken_VERB 0.8461538461538461
# seeking_VERB 1.0
# cave_VERB 0.09090909090909091
# Be_VERB 1.0
# matches_VERB 0.1935483870967742
# seems_VERB 1.0
# Having_VERB 1.0
# weigh_VERB 1.0
# applaud_VERB 1.0
# employed_VERB 0.9411764705882353
# demonstrated_VERB 1.0
# snapped_VERB 1.0
# believed_VERB 1.0
# related_VERB 0.6296296296296297
# shall_VERB 1.0
# equate_VERB 1.0
# increases_VERB 0.64
# swivel_VERB 0.5
# decide_VERB 1.0
# beware_VERB 1.0
# diverts_VERB 1.0
# cocks_VERB 1.0
# telegraphing_VERB 1.0
# set_VERB 0.7259887005649718
# power_VERB 0.011111111111111112
# Throw_VERB 1.0
# Go_VERB 1.0
# Lean_VERB 1.0
# Withdrawing_VERB 1.0
# digging_VERB 0.7857142857142857
# cocking_VERB 0.5
# drive_VERB 0.6341463414634146
# range_VERB 0.023391812865497075
# sprained_VERB 1.0
# advances_VERB 0.1
# completed_VERB 0.9772727272727273
# Hold_VERB 1.0
# reverse-punch_VERB 1.0
# Complete_VERB 0.75
# complete_VERB 0.3333333333333333
# employs_VERB 1.0
# accompanied_VERB 1.0
# Let_VERB 1.0
# guard_VERB 0.04838709677419355
# augment_VERB 1.0
# capitalising_VERB 1.0
# Advance_VERB 0.6666666666666666
# skims_VERB 1.0
# moved_VERB 1.0
# Turn_VERB 0.7777777777777778
# Twist_VERB 1.0
# direct_VERB 0.2125
# Snap_VERB 0.6666666666666666
# tailored_VERB 0.3333333333333333
# curtails_VERB 1.0
# Dig_VERB 1.0
# Add_VERB 1.0
# unrolls_VERB 1.0
# out-range_VERB 1.0
# leads_VERB 0.9743589743589743
# flexed_VERB 1.0
# disguise_VERB 0.7272727272727273
# Flex_VERB 1.0
# thrusts_VERB 0.6666666666666666
# unroll_VERB 1.0
# slides_VERB 0.6
# Scoring_VERB 0.5
# Bear_VERB 0.5555555555555556
# increased_VERB 0.66
# training_VERB 0.058333333333333334
# convince_VERB 1.0
# stressed_VERB 1.0
# maintain_VERB 1.0
# losing_VERB 0.9487179487179487
# expecting_VERB 1.0
# aims_VERB 0.24390243902439024
# experienced_VERB 0.625
# digs_VERB 1.0
# tap_VERB 0.15789473684210525
# Draw_VERB 0.8571428571428571
# transfers_VERB 0.4
# tends_VERB 1.0
# collide_VERB 1.0
# pass_VERB 0.7755102040816326
# rises_VERB 0.6666666666666666
# bent_VERB 0.7857142857142857
# aid_VERB 0.26666666666666666
# swivels_VERB 1.0
# engages_VERB 1.0
# turns_VERB 0.6530612244897959
# drops_VERB 0.5238095238095238
# drives_VERB 0.8333333333333334
# adding_VERB 1.0
# forces_VERB 0.09574468085106383
# hooked_VERB 0.4
# swept_VERB 1.0
# reassume_VERB 1.0
# impaled_VERB 1.0
# watch_VERB 0.6582278481012658
# advancing_VERB 0.5
# renders_VERB 1.0
# exposes_VERB 1.0
# shorten_VERB 1.0
# Swivel_VERB 1.0
# fend_VERB 1.0
# hunching_VERB 1.0
# Power_VERB 0.1
# dropped_VERB 0.9591836734693877
# leaned_VERB 1.0
# hooking_VERB 0.6666666666666666
# dragging_VERB 1.0
# pointing_VERB 0.96875
# getting_VERB 1.0
# spent_VERB 0.897196261682243
# snag_VERB 1.0
# looping_VERB 1.0
# hooks_VERB 0.125
# leaning_VERB 1.0
# detect_VERB 1.0
# cannons_VERB 0.5
# clinches_VERB 1.0
# responded_VERB 1.0
# launching_VERB 0.7391304347826086
# touch_VERB 0.43636363636363634
# enjoys_VERB 1.0
# thump_VERB 0.3333333333333333
# stopped_VERB 0.989010989010989
# push_VERB 0.6944444444444444
# curling_VERB 0.8333333333333334
# falls_VERB 0.8214285714285714
# Push_VERB 1.0
# brush_VERB 0.23809523809523808
# hook_VERB 0.3548387096774194
# thuds_VERB 1.0
# defending_VERB 1.0
# add_VERB 1.0
# setting_VERB 0.7058823529411765
# giving_VERB 0.9893617021276596
# Imagine_VERB 1.0
# sees_VERB 1.0
# sweep_VERB 0.28205128205128205
# learn_VERB 1.0
# contains_VERB 1.0
# substitute_VERB 0.23809523809523808
# covering_VERB 0.9411764705882353
# SWEEPS_VERB 1.0
# sweeps_VERB 0.8
# reflected_VERB 0.9642857142857143
# sweeping_VERB 0.5714285714285714
# misses_VERB 0.6
# spin_VERB 0.2222222222222222
# waiting_VERB 0.9733333333333334
# degenerates_VERB 1.0
# pumping_VERB 0.5
# distinguish_VERB 1.0
# merges_VERB 1.0
# compare_VERB 1.0
# lands_VERB 0.15384615384615385
# launches_VERB 0.125
# evade_VERB 1.0
# descended_VERB 1.0
# presupposes_VERB 1.0
# landed_VERB 0.7692307692307693
# assuming_VERB 1.0
# swing_VERB 0.36764705882352944
# knocks_VERB 0.25
# knocked_VERB 1.0
# blur_VERB 0.2
# shifting_VERB 0.2
# Beware_VERB 1.0
# over-committing_VERB 1.0
# passes_VERB 0.8
# prevent_VERB 1.0
# degenerating_VERB 1.0
# Over-committing_VERB 1.0
# expose_VERB 1.0
# acquiring_VERB 1.0
# Have_VERB 1.0
# flexing_VERB 1.0
# Sweep_VERB 0.75
# performs_VERB 1.0
# intersects_VERB 1.0
# Provided_VERB 0.5
# reduced_VERB 0.734375
# attempt_VERB 0.2608695652173913
# planted_VERB 0.9302325581395349
# Wait_VERB 1.0
# over-commit_VERB 1.0
# reaps_VERB 1.0
# incorporating_VERB 1.0
# focused_VERB 1.0
# changed_VERB 0.9746835443037974
# putting_VERB 1.0
# alter_VERB 0.625
# progresses_VERB 1.0
# maintained_VERB 0.96
# advanced_VERB 0.4230769230769231
# clinch_VERB 0.5
# sets_VERB 0.48
# cocked_VERB 0.6666666666666666
# involve_VERB 1.0
# repeating_VERB 1.0
# Assessing_VERB 1.0
# Apply_VERB 1.0
# Does_VERB 1.0
# indicating_VERB 1.0
# adopt_VERB 1.0
# governs_VERB 1.0
# waits_VERB 1.0
# counters_VERB 0.3333333333333333
# concluding_VERB 0.4
# responds_VERB 1.0
# countering_VERB 0.6666666666666666
# backs_VERB 0.1875
# prefers_VERB 1.0
# smother_VERB 1.0
# proceed_VERB 1.0
# finds_VERB 1.0
# double_VERB 0.10526315789473684
# Put_VERB 1.0
# achieving_VERB 1.0
# achieved_VERB 1.0
# Is_VERB 1.0
# Southpaw_VERB 1.0
# Are_VERB 1.0
# grab_VERB 0.6666666666666666
# provoke_VERB 1.0
# Lash_VERB 1.0
# exploit_VERB 1.0
# Maintaining_VERB 1.0
# accrue_VERB 1.0
# reached_VERB 1.0
# lagging_VERB 0.5
# nominating_VERB 1.0
# nominate_VERB 1.0
# noticed_VERB 1.0
# organised_VERB 0.9473684210526315
# designed_VERB 0.9848484848484849
# teach_VERB 1.0
# Wear_VERB 0.8
# illustrate_VERB 1.0
# wants_VERB 1.0
# assessed_VERB 1.0
# read_VERB 1.0
# selected_VERB 0.75
# taught_VERB 1.0
# demonstrate_VERB 1.0
# works_VERB 0.327683615819209
# chosen_VERB 0.6307692307692307
# sharpens_VERB 1.0
# welds_VERB 1.0
# isolate_VERB 0.8333333333333334
# breaks_VERB 0.5
# remaining_VERB 0.2682926829268293
# refuse_VERB 1.0
# treated_VERB 1.0
# deserve_VERB 1.0
# covered_VERB 1.0
# performing_VERB 0.8461538461538461
# DEALING_VERB 1.0
# heal_VERB 0.8
# affect_VERB 1.0
# over-used_VERB 1.0
# squeezed_VERB 1.0
# mix_VERB 0.27586206896551724
# form_VERB 0.20245398773006135
# storing_VERB 1.0
# administered_VERB 1.0
# minimise_VERB 1.0
# secure_VERB 0.4074074074074074
# shrouded_VERB 1.0
# bruising_VERB 0.5
# care_VERB 0.18253968253968253
# lyobands_VERB 1.0
# discard_VERB 1.0
# Wrap_VERB 1.0
# spiral_VERB 0.8
# Remove_VERB 1.0
# smash_VERB 0.8
# bandaging_VERB 0.5
# bandage_VERB 0.15384615384615385
# arrange_VERB 1.0
# suggest_VERB 1.0
# employing_VERB 0.7142857142857143
# bandaged_VERB 1.0
# cushioned_VERB 1.0
# dressed_VERB 0.9714285714285714
# extend_VERB 1.0
# got_VERB 1.0
# wrapping_VERB 1.0
# Close_VERB 0.1
# raises_VERB 0.9444444444444444
# draining_VERB 0.6
# insist_VERB 1.0
# skewering_VERB 1.0
# encountered_VERB 1.0
# dislocated_VERB 1.0
# strap_VERB 0.3
# Clean_VERB 0.42857142857142855
# walking_VERB 0.7903225806451613
# retain_VERB 1.0
# supported_VERB 1.0
# pay_VERB 0.9301075268817204
# carrying_VERB 0.975609756097561
# attend_VERB 1.0
# manifested_VERB 1.0
# indicate_VERB 1.0
# slamming_VERB 1.0
# damaged_VERB 0.6363636363636364
# contract_VERB 0.07692307692307693
# managing_VERB 0.45
# managed_VERB 1.0
# exercises_VERB 0.0967741935483871
# builds_VERB 1.0
# helping_VERB 0.9024390243902439
# grinding_VERB 0.4444444444444444
# played_VERB 1.0
# Bandage_VERB 1.0
# reapplying_VERB 1.0
# aggravate_VERB 1.0
# stabilise_VERB 1.0
# stops_VERB 0.7941176470588235
# twists_VERB 0.42857142857142855
# placed_VERB 1.0
# continuing_VERB 0.2916666666666667
# consists_VERB 1.0
# Straining_VERB 1.0
# pulling_VERB 1.0
# Reduce_VERB 1.0
# strengthening_VERB 0.8333333333333334
# attended_VERB 0.9117647058823529
# afford_VERB 1.0
# Loosen_VERB 1.0
# start_VERB 0.6741071428571429
# swelling_VERB 0.4
# exclude_VERB 1.0
# bleed_VERB 1.0
# gauge_VERB 0.25
# stick_VERB 0.17355371900826447
# ruptured_VERB 0.5
# disfiguring_VERB 1.0
# chipped_VERB 0.6666666666666666
# loosened_VERB 1.0
# fix_VERB 0.9375
# bleeds_VERB 1.0
# tilt_VERB 1.0
# pinch_VERB 0.75
# pack_VERB 0.24
# inform_VERB 1.0
# sustained_VERB 0.5882352941176471
# mind_VERB 0.16745283018867924
# talk_VERB 0.8076923076923077
# suffered_VERB 1.0
# sustaining_VERB 1.0
# multiplied_VERB 1.0
# accept_VERB 1.0
# ensued_VERB 1.0
# report_VERB 0.2127659574468085
# recover_VERB 1.0
# tilting_VERB 1.0
# injuring_VERB 1.0
# sharpen_VERB 1.0
# dull_VERB 0.043478260869565216
# arising_VERB 1.0
# banned_VERB 0.6
# include_VERB 1.0
# contain_VERB 1.0
# test_VERB 0.23076923076923078
# entering_VERB 1.0
# detected_VERB 0.9375
# unsporting_VERB 1.0
# hurt_VERB 0.5357142857142857
# securing_VERB 1.0
# containing_VERB 1.0
# trained_VERB 0.8604651162790697
# biased_VERB 0.8
# Pare_VERB 1.0
# progress_VERB 0.1111111111111111
# conferred_VERB 1.0
# recognised_VERB 0.9642857142857143
# affiliated_VERB 0.75
# write_VERB 1.0
# enclosing_VERB 0.8
# thinking_VERB 0.671875
# Start_VERB 1.0
# decrease_VERB 0.5
# split_VERB 0.6296296296296297
# promotes_VERB 1.0
# required_VERB 0.9052631578947369
# determine_VERB 1.0
# depending_VERB 1.0
# ranges_VERB 0.625
# developing_VERB 0.6779661016949152
# stimulate_VERB 1.0
# experiment_VERB 0.24
# promote_VERB 1.0
# overtraining_VERB 1.0
# grow_VERB 1.0
# recovered_VERB 1.0
# exercised_VERB 1.0
# obtain_VERB 1.0
# twitch_VERB 0.1
# associated_VERB 0.7948717948717948
# producing_VERB 0.972972972972973
# varies_VERB 1.0
# determined_VERB 0.6739130434782609
# skipping_VERB 0.3333333333333333
# gear_VERB 0.125
# belong_VERB 1.0
# equipped_VERB 1.0
# ail_VERB 1.0
# enable_VERB 1.0
# invented_VERB 0.7692307692307693
# purchasing_VERB 0.5454545454545454
# lying_VERB 0.88
# adjusting_VERB 1.0
# emphasising_VERB 1.0
# creates_VERB 1.0
# desired_VERB 0.5
# exercising_VERB 1.0
# constitute_VERB 1.0
# structured_VERB 0.5625
# needed_VERB 1.0
# eat_VERB 1.0
# consume_VERB 1.0
# divide_VERB 0.42857142857142855
# gaining_VERB 1.0
# stored_VERB 1.0
# consuming_VERB 0.5
# adjust_VERB 1.0
# tone_VERB 0.06666666666666667
# tighten_VERB 1.0
# compensates_VERB 1.0
# repaired_VERB 1.0
# weighing_VERB 1.0
# depend_VERB 1.0
# eaten_VERB 1.0
# exceeding_VERB 1.0
# digest_VERB 1.0
# nullify_VERB 1.0
# regenerated_VERB 1.0
# formed_VERB 1.0
# supplied_VERB 1.0
# derived_VERB 1.0
# supplement_VERB 0.45454545454545453
# consumed_VERB 1.0
# stays_VERB 0.8181818181818182
# adds_VERB 1.0
# replaced_VERB 1.0
# pumped_VERB 1.0
# finished_VERB 0.8974358974358975
# disappears_VERB 1.0
# started_VERB 1.0
# restore_VERB 1.0
# feeling_VERB 0.3312883435582822
# play_VERB 0.5721925133689839
# transported_VERB 1.0
# becoming_VERB 0.9836065573770492
# remedied_VERB 1.0
# affected_VERB 0.9019607843137255
# combined_VERB 0.8571428571428571
# suffering_VERB 0.6129032258064516
# balanced_VERB 0.4666666666666667
# absorbed_VERB 1.0
# supplements_VERB 0.5
# considering_VERB 0.7142857142857143
# contributing_VERB 1.0
# enables_VERB 1.0
# removing_VERB 1.0
# inositol_VERB 1.0
# prevents_VERB 1.0
# combatting_VERB 1.0
# yeast_VERB 0.043478260869565216
# store_VERB 0.18604651162790697
# excreted_VERB 1.0
# combat_VERB 0.6666666666666666
# undertakes_VERB 1.0
# spread_VERB 0.7166666666666667
# top_VERB 0.014218009478672985
# exceeded_VERB 1.0
# attempted_VERB 0.9090909090909091
# consult_VERB 1.0
# exercise_VERB 0.0975609756097561
# Subtract_VERB 1.0
# reverts_VERB 1.0
# revert_VERB 1.0
# elapsed_VERB 1.0
# detailed_VERB 0.075
# attempting_VERB 1.0
# Touch_VERB 0.6666666666666666
# Return_VERB 0.6666666666666666
# shoulder_VERB 0.08139534883720931
# Keeping_VERB 1.0
# press_VERB 0.26506024096385544
# Lower_VERB 0.42857142857142855
# Running_VERB 0.8
# link_VERB 0.2702702702702703
# jumps_VERB 0.75
# bringing_VERB 1.0
# crouch_VERB 1.0
# touching_VERB 0.8333333333333334
# supporting_VERB 0.43478260869565216
# swap_VERB 1.0
# boring_VERB 0.13636363636363635
# inserted_VERB 1.0
# demanding_VERB 0.5625
# introduce_VERB 1.0
# enhance_VERB 1.0
# burn_VERB 0.6896551724137931
# wish_VERB 0.8818181818181818
# attained_VERB 1.0
# deals_VERB 0.7
# incorporated_VERB 1.0
# execute_VERB 1.0
# Refer_VERB 1.0
# serve_VERB 0.9166666666666666
# weighted_VERB 0.75
# filling_VERB 0.8571428571428571
# Standing_VERB 0.7142857142857143
# counts_VERB 0.6666666666666666
# Raise_VERB 1.0
# Grip_VERB 1.0
# bounce_VERB 0.4444444444444444
# assist_VERB 1.0
# concentrating_VERB 1.0
# Inhale_VERB 1.0
# breathe_VERB 1.0
# hanging_VERB 0.5555555555555556
# straightening_VERB 1.0
# sway_VERB 0.6
# Stretching_VERB 1.0
# jerk_VERB 0.5384615384615384
# head_VERB 0.021148036253776436
# Press_VERB 0.2
# detract_VERB 1.0
# unfurl_VERB 1.0
# roll_VERB 0.5882352941176471
# gripping_VERB 0.75
# crossed_VERB 0.9642857142857143
# crunch_VERB 1.0
# stretches_VERB 0.7
# straightened_VERB 1.0
# Incline_VERB 1.0
# Set_VERB 0.8571428571428571
# breathing_VERB 0.5454545454545454
# develops_VERB 1.0
# Squat_VERB 0.5
# arched_VERB 0.3333333333333333
# rounded_VERB 0.6153846153846154
# Place_VERB 0.5185185185185185
# rocking_VERB 0.5
# lowering_VERB 0.7
# bending_VERB 0.7692307692307693
# dips_VERB 0.5
# locked_VERB 0.9090909090909091
# contracted_VERB 1.0
# staying_VERB 0.9047619047619048
# warming_VERB 1.0
# composed_VERB 0.9
# filled_VERB 0.96875
# weights_VERB 0.047619047619047616
# improved_VERB 0.7222222222222222
# neglected_VERB 0.5384615384615384
# tend_VERB 1.0
# Squatting_VERB 1.0
# specialising_VERB 1.0
# rotating_VERB 0.8571428571428571
# laid_VERB 1.0
# sagging_VERB 0.3333333333333333
# isolating_VERB 1.0
# biceps_VERB 0.06666666666666667
# strapped_VERB 0.8333333333333334
# accumulates_VERB 1.0
# joins_VERB 0.75
# create_VERB 1.0
# situated_VERB 1.0
# operate_VERB 1.0
# support_VERB 0.3333333333333333
# treat_VERB 0.875
# reaches_VERB 0.9047619047619048
# iron_VERB 0.024390243902439025
# lowered_VERB 1.0
# adduct_VERB 1.0
# fades_VERB 1.0
# rectified_VERB 1.0
# Varying_VERB 1.0
# alters_VERB 1.0
# stuck_VERB 0.7096774193548387
# attached_VERB 0.9629629629629629
# emphasise_VERB 1.0
# relieve_VERB 1.0
# seeming_VERB 0.75
# enhances_VERB 1.0
# hide_VERB 1.0
# counteract_VERB 1.0
# originate_VERB 1.0
# account_VERB 0.08888888888888889
# lat_VERB 0.3333333333333333
# pulls_VERB 0.8
# created_VERB 0.9811320754716981
# Alternate_VERB 1.0
# spoiling_VERB 1.0
# triceps_VERB 0.09090909090909091
# overdeveloped_VERB 0.5
# originates_VERB 1.0
# inhibiting_VERB 1.0
# fits_VERB 0.9166666666666666
# supinate_VERB 1.0
# aiding_VERB 1.0
# omitted_VERB 1.0
# overtrain_VERB 1.0
# correcting_VERB 1.0
# overemphasised_VERB 1.0
# reducing_VERB 1.0
# tearing_VERB 1.0
# eased_VERB 1.0
# reapplied_VERB 1.0
# suggests_VERB 1.0
# attain_VERB 1.0
# hurts_VERB 1.0
# release_VERB 0.3333333333333333
# overstretch_VERB 1.0
# weightlifting_VERB 1.0
# trains_VERB 0.25
# brewed_VERB 1.0
# granted_VERB 1.0
# reserved_VERB 0.8333333333333334
# letting_VERB 1.0
# ferment_VERB 0.75
# crush_VERB 0.5
# transforming_VERB 0.75
# ends_VERB 0.3829787234042553
# harvested_VERB 1.0
# soaked_VERB 0.2857142857142857
# transferred_VERB 0.9444444444444444
# heated_VERB 0.5
# unlocked_VERB 1.0
# milled_VERB 1.0
# mixed_VERB 0.4358974358974359
# dissolve_VERB 1.0
# slotted_VERB 1.0
# sprinkled_VERB 1.0
# sparging_VERB 0.5
# boiled_VERB 0.5
# boiling_VERB 0.625
# hopped_VERB 1.0
# flows_VERB 1.0
# cooled_VERB 1.0
# fermenting_VERB 0.6666666666666666
# confronted_VERB 1.0
# sink_VERB 0.30434782608695654
# saved_VERB 0.9285714285714286
# sold_VERB 0.9555555555555556
# continues_VERB 1.0
# purge_VERB 1.0
# attract_VERB 1.0
# drag_VERB 0.3333333333333333
# racked_VERB 1.0
# brew_VERB 0.75
# filtering_VERB 1.0
# showing_VERB 0.8604651162790697
# fed_VERB 1.0
# extracted_VERB 1.0
# Fermenting_VERB 1.0
# bunged_VERB 1.0
# keg_VERB 0.35714285714285715
# Keg_VERB 1.0
# includes_VERB 1.0
# killed_VERB 1.0
# conditioned_VERB 0.5
# chilled_VERB 0.36363636363636365
# filtered_VERB 0.8888888888888888
# pasteurised_VERB 0.6
# halted_VERB 1.0
# served_VERB 1.0
# injected_VERB 1.0
# connected_VERB 0.8378378378378378
# operated_VERB 1.0
# mask_VERB 0.16666666666666666
# foisted_VERB 1.0
# passed_VERB 1.0
# imported_VERB 0.45454545454545453
# adhere_VERB 1.0
# lagered_VERB 1.0
# priced_VERB 1.0
# combines_VERB 0.875
# speeded_VERB 1.0
# cheapen_VERB 1.0
# hasten_VERB 1.0
# classified_VERB 0.875
# excluded_VERB 1.0
# list_VERB 0.09473684210526316
# drinking_VERB 0.6612903225806451
# stuffed_VERB 0.7222222222222222
# amyloglucosidase_VERB 1.0
# papain_VERB 1.0
# reveal_VERB 1.0
# accounted_VERB 1.0
# trumpet_VERB 0.5
# estimated_VERB 0.9090909090909091
# generated_VERB 1.0
# combine_VERB 0.9411764705882353
# fuel_VERB 0.024390243902439025
# serving_VERB 0.825
# IS_VERB 1.0
# FLAVOURING_VERB 1.0
# ARE_VERB 1.0
# ADDED_VERB 1.0
# KNOW_VERB 1.0
# HAVE_VERB 1.0
# CREATED_VERB 1.0
# DO_VERB 1.0
# WANT_VERB 1.0
# says_VERB 1.0
# owned_VERB 1.0
# Described_VERB 1.0
# handle_VERB 0.7105263157894737
# Depending_VERB 1.0
# drunk_VERB 0.20588235294117646
# rolled_VERB 0.9444444444444444
# tastes_VERB 0.5
# masked_VERB 0.8
# starts_VERB 1.0
# judges_VERB 0.15789473684210525
# hammers_VERB 1.0
# cask_VERB 0.043478260869565216
# interfere_VERB 1.0
# prolong_VERB 1.0
# frowns_VERB 1.0
# interfering_VERB 1.0
# Left_VERB 0.25
# considers_VERB 1.0
# matured_VERB 1.0
# delivers_VERB 1.0
# dispense_VERB 1.0
# preferred_VERB 0.6428571428571429
# measures_VERB 0.09090909090909091
# translated_VERB 1.0
# ruin_VERB 0.875
# Serving_VERB 1.0
# drank_VERB 1.0
# introduced_VERB 1.0
# ranging_VERB 1.0
# disappeared_VERB 0.9130434782608695
# flying_VERB 0.5035460992907801
# answered_VERB 1.0
# sparkling_VERB 0.7857142857142857
# established_VERB 0.8
# brewing_VERB 0.09090909090909091
# waters_VERB 0.1111111111111111
# Burtonise_VERB 1.0
# styled_VERB 1.0
# dominated_VERB 0.9545454545454546
# waned_VERB 1.0
# distinguished_VERB 0.5263157894736842
# enjoyed_VERB 1.0
# poured_VERB 0.9459459459459459
# Brewed_VERB 1.0
# stems_VERB 0.1891891891891892
# exported_VERB 0.75
# drink_VERB 0.3627450980392157
# grown_VERB 1.0
# importing_VERB 1.0
# distilling_VERB 1.0
# recalling_VERB 0.875
# clips_VERB 0.25
# derives_VERB 1.0
# primed_VERB 1.0
# promoted_VERB 1.0
# threatened_VERB 0.9047619047619048
# replace_VERB 1.0
# Met_VERB 0.6
# backed_VERB 1.0
# listed_VERB 0.7333333333333333
# grew_VERB 1.0
# became_VERB 1.0
# promoting_VERB 1.0
# unveiled_VERB 1.0
# opened_VERB 1.0
# hurried_VERB 1.0
# embrace_VERB 0.8
# please_VERB 0.15517241379310345
# based_VERB 1.0
# elected_VERB 1.0
# plan_VERB 0.24742268041237114
# grouped_VERB 1.0
# overseen_VERB 1.0
# discuss_VERB 1.0
# refashion_VERB 1.0
# lobbied_VERB 0.6666666666666666
# demands_VERB 0.2608695652173913
# challenge_VERB 0.21666666666666667
# pitch_VERB 0.5384615384615384
# preserve_VERB 0.8095238095238095
# Brewing_VERB 0.14285714285714285
# organise_VERB 1.0
# Joining_VERB 1.0
# enjoy_VERB 1.0
# demonstrating_VERB 1.0
# Offering_VERB 1.0
# Campaign_VERB 0.06896551724137931
# sent_VERB 1.0
# champions_VERB 0.125
# Brew_VERB 1.0
# playing_VERB 0.9583333333333334
# mashing_VERB 0.25
# selling_VERB 0.8461538461538461
# rinse_VERB 0.75
# pour_VERB 0.9333333333333333
# Rinse_VERB 1.0
# stir_VERB 0.5
# Top_VERB 0.3333333333333333
# Boil_VERB 1.0
# cool_VERB 0.16393442622950818
# speed_VERB 0.049723756906077346
# mutate_VERB 1.0
# skim_VERB 1.0
# gather_VERB 1.0
# collapse_VERB 0.5454545454545454
# syphon_VERB 1.0
# sterilised_VERB 1.0
# rinsed_VERB 0.5
# Saw_VERB 1.0
# insert_VERB 0.8571428571428571
# Syphon_VERB 1.0
# Fit_VERB 1.0
# Sterilise_VERB 1.0
# capping_VERB 0.5
# cleared_VERB 1.0
# chill_VERB 0.125
# rise_VERB 0.4117647058823529
# pouring_VERB 0.6
# Win_VERB 1.0
# SPEAKING_VERB 1.0
# reports_VERB 0.3125
# File_VERB 0.75
# Coaching_VERB 0.5
# Spot_VERB 0.6666666666666666
# Read_VERB 0.75
# Fed_VERB 1.0
# attends_VERB 1.0
# capture_VERB 0.47368421052631576
# mention_VERB 0.7878787878787878
# reads_VERB 1.0
# call_VERB 0.6846153846153846
# beckons_VERB 1.0
# Representing_VERB 1.0
# represented_VERB 1.0
# offered_VERB 0.9911504424778761
# donate_VERB 1.0
# announced_VERB 1.0
# contested_VERB 1.0
# host_VERB 0.19047619047619047
# founded_VERB 1.0
# purchased_VERB 1.0
# inscribed_VERB 0.8333333333333334
# Colgate_VERB 1.0
# sponsored_VERB 0.8620689655172413
# singles/doubles_VERB 1.0
# doubles_VERB 0.4
# beats_VERB 0.7
# hosted_VERB 1.0
# Ride_VERB 0.42857142857142855
# Opening_VERB 0.2
# geared_VERB 1.0
# celebrating_VERB 1.0
# invited_VERB 0.9696969696969697
# encouraging_VERB 0.3157894736842105
# representing_VERB 0.9047619047619048
# Speaking_VERB 1.0
# administering_VERB 1.0
# expressed_VERB 0.9574468085106383
# ruining_VERB 1.0
# sacrifice_VERB 0.4
# Singles_VERB 0.5
# eluded_VERB 1.0
# showed_VERB 1.0
# hated_VERB 0.95
# smashed_VERB 1.0
# wonder_VERB 0.6101694915254238
# strain_VERB 0.1111111111111111
# thought_VERB 0.7012750455373407
# financed_VERB 1.0
# gets_VERB 1.0
# sign_VERB 0.34782608695652173
# pout_VERB 1.0
# Watch_VERB 1.0
# incorporate_VERB 1.0
# tuning_VERB 1.0
# features_VERB 0.16883116883116883
# included_VERB 0.9850746268656716
# notified_VERB 1.0
# issued_VERB 1.0
# ending_VERB 0.6666666666666666
# referred_VERB 1.0
# restored_VERB 0.9230769230769231
# centred_VERB 1.0
# dying_VERB 0.6216216216216216
# dismiss_VERB 1.0
# asking_VERB 1.0
# reconciled_VERB 1.0
# dismissed_VERB 1.0
# inspire_VERB 1.0
# culminating_VERB 0.8571428571428571
# Forget_VERB 1.0
# Slams_VERB 1.0
# frustrates_VERB 1.0
# sloshing_VERB 0.5
# damaging_VERB 0.45454545454545453
# benefitting_VERB 1.0
# quoting_VERB 1.0
# insisting_VERB 1.0
# blame_VERB 0.782608695652174
# guarantees_VERB 1.0
# heard_VERB 1.0
# spurred_VERB 1.0
# doubled_VERB 1.0
# starting_VERB 0.6857142857142857
# cook_VERB 0.5862068965517241
# sponsoring_VERB 1.0
# ask_VERB 1.0
# paid_VERB 0.9473684210526315
# implying_VERB 1.0
# May_VERB 0.15384615384615385
# undergone_VERB 1.0
# coping_VERB 0.875
# recalls_VERB 1.0
# launched_VERB 1.0
# persuade_VERB 1.0
# reinstated_VERB 1.0
# died_VERB 1.0
# persuaded_VERB 1.0
# insisted_VERB 1.0
# return_VERB 0.5754716981132075
# waited_VERB 1.0
# doubted_VERB 1.0
# contributed_VERB 1.0
# wished_VERB 1.0
# commissioned_VERB 1.0
# reflects_VERB 1.0
# Providing_VERB 1.0
# agree_VERB 1.0
# agreeing_VERB 1.0
# 've_VERB 1.0
# stage_VERB 0.022727272727272728
# compensated_VERB 1.0
# qualified_VERB 0.75
# told_VERB 1.0
# judging_VERB 0.8461538461538461
# gave_VERB 1.0
# re-iterating_VERB 1.0
# 're_VERB 1.0
# join_VERB 0.9661016949152542
# survive_VERB 1.0
# Explaining_VERB 1.0
# supports_VERB 0.7142857142857143
# refusing_VERB 1.0
# signed_VERB 0.9354838709677419
# realised_VERB 1.0
# suppose_VERB 1.0
# knew_VERB 1.0
# bite_VERB 0.625
# earned_VERB 1.0
# listen_VERB 1.0
# admitted_VERB 1.0
# wanting_VERB 0.875
# suit_VERB 0.5892857142857143
# qualify_VERB 1.0
# Machine_VERB 1.0
# marches_VERB 0.6666666666666666
# came_VERB 1.0
# defeated_VERB 0.8421052631578947
# demolished_VERB 1.0
# gambled_VERB 1.0
# floundering_VERB 1.0
# lapped_VERB 1.0
# regretting_VERB 1.0
# proceeded_VERB 1.0
# defeating_VERB 1.0
# drew_VERB 1.0
# stepped_VERB 1.0
# deflate_VERB 1.0
# confirming_VERB 1.0
# located_VERB 1.0
# offering_VERB 0.8888888888888888
# servicing_VERB 0.5
# engulfed_VERB 0.6666666666666666
# devouring_VERB 1.0
# listening_VERB 0.9743589743589743
# Based_VERB 1.0
# watches_VERB 1.0
# listens_VERB 1.0
# overtaken_VERB 1.0
# fro-ing_VERB 1.0
# explains_VERB 1.0
# pays_VERB 1.0
# reporting_VERB 0.6923076923076923
# Snooker_VERB 1.0
# sponsor_VERB 0.4
# accommodating_VERB 1.0
# disagree_VERB 1.0
# contacted_VERB 1.0
# print_VERB 0.125
# teamed_VERB 1.0
# named_VERB 1.0
# photographed_VERB 1.0
# resulted_VERB 1.0
# answer_VERB 0.3939393939393939
# brand_VERB 0.125
# Name_VERB 0.46153846153846156
# Has_VERB 1.0
# emerged_VERB 1.0
# headed_VERB 0.8947368421052632
# ranked_VERB 0.42857142857142855
# See_VERB 1.0
# featured_VERB 1.0
# looking_VERB 0.9823008849557522
# seeing_VERB 0.967032967032967
# handles_VERB 0.16666666666666666
# Save_VERB 1.0
# Rally_VERB 0.5
# Pictured_VERB 1.0
# rallied_VERB 1.0
# permeate_VERB 1.0
# dot_VERB 0.16666666666666666
# costing_VERB 0.8333333333333334
# attending_VERB 1.0
# enhanced_VERB 0.5
# honed_VERB 1.0
# stormed_VERB 1.0
# operates_VERB 1.0
# maximize_VERB 1.0
# drill_VERB 0.3333333333333333
# videotaped_VERB 1.0
# charted_VERB 1.0
# Cost_VERB 0.8
# guaranteeing_VERB 1.0
# represent_VERB 1.0
# commented_VERB 1.0
# offers_VERB 0.8545454545454545
# struggled_VERB 1.0
# quit_VERB 1.0
# resort_VERB 0.6666666666666666
# crying_VERB 0.6666666666666666
# stated_VERB 0.9166666666666666
# writing_VERB 0.5493827160493827
# printed_VERB 0.47619047619047616
# receives_VERB 1.0
# breaking_VERB 0.9473684210526315
# Opens_VERB 1.0
# dare_VERB 1.0
# criticise_VERB 1.0
# proved_VERB 1.0
# belongs_VERB 1.0
# entertaining_VERB 0.2727272727272727
# seemed_VERB 1.0
# reply_VERB 0.5945945945945946
# asserted_VERB 1.0
# Graf_VERB 0.13636363636363635
# searched_VERB 1.0
# voiced_VERB 1.0
# sympathising_VERB 1.0
# blamed_VERB 1.0
# smiling_VERB 0.7037037037037037
# smiled_VERB 1.0
# titled_VERB 0.7272727272727273
# bet_VERB 0.8235294117647058
# let's_VERB 1.0
# sorted_VERB 1.0
# lob_VERB 1.0
# admits_VERB 1.0
# quote_VERB 0.6428571428571429
# coming_VERB 0.9112903225806451
# wrote_VERB 1.0
# videoed_VERB 1.0
# beaten_VERB 0.8125
# messing_VERB 1.0
# watched_VERB 1.0
# address_VERB 0.25757575757575757
# published_VERB 0.96
# Flicking_VERB 1.0
# inferred_VERB 1.0
# claimed_VERB 1.0
# accused_VERB 0.9473684210526315
# behold_VERB 1.0
# Going_VERB 1.0
# praising_VERB 1.0
# wondered_VERB 1.0
# 'll_VERB 1.0
# inundating_VERB 1.0
# disguised_VERB 0.7777777777777778
# GASP_VERB 1.0
# vindicated_VERB 1.0
# Dismissing_VERB 1.0
# emblazoned_VERB 1.0
# rested_VERB 1.0
# written_VERB 0.8563218390804598
# hearing_VERB 0.6097560975609756
# owns_VERB 1.0
# love_VERB 0.3385579937304075
# Neglected_VERB 0.5
# outline_VERB 0.19047619047619047
# indoctrinated_VERB 1.0
# crumbling_VERB 0.5
# exist_VERB 1.0
# overcome_VERB 1.0
# solve_VERB 1.0
# competed_VERB 1.0
# received_VERB 0.9876543209876543
# enabled_VERB 1.0
# construct_VERB 0.5
# approaches_VERB 0.125
# rage_VERB 0.125
# spending_VERB 0.75
# declining_VERB 0.5714285714285714
# wonders_VERB 0.46153846153846156
# relying_VERB 1.0
# unlock_VERB 1.0
# declined_VERB 1.0
# import_VERB 0.2
# begs_VERB 1.0
# Let's_VERB 1.0
# thank_VERB 1.0
# stood_VERB 1.0
# slept_VERB 1.0
# wrapped_VERB 1.0
# Will_VERB 0.6363636363636364
# telling_VERB 0.8064516129032258
# moan_VERB 1.0
# peep_VERB 1.0
# signs_VERB 0.07407407407407407
# mentions_VERB 0.8333333333333334
# grace_VERB 0.08333333333333333
# wishes_VERB 0.5217391304347826
# cared_VERB 1.0
# plays_VERB 0.3835616438356164
# lacking_VERB 1.0
# Chang_VERB 0.3
# stay_VERB 0.8732394366197183
# bowing_VERB 1.0
# reveals_VERB 1.0
# asserts_VERB 1.0
# respected_VERB 0.8125
# threw_VERB 1.0
# liked_VERB 1.0
# coached_VERB 1.0
# inherited_VERB 1.0
# loved_VERB 0.9130434782608695
# credits_VERB 0.25
# witnessed_VERB 1.0
# thwarted_VERB 1.0
# coaching_VERB 0.2857142857142857
# speak_VERB 1.0
# nodding_VERB 1.0
# broaden_VERB 1.0
# Permit_VERB 1.0
# acknowledges_VERB 1.0
# born_VERB 0.9577464788732394
# esteemed_VERB 1.0
# balance_VERB 0.11320754716981132
# returned_VERB 1.0
# focus_VERB 0.4
# compensate_VERB 1.0
# possessed_VERB 1.0
# confront_VERB 1.0
# volley_VERB 0.75
# instruct_VERB 1.0
# listened_VERB 1.0
# Did_VERB 1.0
# Was_VERB 1.0
# Were_VERB 1.0
# analyze_VERB 1.0
# Play_VERB 0.6666666666666666
# Hit_VERB 1.0
# asks_VERB 1.0
# Establish_VERB 1.0
# master_VERB 0.1
# lapse_VERB 0.25
# hustle_VERB 1.0
# struggle_VERB 0.2894736842105263
# understood_VERB 1.0
# Lendl_VERB 0.375
# 'd_VERB 1.0
# choose_VERB 1.0
# benefitted_VERB 1.0
# ironing_VERB 0.8
# sweating_VERB 0.75
# drilling_VERB 0.5
# matters_VERB 0.18181818181818182
# Rallying_VERB 1.0
# rally_VERB 0.07142857142857142
# directing_VERB 1.0
# returning_VERB 0.9545454545454546
# chase_VERB 0.6666666666666666
# pursuing_VERB 1.0
# rallying_VERB 1.0
# practised_VERB 0.6
# struggling_VERB 0.8823529411764706
# stress_VERB 0.175
# improves_VERB 1.0
# cease_VERB 1.0
# bounced_VERB 1.0
# creep_VERB 1.0
# Playing_VERB 1.0
# ceases_VERB 1.0
# appreciate_VERB 1.0
# discussing_VERB 1.0
# installed_VERB 1.0
# arrived_VERB 1.0
# disturbing_VERB 0.18181818181818182
# devoted_VERB 0.2631578947368421
# escape_VERB 0.5769230769230769
# lengthen_VERB 1.0
# challenging_VERB 0.7
# assess_VERB 1.0
# praise_VERB 0.36363636363636365
# demonstrates_VERB 1.0
# slipped_VERB 1.0
# materialise_VERB 1.0
# involving_VERB 1.0
# Cash_VERB 0.3333333333333333
# impressed_VERB 0.13636363636363635
# Trust_VERB 0.3333333333333333
# studying_VERB 0.9375
# displayed_VERB 1.0
# conceding_VERB 1.0
# ended_VERB 1.0
# disposed_VERB 0.625
# attracted_VERB 1.0
# rushing_VERB 0.875
# began_VERB 1.0
# looked_VERB 1.0
# suspended_VERB 0.8181818181818182
# continued_VERB 0.8431372549019608
# overshadowed_VERB 1.0
# resumed_VERB 1.0
# appeared_VERB 1.0
# triumphed_VERB 1.0
# reunited_VERB 1.0
# Carries_VERB 1.0
# opening_VERB 0.40625
# hits_VERB 0.75
# executes_VERB 1.0
# suspects_VERB 0.45454545454545453
# defy_VERB 1.0
# threatening_VERB 0.75
# coach_VERB 0.058823529411764705
# understated_VERB 1.0
# entered_VERB 1.0
# denied_VERB 1.0
# slumped_VERB 1.0
# fell_VERB 0.9827586206896551
# overcame_VERB 1.0
# partner_VERB 0.01639344262295082
# stamped_VERB 0.6
# dominating_VERB 0.7777777777777778
# disputing_VERB 1.0
# Wilander_VERB 1.0
# dumped_VERB 1.0
# enter_VERB 1.0
# bodied_VERB 1.0
# strengthens_VERB 1.0
# stabilizes_VERB 1.0
# consisting_VERB 1.0
# Head_VERB 0.06818181818181818
# expands_VERB 1.0
# expand_VERB 1.0
# seeded_VERB 0.6666666666666666
# joined_VERB 1.0
# proving_VERB 1.0
# singles_VERB 0.07692307692307693
# Sanctioned_VERB 1.0
# mixing_VERB 0.9090909090909091
# teaching_VERB 0.2755102040816326
# wishing_VERB 1.0
# retails_VERB 1.0
# heads_VERB 0.04411764705882353
# curtailed_VERB 1.0
# dedicated_VERB 0.75
# lives_VERB 0.21518987341772153
# acted_VERB 1.0
# satisfying_VERB 0.14285714285714285
# resolve_VERB 0.6666666666666666
# resolved_VERB 1.0
# embroidered_VERB 0.6
# coordinating_VERB 0.5
# Slazenger_VERB 0.4
# Styled_VERB 1.0
# packed_VERB 0.7307692307692307
# oriented_VERB 1.0
# shell_VERB 0.125
# cornflower_VERB 1.0
# complement_VERB 0.7777777777777778
# catered_VERB 1.0
# featuring_VERB 1.0
# wrap_VERB 1.0
# zips_VERB 1.0
# lined_VERB 0.8333333333333334
# replaces_VERB 1.0
# slipping_VERB 0.8666666666666667
# waning_VERB 0.5
# predicts_VERB 1.0
# opting_VERB 1.0
# woven_VERB 0.6
# tempt_VERB 1.0
# ...
# Slowing_VERB 1.0
# retrieve_VERB 1.0
# overtake_VERB 1.0
# brake_VERB 0.125
# Parking_VERB 0.3333333333333333
# anchored_VERB 1.0
# rolls_VERB 0.6
# fuselage_VERB 0.16666666666666666
# Cockpit_VERB 1.0
# scorned_VERB 1.0
# skip_VERB 0.6666666666666666
# strapping_VERB 0.16666666666666666
# jam_VERB 0.125
# tightening_VERB 1.0
# re-adjusted_VERB 1.0
# unlocking_VERB 1.0
# winch_VERB 0.14285714285714285
# pilot_VERB 0.00558659217877095
# semi-stalled_VERB 1.0
# Inhibiting_VERB 1.0
# severed_VERB 0.5
# Realising_VERB 1.0
# overruled_VERB 1.0
# scrapes_VERB 0.5
# exerts_VERB 1.0
# aerotowing_VERB 1.0
# weathercocking_VERB 0.4
# yaws_VERB 1.0
# pivot_VERB 1.0
# pivots_VERB 1.0
# accentuated_VERB 1.0
# overdo_VERB 1.0
# skidding_VERB 1.0
# down-load_VERB 0.5
# Steering_VERB 1.0
# steering_VERB 0.4
# co-ordinating_VERB 0.5
# rudder_VERB 0.06818181818181818
# Winch_VERB 1.0
# re-grip_VERB 1.0
# slows_VERB 1.0
# crabbing_VERB 1.0
# Launch_VERB 0.5
# kink_VERB 0.2
# parafil_VERB 0.3333333333333333
# coil_VERB 0.14285714285714285
# lowers_VERB 1.0
# safeguards_VERB 0.5
# Breaking_VERB 1.0
# Launching_VERB 1.0
# overstressing_VERB 1.0
# overload_VERB 1.0
# steepening_VERB 0.5
# stalled_VERB 0.8181818181818182
# zooming_VERB 1.0
# skid_VERB 0.5
# unsticking_VERB 1.0
# steepened_VERB 1.0
# steepen_VERB 1.0
# overspeeding_VERB 0.5
# overrunning_VERB 1.0
# Pulling_VERB 1.0
# over-reacting_VERB 1.0
# overshooting_VERB 0.8
# under-read_VERB 1.0
# buffeting_VERB 1.0
# overspeed_VERB 1.0
# yawing_VERB 0.2857142857142857
# Stall_VERB 1.0
# stalling_VERB 0.4827586206896552
# Stalling_VERB 1.0
# stalls_VERB 0.10526315789473684
# undershoot_VERB 0.625
# over-rudder_VERB 1.0
# Over-ruddering_VERB 1.0
# yaw_VERB 0.15384615384615385
# spins_VERB 0.5
# unstall_VERB 0.9
# inferring_VERB 1.0
# speeds_VERB 0.045454545454545456
# Applying_VERB 1.0
# re-stalled_VERB 1.0
# unstalls_VERB 0.6666666666666666
# drilled_VERB 1.0
# centralised_VERB 1.0
# diving_VERB 0.5
# flick_VERB 0.5
# misting_VERB 1.0
# blots_VERB 1.0
# Flying_VERB 0.45454545454545453
# centralises_VERB 1.0
# eases_VERB 1.0
# over-speeding_VERB 1.0
# Blanketing_VERB 1.0
# airbrakes_VERB 0.016129032258064516
# overbalanced_VERB 1.0
# overbalancing_VERB 1.0
# re-stall_VERB 0.5
# recovers_VERB 1.0
# overstress_VERB 1.0
# regaining_VERB 1.0
# preprogrammed_VERB 1.0
# overstressed_VERB 1.0
# Piecing_VERB 1.0
# tensing_VERB 1.0
# over-ruddering_VERB 0.25
# recentralised_VERB 1.0
# Unstalling_VERB 1.0
# reselect_VERB 1.0
# AGL_VERB 1.0
# recheck_VERB 1.0
# Bergfalke_VERB 0.5
# drifts_VERB 0.16666666666666666
# battled_VERB 1.0
# Discard_VERB 1.0
# Landing_VERB 0.6666666666666666
# reposition_VERB 1.0
# extricate_VERB 1.0
# Positioning_VERB 0.5
# overshoot_VERB 0.5
# sideslipping_VERB 0.7142857142857143
# conceal_VERB 1.0
# Experience_VERB 0.16666666666666666
# Practising_VERB 0.5
# deteriorated'_VERB 1.0
# orientate_VERB 1.0
# orientating_VERB 1.0
# Re-learn_VERB 1.0
# overloading_VERB 0.5
# Blank_VERB 0.5
# Introduce_VERB 1.0
# sideslip_VERB 1.0
# undershooting_VERB 1.0
# manipulating_VERB 1.0
# Aerotow_VERB 1.0
# Crossing_VERB 1.0
# wire_VERB 0.05263157894736842
# aerotow_VERB 0.25
# pitching_VERB 0.6
# over-control_VERB 1.0
# dislikes_VERB 0.25
# incapacitated_VERB 1.0
# re-inforced_VERB 1.0
# Associating_VERB 1.0
# dived_VERB 1.0
# over-correct_VERB 1.0
# ballooning_VERB 1.0
# mis-timing_VERB 1.0
# pitting_VERB 1.0
# Slip_VERB 0.6666666666666666
# spiralling_VERB 0.5
# Hail_VERB 1.0
# hyperventilate_VERB 1.0
# Polishing_VERB 1.0
# hibernating_VERB 1.0
# airbrake_VERB 0.04081632653061224
# sinks_VERB 0.5
# timing_VERB 0.06666666666666667
# crashes_VERB 0.6666666666666666
# Honing_VERB 1.0
# swings_VERB 0.14285714285714285
# Explore_VERB 1.0
# thermalling_VERB 0.5
# Attempt_VERB 1.0
# centring_VERB 1.0
# Detecting_VERB 1.0
# hints_VERB 0.125
# out-climb_VERB 1.0
# centre_VERB 0.008771929824561403
# Checking_VERB 1.0
# banking_VERB 0.25
# steadying_VERB 1.0
# invalidated_VERB 1.0
# Obtain_VERB 1.0
# flap_VERB 0.125
# undercarriage_VERB 0.16666666666666666
# contrive_VERB 1.0
# deluded_VERB 1.0
# jettison_VERB 1.0
# claw_VERB 0.5
# overcontrolling_VERB 1.0
# smooth_VERB 0.04
# retrim_VERB 1.0
# Rejoin_VERB 1.0
# disposes_VERB 1.0
# downgrades_VERB 1.0
# assimilating_VERB 1.0
# praises_VERB 0.3333333333333333
# criticizes_VERB 1.0
# latch_VERB 0.25
# naturalize_VERB 1.0
# fabricates_VERB 1.0
# deems_VERB 1.0
# ascribe_VERB 1.0
# Concerning_VERB 0.3333333333333333
# restates_VERB 1.0
# reviving_VERB 0.5
# signifies_VERB 1.0
# reintroduce_VERB 1.0
# constituting_VERB 1.0
# idealized_VERB 0.6666666666666666
# unseating_VERB 1.0
# reinstates_VERB 1.0
# characterize_VERB 1.0
# transposes_VERB 1.0
# fulfils_VERB 1.0
# entailed_VERB 1.0
# abstracts_VERB 1.0
# apprehends_VERB 1.0
# discriminates_VERB 1.0
# fare_VERB 0.16666666666666666
# reside_VERB 1.0
# analyses_VERB 0.16666666666666666
# quantified_VERB 1.0
# marginalized_VERB 1.0
# muddied_VERB 1.0
# loom_VERB 1.0
# transduces_VERB 1.0
# enduring_VERB 0.3333333333333333
# conserved_VERB 1.0
# bumps_VERB 0.5
# differentiating_VERB 1.0
# distrusting_VERB 1.0
# Recall_VERB 1.0
# contrasting_VERB 0.2
# switches_VERB 0.3333333333333333
# by-passed_VERB 1.0
# blinked_VERB 1.0
# parsing_VERB 0.4
# parse_VERB 1.0
# Believing_VERB 1.0
# slotting_VERB 1.0
# deliberate_VERB 0.06666666666666667
# overstating_VERB 1.0
# canalized_VERB 1.0
# disbelieve_VERB 1.0
# computes_VERB 1.0
# theorize_VERB 1.0
# interact_VERB 1.0
# input_VERB 0.04878048780487805
# Functionlust_VERB 1.0
# glance_VERB 0.18181818181818182
# ascribing_VERB 1.0
# scanning_VERB 1.0
# tiled_VERB 0.3333333333333333
# willed_VERB 1.0
# highfalutin'_VERB 1.0
# flourishing_VERB 0.3333333333333333
# posit_VERB 1.0
# espousing_VERB 1.0
# constructs_VERB 0.14285714285714285
# underlying_VERB 0.35714285714285715
# retrieving_VERB 1.0
# retrieves_VERB 1.0
# witnesses_VERB 0.1
# transposing_VERB 1.0
# disprove_VERB 1.0
# sketching_VERB 1.0
# swamps_VERB 1.0
# co-ordinated_VERB 0.3333333333333333
# misinterpret_VERB 1.0
# misinterpreting_VERB 1.0
# centrated_VERB 1.0
# Viewed_VERB 1.0
# departs_VERB 1.0
# filch_VERB 1.0
# convinces_VERB 1.0
# sucked_VERB 1.0
# processes_VERB 0.01282051282051282
# resonating_VERB 1.0
# inheriting_VERB 1.0
# interacting_VERB 1.0
# Hume_VERB 0.14285714285714285
# translating_VERB 1.0
# lump_VERB 0.09090909090909091
# bracket_VERB 0.1111111111111111
# recurred_VERB 1.0
# affording_VERB 1.0
# localizing_VERB 1.0
# functioning_VERB 0.25
# hallucinating_VERB 1.0
# EEG_VERB 0.1111111111111111
# triggering_VERB 1.0
# Averaging_VERB 0.5
# Subtracting_VERB 1.0
# Libet_VERB 0.05263157894736842
# preceding_VERB 0.25
# electrodes_VERB 0.25
# untangling_VERB 1.0
# signalling_VERB 0.5
# emitted_VERB 1.0
# decreased_VERB 0.5
# damping_VERB 0.75
# peaking_VERB 1.0
# elicited_VERB 1.0
# underpin_VERB 1.0
# correlate_VERB 1.0
# validating_VERB 1.0
# dissociating_VERB 1.0
# compartmentalizes_VERB 1.0
# sheds_VERB 0.5
# elucidating_VERB 1.0
# communicating_VERB 1.0
# by-and-large_VERB 1.0
# impairs_VERB 1.0
# puzzle_VERB 0.2
# probe_VERB 1.0
# parsed_VERB 0.5
# LISTEN_VERB 1.0
# blasp_VERB 0.5
# utilizing_VERB 1.0
# pinpointed_VERB 1.0
# regularizes_VERB 1.0
# Schwartz_VERB 1.0
# pronounces_VERB 1.0
# categorize_VERB 1.0
# clarifies_VERB 1.0
# conceptualizing_VERB 1.0
# lip-read_VERB 1.0
# lip-reading_VERB 0.2
# utilized_VERB 1.0
# priming_VERB 0.4
# accomplish_VERB 1.0
# introspect_VERB 1.0
# conceptualize_VERB 1.0
# comprised_VERB 1.0
# Suggested_VERB 1.0
# imaging_VERB 0.5
# displace_VERB 1.0
# disparage_VERB 1.0
# over-ride_VERB 1.0
# mobilize_VERB 1.0
# presseth_VERB 1.0
# worketh_VERB 1.0
# produceth_VERB 1.0
# impinges_VERB 1.0
# worlded_VERB 1.0
# re-describe_VERB 1.0
# coding_VERB 0.2
# correlating_VERB 1.0
# reconstructed_VERB 0.5
# summarizing_VERB 1.0
# differentiated_VERB 1.0
# formalized_VERB 1.0
# attuned_VERB 1.0
# elicit_VERB 1.0
# correlates_VERB 1.0
# invalidate_VERB 1.0
# spiking_VERB 1.0
# unmasking_VERB 0.5
# encompassed_VERB 1.0
# validates_VERB 1.0
# reposes_VERB 1.0
# reform_VERB 0.1111111111111111
# validate_VERB 1.0
# entrained_VERB 1.0
# defines/explains_VERB 1.0
# by-pass_VERB 1.0
# by-passes_VERB 1.0
# connecting_VERB 1.0
# dotting_VERB 1.0
# proposing_VERB 1.0
# inherits_VERB 1.0
# triggered_VERB 1.0
# encoding_VERB 0.6666666666666666
# encode_VERB 1.0
# translates_VERB 1.0
# decoding_VERB 0.5
# espouse_VERB 1.0
# coheres_VERB 1.0
# postulate_VERB 1.0
# synthesized_VERB 1.0
# dawning_VERB 1.0
# locates_VERB 1.0
# biologize_VERB 1.0
# reiterated_VERB 1.0
# moping_VERB 1.0
# savaged_VERB 1.0
# declaim_VERB 1.0
# Matters_VERB 0.5
# drawled_VERB 0.875
# smouldered_VERB 1.0
# flecked_VERB 0.5
# scrunched_VERB 1.0
# Toss_VERB 1.0
# pervert_VERB 0.5
# edit_VERB 1.0
# unfolded_VERB 1.0
# re-do_VERB 1.0
# faltering_VERB 1.0
# desiring_VERB 1.0
# swoon_VERB 1.0
# murmuring_VERB 0.6666666666666666
# edge_VERB 0.010869565217391304
# impresses_VERB 1.0
# mocking_VERB 0.25
# sanforised_VERB 1.0
# metamorphosed_VERB 1.0
# fantasise_VERB 1.0
# confided_VERB 1.0
# pottering_VERB 1.0
# piss_VERB 0.4
# trilled_VERB 1.0
# horseshit_VERB 1.0
# swatting_VERB 1.0
# hug_VERB 0.4
# capitaine_VERB 1.0
# tiptoe_VERB 0.3333333333333333
# Signing_VERB 0.5
# undress_VERB 1.0
# tantalised_VERB 1.0
# tantalise_VERB 1.0
# flood_VERB 0.16666666666666666
# Driving_VERB 1.0
# Flirting_VERB 1.0
# camouflaged_VERB 1.0
# Believe_VERB 1.0
# masturbated_VERB 1.0
# commiserated_VERB 1.0
# /love_VERB 1.0
# re-read_VERB 1.0
# mess_VERB 0.10344827586206896
# swaggered_VERB 1.0
# Dedicated_VERB 0.5
# Drive_VERB 1.0
# swooping_VERB 0.5
# flyover_VERB 1.0
# raged_VERB 1.0
# declaiming_VERB 1.0
# lap_VERB 0.125
# rip_VERB 1.0
# thrummed_VERB 1.0
# thru'_VERB 1.0
# nuzzle_VERB 1.0
# numbing_VERB 1.0
# floundered_VERB 1.0
# pounded_VERB 1.0
# peed_VERB 1.0
# zipped_VERB 0.5
# sauntered_VERB 1.0
# Cool_VERB 0.5
# yawned_VERB 1.0
# peck_VERB 0.5
# conferring_VERB 1.0
# loped_VERB 1.0
# sheened_VERB 1.0
# shimmered_VERB 1.0
# grabbing_VERB 1.0
# ripping_VERB 1.0
# fucking_VERB 0.029411764705882353
# looped_VERB 0.5
# blurred_VERB 0.75
# Paused_VERB 1.0
# Fool_VERB 1.0
# WAIT_VERB 1.0
# wooing_VERB 1.0
# pubbed_VERB 1.0
# clubbed_VERB 1.0
# waded_VERB 1.0
# spouting_VERB 1.0
# blazoned_VERB 1.0
# scares_VERB 1.0
# ghosted_VERB 1.0
# panicked_VERB 1.0
# partied_VERB 1.0
# paddled_VERB 1.0
# abalone_VERB 1.0
# maundering_VERB 1.0
# schlepp_VERB 1.0
# tingling_VERB 0.5
# sober_VERB 0.0625
# tugged_VERB 1.0
# untie_VERB 1.0
# jangle_VERB 1.0
# agonised_VERB 1.0
# darlinged_VERB 1.0
# butterflying_VERB 1.0
# pardon_VERB 0.6
# twirling_VERB 1.0
# plonking_VERB 1.0
# Fasten_VERB 1.0
# camp_VERB 0.06896551724137931
# Kissed_VERB 1.0
# drool_VERB 1.0
# recycles_VERB 1.0
# frequent_VERB 0.058823529411764705
# Baking_VERB 1.0
# screeched_VERB 1.0
# lurched_VERB 1.0
# pick'em_VERB 1.0
# tweetered_VERB 1.0
# zip_VERB 0.5
# parcelling_VERB 1.0
# crippled_VERB 0.5
# slash_VERB 1.0
# luv_VERB 1.0
# runneth_VERB 1.0
# Cook_VERB 0.038461538461538464
# Open_VERB 0.04
# Yizz_VERB 1.0
# esses_VERB 1.0
# dazed_VERB 0.5
# fears_VERB 0.13333333333333333
# nipples_VERB 0.25
# punctuated_VERB 1.0
# clammed_VERB 1.0
# feigned_VERB 0.6666666666666666
# civilised_VERB 0.4
# phones_VERB 0.5
# blushing_VERB 0.6666666666666666
# crumple_VERB 1.0
# chat_VERB 0.2857142857142857
# volunteering_VERB 1.0
# grin_VERB 0.16666666666666666
# wrecking_VERB 1.0
# explode_VERB 1.0
# Notes_VERB 0.5
# whips_VERB 0.5
# dissolving_VERB 1.0
# melting_VERB 0.5
# lilting_VERB 0.5
# caressing_VERB 1.0
# bleaches_VERB 1.0
# dazzle_VERB 0.4
# tumbles_VERB 1.0
# misted_VERB 1.0
# snowdrop_VERB 1.0
# Stunned_VERB 1.0
# raring_VERB 1.0
# defying_VERB 1.0
# Pardon_VERB 0.4
# Jem_VERB 0.2857142857142857
# loafed_VERB 1.0
# Worry_VERB 1.0
# flatter_VERB 0.3333333333333333
# luxuriated_VERB 1.0
# spat_VERB 1.0
# amuse_VERB 1.0
# bruised_VERB 0.2
# trivialised_VERB 0.5
# knelt_VERB 1.0
# censored_VERB 0.5
# wowing_VERB 1.0
# dope_VERB 0.5
# wank_VERB 1.0
# fleshed_VERB 1.0
# flayed_VERB 1.0
# skin_VERB 0.03508771929824561
# nuzzled_VERB 1.0
# conditioning_VERB 0.14285714285714285
# Licence_VERB 1.0
# flirts_VERB 1.0
# nibbled_VERB 1.0
# ignites_VERB 1.0
# thrills_VERB 1.0
# Lying_VERB 1.0
# conjure_VERB 1.0
# fan_VERB 0.058823529411764705
# Sparkle_VERB 1.0
# swirling_VERB 1.0
# amazes_VERB 1.0
# snow_VERB 0.05555555555555555
# lilts_VERB 1.0
# seduce_VERB 1.0
# materialises_VERB 1.0
# shoots_VERB 0.07142857142857142
# canonises_VERB 1.0
# shatters_VERB 1.0
# whiplashes_VERB 1.0
# Wish_VERB 1.0
# pissed_VERB 0.5555555555555556
# boogie_VERB 1.0
# loitering_VERB 1.0
# enraptured_VERB 1.0
# Sounds_VERB 0.5
# slurring_VERB 1.0
# Ug_VERB 1.0
# mothered_VERB 1.0
# curses_VERB 0.4
# gulping_VERB 1.0
# strutting_VERB 1.0
# straddling_VERB 1.0
# mistressed_VERB 1.0
# ruffling_VERB 1.0
# Sailed_VERB 1.0
# gobbles_VERB 1.0
# Shoppin'_VERB 1.0
# im_VERB 1.0
# Licketty-split_VERB 1.0
# rhapsodised_VERB 1.0
# loose_VERB 0.041666666666666664
# kneaded_VERB 1.0
# cherub_VERB 0.5
# squirt_VERB 0.5
# Wasted_VERB 1.0
# side-stepped_VERB 1.0
# ogling_VERB 1.0
# huggin'_VERB 1.0
# whut_VERB 1.0
# walkin'_VERB 1.0
# searchin'_VERB 1.0
# sun_VERB 0.0078125
# ell_VERB 1.0
# gulped_VERB 1.0
# butting_VERB 1.0
# nudged_VERB 1.0
# firming_VERB 1.0
# jabbed_VERB 1.0
# caressed_VERB 1.0
# 'Samatter_VERB 1.0
# gushing_VERB 1.0
# sloshed_VERB 1.0
# blank_VERB 0.0625
# propped_VERB 1.0
# fret_VERB 0.5
# magicked_VERB 1.0
# hating_VERB 1.0
# necking_VERB 0.5
# fires_VERB 0.06666666666666667
# sneered_VERB 1.0
# thrilling_VERB 0.2
# veer_VERB 1.0
# basked_VERB 1.0
# zipping_VERB 1.0
# boxed_VERB 0.5
# stomped_VERB 1.0
# Ripped_VERB 1.0
# Hug_VERB 1.0
# pain_VERB 0.011764705882352941
# most-likely-to-succeed_VERB 1.0
# Feted_VERB 1.0
# wined_VERB 1.0
# boot_VERB 0.16666666666666666
# slum_VERB 0.25
# fielding_VERB 1.0
# mothering_VERB 1.0
# plying_VERB 1.0
# gloried_VERB 1.0
# blanked_VERB 1.0
# panted_VERB 1.0
# slake_VERB 1.0
# mirage_VERB 0.3333333333333333
# shrivelled_VERB 0.5
# fearing_VERB 1.0
# commenting_VERB 1.0
# Waited_VERB 1.0
# centipede_VERB 1.0
# riot_VERB 0.14285714285714285
# swapping_VERB 1.0
# shoosh_VERB 1.0
# fumble_VERB 1.0
# intimated_VERB 1.0
# Downed_VERB 1.0
# re-filled_VERB 1.0
# yowling_VERB 1.0
# screech_VERB 0.3333333333333333
# forsake_VERB 1.0
# Swoop_VERB 1.0
# swoop_VERB 0.5
# hates_VERB 1.0
# grinds_VERB 0.25
# whippet_VERB 0.5
# hop_VERB 0.2
# Lighten_VERB 1.0
# snuffle_VERB 1.0
# Rooted_VERB 1.0
# hardening_VERB 1.0
# browsed_VERB 1.0
# dahlink_VERB 0.5
# gehd_VERB 1.0
# Led_VERB 1.0
# slather_VERB 1.0
# Negotiating_VERB 1.0
# toughen_VERB 1.0
# Sober_VERB 1.0
# Pushed_VERB 1.0
# blissed_VERB 1.0
# bronzes_VERB 0.5
# Stroll_VERB 1.0
# borrowing_VERB 1.0
# steady_VERB 0.045454545454545456
# discommode_VERB 1.0
# Lend_VERB 1.0
# phase_VERB 0.041666666666666664
# compering_VERB 1.0
# Relegate_VERB 1.0
# repulsed_VERB 1.0
# veil_VERB 0.3333333333333333
# rampaged_VERB 1.0
# crumpling_VERB 1.0
# re-run_VERB 1.0
# shushed_VERB 1.0
# coaxed_VERB 1.0
# Felt_VERB 1.0
# entangled_VERB 1.0
# fling_VERB 0.6666666666666666
# spiralled_VERB 1.0
# Zzthat_VERB 1.0
# moonbeam_VERB 0.5
# Sanctified_VERB 1.0
# muscled_VERB 1.0
# TELL_VERB 1.0
# socialising_VERB 1.0
# bawl_VERB 1.0
# Floating_VERB 0.6666666666666666
# crackling_VERB 1.0
# stabbing_VERB 1.0
# flits_VERB 1.0
# Becomes_VERB 1.0
# lugs_VERB 1.0
# whittering_VERB 1.0
# Squinted_VERB 1.0
# whingeing_VERB 1.0
# fretted_VERB 1.0
# blindfolded_VERB 1.0
# chanted_VERB 1.0
# FUCK_VERB 1.0
# firmed_VERB 1.0
# seeding_VERB 1.0
# re-dialled_VERB 1.0
# foaming_VERB 1.0
# splattered_VERB 0.5
# prying_VERB 0.3333333333333333
# unravelled_VERB 1.0
# beached_VERB 0.3333333333333333
# shredded_VERB 1.0
# roughened_VERB 1.0
# Counterposing_VERB 1.0
# Gawping_VERB 1.0
# swooped_VERB 1.0
# shuttled_VERB 1.0
# Fooled_VERB 1.0
# duped_VERB 1.0
# unscrewed_VERB 1.0
# snowed_VERB 1.0
# Hoped_VERB 1.0
# cornflowers_VERB 0.3333333333333333
# Seeing_VERB 0.5
# mailing_VERB 1.0
# paralysed_VERB 0.5
# Scrub_VERB 1.0
# sparking_VERB 1.0
# skimmed_VERB 0.5
# mend_VERB 1.0
# showered_VERB 1.0
# fiddled_VERB 1.0
# lazed_VERB 1.0
# transfixed_VERB 1.0
# flurried_VERB 1.0
# s'il_VERB 1.0
# L'anglaise_VERB 1.0
# timmortalshe_VERB 1.0
# soughed_VERB 1.0
# overreached_VERB 1.0
# organises_VERB 1.0
# copes_VERB 1.0
# wincing_VERB 1.0
# tanned_VERB 0.5
# rocketed_VERB 1.0
# malingering_VERB 1.0
# seeped_VERB 1.0
# drydocked_VERB 1.0
# gusted_VERB 1.0
# flirted_VERB 1.0
# wastes_VERB 1.0
# lumbered_VERB 1.0
# raging_VERB 0.25
# Crew-cut_VERB 1.0
# lollopped_VERB 1.0
# warms_VERB 1.0
# stalk_VERB 1.0
# Skulk_VERB 1.0
# howls_VERB 1.0
# bares_VERB 1.0
# fluffs_VERB 1.0
# glitter_VERB 0.25
# tightens_VERB 1.0
# lounges_VERB 1.0
# stakes_VERB 0.16666666666666666
# lope_VERB 1.0
# satiated_VERB 1.0
# regroups_VERB 1.0
# petted_VERB 1.0
# Lurch_VERB 1.0
# Slop_VERB 1.0
# slashes_VERB 1.0
# Claw_VERB 1.0
# manoeuvres_VERB 0.2
# throb_VERB 0.5
# Rasped_VERB 1.0
# pitches_VERB 0.5
# clatters_VERB 0.5
# bundle_VERB 0.125
# slumps_VERB 1.0
# jolts_VERB 1.0
# streak_VERB 0.2
# streaks_VERB 0.5
# sags_VERB 1.0
# arches_VERB 0.14285714285714285
# flings_VERB 1.0
# drags_VERB 1.0
# pulsing_VERB 1.0
# Delight_VERB 0.5
# sculpt_VERB 1.0
# cuffing_VERB 1.0
# spooning_VERB 1.0
# kid_VERB 0.16666666666666666
# razor_VERB 1.0
# humiliate_VERB 1.0
# crooked_VERB 0.25
# worming_VERB 1.0
# treasured_VERB 0.3333333333333333
# scorning_VERB 1.0
# Whimper_VERB 1.0
# tango_VERB 0.5
# sheathing_VERB 1.0
# stomp_VERB 1.0
# whittered_VERB 1.0
# hurtled_VERB 1.0
